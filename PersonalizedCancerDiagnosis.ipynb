# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
#from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 224.68044710000686 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.4768812501546282
# Log loss on Test Data using Random Model 2.515220677627905
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 230
# BRCA1     177
# TP53      107
# EGFR       89
# PTEN       76
# BRCA2      74
# KIT        66
# BRAF       61
# ERBB2      48
# ALK        45
# PDGFRA     45
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 230 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2708      BRAF
# 2438     BRCA1
# 2318      JAK2
# 3073    NOTCH1
# 1511       ALK
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1a',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'asxl1',
#  'atm',
#  'atr',
#  'aurkb',
#  'axin1',
#  'b2m',
#  'bap1',
#  'bard1',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brd4',
#  'brip1',
#  'btk',
#  'card11',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'cebpa',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'epcam',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fam58a',
#  'fanca',
#  'fat1',
#  'fbxw7',
#  'fgf19',
#  'fgf3',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt1',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxo1',
#  'foxp1',
#  'fubp1',
#  'gata3',
#  'gli1',
#  'gna11',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hist1h1c',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'ikzf1',
#  'il7r',
#  'inpp4b',
#  'jak1',
#  'jak2',
#  'jun',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'kmt2a',
#  'kmt2b',
#  'kmt2c',
#  'knstrn',
#  'kras',
#  'lats1',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mdm2',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'mycn',
#  'myd88',
#  'ncor1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'npm1',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk3',
#  'nup93',
#  'pak1',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pik3r3',
#  'pim1',
#  'pms1',
#  'pms2',
#  'pole',
#  'ppm1d',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51b',
#  'rad51d',
#  'raf1',
#  'rara',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rictor',
#  'rit1',
#  'rnf43',
#  'ros1',
#  'runx1',
#  'rxra',
#  'rybp',
#  'sdhb',
#  'setd2',
#  'sf3b1',
#  'shq1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf3',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tp53bp1',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vegfa',
#  'vhl',
#  'whsc1',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 230)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1815767306804028
# For values of alpha =  0.0001 The log loss is: 1.170259811199067
# For values of alpha =  0.001 The log loss is: 1.2257934940725839
# For values of alpha =  0.01 The log loss is: 1.359463700150422
# For values of alpha =  0.1 The log loss is: 1.4583173976640031
# For values of alpha =  1 The log loss is: 1.4954423186681118
# For values of best alpha =  0.0001 The train log loss is: 1.0172814717012544
# For values of best alpha =  0.0001 The cross validation log loss is: 1.170259811199067
# For values of best alpha =  0.0001 The test log loss is: 1.2060857621842993

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  230  genes in train dataset?
# Ans
# 1. In test data 631 out of 665 : 94.88721804511279
# 2. In cross validation data 516 out of  532 : 96.99248120300751

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1928
# Truncating_Mutations    55
# Deletion                51
# Amplification           45
# Fusions                 25
# T58I                     3
# G12V                     3
# Q61H                     3
# Overexpression           3
# M1R                      2
# G67R                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1928 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02589454 0.04990584 0.07109228 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1950)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7322148163905366
# For values of alpha =  0.0001 The log loss is: 1.730686241012458
# For values of alpha =  0.001 The log loss is: 1.7318570560320878
# For values of alpha =  0.01 The log loss is: 1.7376417479467952
# For values of alpha =  0.1 The log loss is: 1.7499525511099958
# For values of alpha =  1 The log loss is: 1.7510093554334205
# For values of best alpha =  0.0001 The train log loss is: 0.799091962983687
# For values of best alpha =  0.0001 The cross validation log loss is: 1.730686241012458
# For values of best alpha =  0.0001 The test log loss is: 1.7009741447656277

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1928  genes in test and cross validation data sets?
# Ans
# 1. In test data 75 out of 665 : 11.278195488721805
# 2. In cross validation data 48 out of  532 : 9.022556390977442

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 53836

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({3: 5891, 4: 3786, 5: 2697, 6: 2576, 7: 2309, 8: 1994, 9: 1647, 10: 1488, 12: 1352, 11: 1171, 14: 1041, 15: 948, 16: 944, 13: 793, 18: 668, 17: 633, 24: 621, 20: 562, 21: 526, 22: 469, 19: 447, 28: 381, 23: 368, 37: 365, 25: 358, 30: 342, 26: 342, 27: 339, 32: 335, 48: 329, 31: 311, 36: 304, 33: 291, 29: 273, 35: 271, 34: 262, 42: 236, 40: 214, 39: 213, 38: 198, 45: 197, 44: 193, 41: 176, 50: 170, 51: 168, 49: 162, 43: 162, 55: 157, 52: 147, 46: 146, 47: 141, 54: 140, 56: 139, 60: 136, 57: 133, 70: 131, 64: 129, 63: 123, 53: 118, 58: 113, 66: 109, 61: 108, 68: 106, 67: 106, 59: 102, 62: 98, 65: 95, 84: 93, 72: 93, 75: 88, 69: 87, 73: 85, 71: 85, 96: 82, 78: 80, 77: 78, 80: 77, 76: 76, 85: 75, 79: 75, 74: 74, 87: 71, 82: 68, 81: 66, 94: 65, 90: 65, 86: 65, 92: 64, 98: 62, 93: 62, 108: 61, 89: 61, 83: 60, 97: 58, 124: 57, 88: 57, 105: 55, 102: 54, 99: 54, 120: 51, 110: 51, 91: 51, 121: 49, 113: 49, 103: 49, 101: 49, 100: 49, 126: 48, 95: 48, 130: 47, 114: 47, 127: 46, 117: 46, 115: 46, 125: 45, 111: 45, 116: 44, 147: 43, 119: 43, 106: 43, 109: 42, 107: 42, 139: 41, 123: 41, 142: 40, 112: 40, 104: 40, 140: 38, 132: 38, 136: 37, 144: 36, 118: 36, 156: 35, 129: 35, 128: 35, 145: 34, 137: 34, 131: 34, 155: 33, 135: 33, 200: 31, 195: 30, 172: 30, 141: 30, 138: 30, 122: 30, 180: 28, 157: 28, 149: 28, 154: 27, 230: 26, 186: 26, 185: 26, 183: 26, 173: 26, 171: 26, 161: 26, 160: 26, 152: 26, 151: 26, 189: 25, 158: 25, 150: 25, 148: 25, 143: 25, 133: 25, 222: 24, 220: 24, 213: 24, 208: 24, 207: 24, 194: 24, 176: 24, 168: 24, 166: 24, 134: 24, 255: 23, 190: 23, 182: 23, 177: 23, 174: 23, 169: 23, 167: 23, 163: 23, 153: 23, 276: 22, 218: 22, 209: 22, 179: 22, 164: 22, 236: 21, 203: 21, 193: 21, 192: 21, 184: 21, 175: 21, 162: 21, 146: 21, 280: 20, 232: 20, 217: 20, 202: 20, 197: 20, 187: 20, 181: 20, 159: 20, 212: 19, 199: 19, 198: 19, 188: 19, 170: 19, 306: 18, 267: 18, 240: 18, 234: 18, 219: 18, 201: 18, 178: 18, 165: 18, 288: 17, 281: 17, 238: 17, 233: 17, 214: 17, 191: 17, 331: 16, 275: 16, 262: 16, 249: 16, 244: 16, 231: 16, 229: 16, 228: 16, 224: 16, 223: 16, 216: 16, 206: 16, 204: 16, 286: 15, 257: 15, 250: 15, 248: 15, 247: 15, 246: 15, 242: 15, 221: 15, 215: 15, 210: 15, 398: 14, 333: 14, 303: 14, 293: 14, 283: 14, 271: 14, 243: 14, 241: 14, 239: 14, 227: 14, 205: 14, 196: 14, 348: 13, 342: 13, 337: 13, 321: 13, 314: 13, 305: 13, 287: 13, 279: 13, 277: 13, 258: 13, 252: 13, 450: 12, 360: 12, 340: 12, 327: 12, 322: 12, 311: 12, 300: 12, 298: 12, 294: 12, 284: 12, 259: 12, 226: 12, 417: 11, 413: 11, 390: 11, 384: 11, 357: 11, 338: 11, 335: 11, 329: 11, 328: 11, 324: 11, 309: 11, 304: 11, 282: 11, 272: 11, 270: 11, 265: 11, 263: 11, 261: 11, 254: 11, 237: 11, 508: 10, 408: 10, 391: 10, 383: 10, 377: 10, 373: 10, 356: 10, 351: 10, 341: 10, 330: 10, 326: 10, 323: 10, 301: 10, 297: 10, 296: 10, 292: 10, 278: 10, 264: 10, 260: 10, 251: 10, 235: 10, 668: 9, 636: 9, 594: 9, 519: 9, 518: 9, 513: 9, 512: 9, 463: 9, 447: 9, 439: 9, 437: 9, 400: 9, 378: 9, 370: 9, 364: 9, 359: 9, 350: 9, 346: 9, 345: 9, 344: 9, 343: 9, 334: 9, 320: 9, 310: 9, 274: 9, 269: 9, 266: 9, 253: 9, 245: 9, 211: 9, 608: 8, 591: 8, 558: 8, 528: 8, 493: 8, 491: 8, 487: 8, 486: 8, 471: 8, 470: 8, 468: 8, 451: 8, 448: 8, 430: 8, 414: 8, 401: 8, 397: 8, 396: 8, 393: 8, 380: 8, 374: 8, 361: 8, 336: 8, 318: 8, 313: 8, 295: 8, 290: 8, 289: 8, 268: 8, 256: 8, 225: 8, 788: 7, 782: 7, 778: 7, 693: 7, 631: 7, 624: 7, 614: 7, 613: 7, 598: 7, 586: 7, 564: 7, 555: 7, 552: 7, 516: 7, 465: 7, 446: 7, 445: 7, 444: 7, 441: 7, 422: 7, 418: 7, 402: 7, 392: 7, 386: 7, 385: 7, 381: 7, 375: 7, 366: 7, 354: 7, 352: 7, 349: 7, 325: 7, 316: 7, 312: 7, 308: 7, 302: 7, 285: 7, 1010: 6, 987: 6, 948: 6, 930: 6, 916: 6, 876: 6, 849: 6, 800: 6, 759: 6, 734: 6, 727: 6, 681: 6, 615: 6, 605: 6, 568: 6, 543: 6, 542: 6, 534: 6, 520: 6, 504: 6, 502: 6, 481: 6, 469: 6, 464: 6, 462: 6, 461: 6, 443: 6, 438: 6, 436: 6, 433: 6, 431: 6, 423: 6, 420: 6, 416: 6, 415: 6, 409: 6, 403: 6, 395: 6, 394: 6, 376: 6 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.2815049178334839
# For values of alpha =  0.0001 The log loss is: 1.146504762188746
# For values of alpha =  0.001 The log loss is: 1.1305162641281696
# For values of alpha =  0.01 The log loss is: 1.2059886315700925
# For values of alpha =  0.1 The log loss is: 1.3582529706490565
# For values of alpha =  1 The log loss is: 1.6097509893225932
# For values of best alpha =  0.001 The train log loss is: 0.7093305006814528
# For values of best alpha =  0.001 The cross validation log loss is: 1.1305162641281696
# For values of best alpha =  0.001 The test log loss is: 1.2206265817459334

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 96.701 % of word of test data appeared in train data
# 98.48 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 56016)
# (number of data points * number of features) in test data =  (665, 56016)
# (number of data points * number of features) in cross validation data = (532, 56016)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.319745260144822
# for alpha = 0.0001
# Log Loss : 1.3121031357156474
# for alpha = 0.001
# Log Loss : 1.298580358254121
# for alpha = 0.1
# Log Loss : 1.26711312478179
# for alpha = 1
# Log Loss : 1.2838397468114364
# for alpha = 10
# Log Loss : 1.3597817721921401
# for alpha = 100
# Log Loss : 1.3333282067290908
# for alpha = 1000
# Log Loss : 1.2776203330021647
# For values of best alpha =  0.1 The train log loss is: 0.8991039536924197
# For values of best alpha =  0.1 The cross validation log loss is: 1.26711312478179
# For values of best alpha =  0.1 The test log loss is: 1.273135032041077

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.26711312478179
# Number of missclassified point : 0.3890977443609023
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0807 0.0733 0.0118 0.1071 0.0369 0.5535 0.1305 0.0034 0.0028]]
# Actual Class : 6
# --------------------------------------------------
# 7 Text feature [i2285v] present in test data point [True]
# 8 Text feature [personal] present in test data point [True]
# 9 Text feature [brca] present in test data point [True]
# 13 Text feature [ivs5] present in test data point [True]
# 15 Text feature [odds] present in test data point [True]
# 18 Text feature [history] present in test data point [True]
# 20 Text feature [433] present in test data point [True]
# Out of the top  100  features  7 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0796 0.0719 0.0117 0.1059 0.0359 0.0362 0.6526 0.0034 0.0028]]
# Actual Class : 7
# --------------------------------------------------
# 18 Text feature [presence] present in test data point [True]
# 19 Text feature [downstream] present in test data point [True]
# 20 Text feature [independent] present in test data point [True]
# 21 Text feature [activating] present in test data point [True]
# 22 Text feature [potential] present in test data point [True]
# 23 Text feature [inhibitor] present in test data point [True]
# 24 Text feature [well] present in test data point [True]
# 26 Text feature [showed] present in test data point [True]
# 27 Text feature [recently] present in test data point [True]
# 28 Text feature [cell] present in test data point [True]
# 29 Text feature [contrast] present in test data point [True]
# 30 Text feature [expressing] present in test data point [True]
# 31 Text feature [activation] present in test data point [True]
# 32 Text feature [cells] present in test data point [True]
# 33 Text feature [found] present in test data point [True]
# 34 Text feature [shown] present in test data point [True]
# 35 Text feature [also] present in test data point [True]
# 36 Text feature [suggest] present in test data point [True]
# 38 Text feature [growth] present in test data point [True]
# 39 Text feature [however] present in test data point [True]
# 40 Text feature [10] present in test data point [True]
# 42 Text feature [compared] present in test data point [True]
# 43 Text feature [similar] present in test data point [True]
# 44 Text feature [inhibition] present in test data point [True]
# 45 Text feature [mutations] present in test data point [True]
# 46 Text feature [higher] present in test data point [True]
# 47 Text feature [12] present in test data point [True]
# 48 Text feature [treated] present in test data point [True]
# 49 Text feature [described] present in test data point [True]
# 50 Text feature [may] present in test data point [True]
# 51 Text feature [addition] present in test data point [True]
# 52 Text feature [studies] present in test data point [True]
# 53 Text feature [molecular] present in test data point [True]
# 54 Text feature [total] present in test data point [True]
# 55 Text feature [factor] present in test data point [True]
# 56 Text feature [observed] present in test data point [True]
# 57 Text feature [without] present in test data point [True]
# 58 Text feature [approximately] present in test data point [True]
# 59 Text feature [phosphorylation] present in test data point [True]
# 60 Text feature [1a] present in test data point [True]
# 61 Text feature [concentrations] present in test data point [True]
# 62 Text feature [using] present in test data point [True]
# 64 Text feature [new] present in test data point [True]
# 65 Text feature [reported] present in test data point [True]
# 66 Text feature [three] present in test data point [True]
# 68 Text feature [followed] present in test data point [True]
# 69 Text feature [identified] present in test data point [True]
# 70 Text feature [including] present in test data point [True]
# 71 Text feature [respectively] present in test data point [True]
# 72 Text feature [furthermore] present in test data point [True]
# 73 Text feature [therapeutic] present in test data point [True]
# 74 Text feature [consistent] present in test data point [True]
# 75 Text feature [small] present in test data point [True]
# 76 Text feature [sensitive] present in test data point [True]
# 77 Text feature [inhibitors] present in test data point [True]
# 78 Text feature [various] present in test data point [True]
# 79 Text feature [occur] present in test data point [True]
# 80 Text feature [although] present in test data point [True]
# 81 Text feature [mutation] present in test data point [True]
# 82 Text feature [two] present in test data point [True]
# 83 Text feature [interestingly] present in test data point [True]
# 84 Text feature [report] present in test data point [True]
# 85 Text feature [suggests] present in test data point [True]
# 86 Text feature [similarly] present in test data point [True]
# 87 Text feature [recent] present in test data point [True]
# 88 Text feature [either] present in test data point [True]
# 89 Text feature [figure] present in test data point [True]
# 90 Text feature [different] present in test data point [True]
# 91 Text feature [thus] present in test data point [True]
# 92 Text feature [activated] present in test data point [True]
# 93 Text feature [due] present in test data point [True]
# 94 Text feature [enhanced] present in test data point [True]
# 95 Text feature [15] present in test data point [True]
# 96 Text feature [whereas] present in test data point [True]
# 98 Text feature [constitutively] present in test data point [True]
# 99 Text feature [show] present in test data point [True]
# Out of the top  100  features  76 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.0167678320827498
# for alpha = 11
# Log Loss : 1.0353556389730036
# for alpha = 15
# Log Loss : 1.0692953244285317
# for alpha = 21
# Log Loss : 1.082282171411136
# for alpha = 31
# Log Loss : 1.079656610782329
# for alpha = 41
# Log Loss : 1.0822670786880215
# for alpha = 51
# Log Loss : 1.0770189122982294
# for alpha = 99
# Log Loss : 1.1197890799100998
# For values of best alpha =  5 The train log loss is: 0.4962743736264608
# For values of best alpha =  5 The cross validation log loss is: 1.0167678320827498
# For values of best alpha =  5 The test log loss is: 1.108841599975996

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0167678320827498
# Number of mis-classified points : 0.34774436090225563
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 1
# Actual Class : 6
# The  5  nearest neighbours of the test points belongs to classes [6 6 6 6 6]
# Fequency of nearest points : Counter({6: 5})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 5 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7]
# Fequency of nearest points : Counter({7: 5})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.321437486057796
# for alpha = 1e-05
# Log Loss : 1.2882423547296564
# for alpha = 0.0001
# Log Loss : 1.078478201041872
# for alpha = 0.001
# Log Loss : 1.0669104366743776
# for alpha = 0.01
# Log Loss : 1.1182170917744263
# for alpha = 0.1
# Log Loss : 1.3971699560294686
# for alpha = 1
# Log Loss : 1.6399033542845391
# for alpha = 10
# Log Loss : 1.6745572039579208
# for alpha = 100
# Log Loss : 1.6782357925114935
# For values of best alpha =  0.001 The train log loss is: 0.5747751614004597
# For values of best alpha =  0.001 The cross validation log loss is: 1.0669104366743776
# For values of best alpha =  0.001 The test log loss is: 1.1603154104187405

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0669104366743776
# Number of mis-classified points : 0.3157894736842105
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.041  0.0467 0.0083 0.0353 0.24   0.576  0.0418 0.0056 0.0053]]
# Actual Class : 6
# --------------------------------------------------
# 275 Text feature [ivs2] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[7.800e-03 5.000e-03 4.000e-04 9.000e-04 1.700e-03 7.000e-04 9.792e-01
#   3.200e-03 1.000e-03]]
# Actual Class : 7
# --------------------------------------------------
# 25 Text feature [constitutive] present in test data point [True]
# 39 Text feature [oncogene] present in test data point [True]
# 51 Text feature [constitutively] present in test data point [True]
# 80 Text feature [downstream] present in test data point [True]
# 130 Text feature [activated] present in test data point [True]
# 171 Text feature [expressing] present in test data point [True]
# 192 Text feature [concentrations] present in test data point [True]
# 212 Text feature [activation] present in test data point [True]
# 262 Text feature [nanomolar] present in test data point [True]
# 315 Text feature [nf] present in test data point [True]
# 355 Text feature [dimension] present in test data point [True]
# 405 Text feature [activating] present in test data point [True]
# 414 Text feature [therapeutics] present in test data point [True]
# 481 Text feature [cysteine] present in test data point [True]
# Out of the top  500  features  14 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2750776831487485
# for alpha = 1e-05
# Log Loss : 1.2306595672421707
# for alpha = 0.0001
# Log Loss : 1.1093125863413649
# for alpha = 0.001
# Log Loss : 1.0811717717186475
# for alpha = 0.01
# Log Loss : 1.1617646218594344
# for alpha = 0.1
# Log Loss : 1.2800863342886417
# for alpha = 1
# Log Loss : 1.5471711315517853
# For values of best alpha =  0.001 The train log loss is: 0.5703198112902136
# For values of best alpha =  0.001 The cross validation log loss is: 1.0811717717186475
# For values of best alpha =  0.001 The test log loss is: 1.1774147909686155

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0811717717186475
# Number of mis-classified points : 0.32706766917293234
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0406 0.0485 0.0091 0.0365 0.2278 0.5844 0.0447 0.0051 0.0033]]
# Actual Class : 6
# --------------------------------------------------
# 240 Text feature [ivs2] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[8.500e-03 5.600e-03 3.000e-04 1.200e-03 1.500e-03 7.000e-04 9.804e-01
#   1.800e-03 1.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 83 Text feature [constitutive] present in test data point [True]
# 117 Text feature [oncogene] present in test data point [True]
# 124 Text feature [constitutively] present in test data point [True]
# 174 Text feature [downstream] present in test data point [True]
# 213 Text feature [expressing] present in test data point [True]
# 237 Text feature [activated] present in test data point [True]
# 310 Text feature [concentrations] present in test data point [True]
# 320 Text feature [nf] present in test data point [True]
# 333 Text feature [activating] present in test data point [True]
# 334 Text feature [activation] present in test data point [True]
# 383 Text feature [cysteine] present in test data point [True]
# 452 Text feature [enhanced] present in test data point [True]
# 458 Text feature [nanomolar] present in test data point [True]
# Out of the top  500  features  13 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.2902522960255227
# for C = 0.0001
# Log Loss : 1.2035769305862518
# for C = 0.001
# Log Loss : 1.092396062807334
# for C = 0.01
# Log Loss : 1.1040926236306452
# for C = 0.1
# Log Loss : 1.3237163274800217
# for C = 1
# Log Loss : 1.6608062135658774
# for C = 10
# Log Loss : 1.6788500754795848
# for C = 100
# Log Loss : 1.6788535142876042
# For values of best alpha =  0.001 The train log loss is: 0.592765159429417
# For values of best alpha =  0.001 The cross validation log loss is: 1.092396062807334
# For values of best alpha =  0.001 The test log loss is: 1.2199811119834565

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.092396062807334
# Number of mis-classified points : 0.32894736842105265
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0603 0.0735 0.0165 0.0753 0.1865 0.446  0.1311 0.0055 0.0053]]
# Actual Class : 6
# --------------------------------------------------
# 413 Text feature [cleveland] present in test data point [True]
# Out of the top  500  features  1 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0547 0.0212 0.0097 0.0143 0.0159 0.0095 0.868  0.0033 0.0033]]
# Actual Class : 7
# --------------------------------------------------
# 349 Text feature [oncogene] present in test data point [True]
# 370 Text feature [constitutive] present in test data point [True]
# 448 Text feature [26s] present in test data point [True]
# 488 Text feature [polyubiquitinated] present in test data point [True]
# Out of the top  500  features  4 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2000290978795645
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1505163292148493
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.1920266204733811
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.1494540745733282
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.181897846297915
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.1370811447337992
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1839916852341965
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.133941550559429
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.182123577013616
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.131234147741131
# For values of best estimator =  2000 The train log loss is: 0.7053883548401354
# For values of best estimator =  2000 The cross validation log loss is: 1.131234147741131
# For values of best estimator =  2000 The test log loss is: 1.1869067856299973

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.131234147741131
# Number of mis-classified points : 0.35902255639097747
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0458 0.0175 0.0138 0.0314 0.0961 0.7734 0.015  0.0032 0.0038]]
# Actual Class : 6
# --------------------------------------------------
# 7 Text feature [missense] present in test data point [True]
# 10 Text feature [function] present in test data point [True]
# 11 Text feature [growth] present in test data point [True]
# 13 Text feature [functional] present in test data point [True]
# 16 Text feature [receptor] present in test data point [True]
# 20 Text feature [treatment] present in test data point [True]
# 21 Text feature [brca1] present in test data point [True]
# 22 Text feature [cells] present in test data point [True]
# 24 Text feature [therapeutic] present in test data point [True]
# 25 Text feature [deleterious] present in test data point [True]
# 30 Text feature [loss] present in test data point [True]
# 40 Text feature [pathogenic] present in test data point [True]
# 51 Text feature [lines] present in test data point [True]
# 52 Text feature [variants] present in test data point [True]
# 53 Text feature [pathogenicity] present in test data point [True]
# 55 Text feature [cell] present in test data point [True]
# 56 Text feature [brca2] present in test data point [True]
# 59 Text feature [neutral] present in test data point [True]
# 64 Text feature [patients] present in test data point [True]
# 68 Text feature [truncating] present in test data point [True]
# 76 Text feature [treated] present in test data point [True]
# 79 Text feature [protein] present in test data point [True]
# 80 Text feature [variant] present in test data point [True]
# 84 Text feature [carriers] present in test data point [True]
# 85 Text feature [clinical] present in test data point [True]
# 89 Text feature [dna] present in test data point [True]
# 93 Text feature [independent] present in test data point [True]
# 95 Text feature [patient] present in test data point [True]
# 96 Text feature [odds] present in test data point [True]
# Out of the top  100  features  29 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0675 0.0428 0.0149 0.0418 0.033  0.0309 0.7598 0.0042 0.005 ]]
# Actuall Class : 7
# --------------------------------------------------
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 4 Text feature [activating] present in test data point [True]
# 5 Text feature [phosphorylation] present in test data point [True]
# 6 Text feature [constitutive] present in test data point [True]
# 7 Text feature [missense] present in test data point [True]
# 8 Text feature [suppressor] present in test data point [True]
# 9 Text feature [oncogenic] present in test data point [True]
# 10 Text feature [function] present in test data point [True]
# 11 Text feature [growth] present in test data point [True]
# 12 Text feature [activated] present in test data point [True]
# 13 Text feature [functional] present in test data point [True]
# 14 Text feature [inhibitor] present in test data point [True]
# 16 Text feature [receptor] present in test data point [True]
# 17 Text feature [signaling] present in test data point [True]
# 19 Text feature [downstream] present in test data point [True]
# 20 Text feature [treatment] present in test data point [True]
# 22 Text feature [cells] present in test data point [True]
# 24 Text feature [therapeutic] present in test data point [True]
# 27 Text feature [inhibition] present in test data point [True]
# 28 Text feature [constitutively] present in test data point [True]
# 30 Text feature [loss] present in test data point [True]
# 31 Text feature [therapy] present in test data point [True]
# 35 Text feature [trials] present in test data point [True]
# 36 Text feature [activate] present in test data point [True]
# 37 Text feature [expressing] present in test data point [True]
# 43 Text feature [stability] present in test data point [True]
# 49 Text feature [oncogene] present in test data point [True]
# 50 Text feature [efficacy] present in test data point [True]
# 51 Text feature [lines] present in test data point [True]
# 55 Text feature [cell] present in test data point [True]
# 57 Text feature [survival] present in test data point [True]
# 58 Text feature [sensitive] present in test data point [True]
# 61 Text feature [advanced] present in test data point [True]
# 63 Text feature [nsclc] present in test data point [True]
# 64 Text feature [patients] present in test data point [True]
# 65 Text feature [proteins] present in test data point [True]
# 67 Text feature [expression] present in test data point [True]
# 69 Text feature [drug] present in test data point [True]
# 70 Text feature [proliferation] present in test data point [True]
# 71 Text feature [p53] present in test data point [True]
# 74 Text feature [nuclear] present in test data point [True]
# 76 Text feature [treated] present in test data point [True]
# 77 Text feature [repair] present in test data point [True]
# 79 Text feature [protein] present in test data point [True]
# 81 Text feature [inhibited] present in test data point [True]
# 85 Text feature [clinical] present in test data point [True]
# 86 Text feature [resistance] present in test data point [True]
# 87 Text feature [egfr] present in test data point [True]
# 89 Text feature [dna] present in test data point [True]
# 91 Text feature [lung] present in test data point [True]
# 93 Text feature [independent] present in test data point [True]
# 98 Text feature [concentrations] present in test data point [True]
# 99 Text feature [active] present in test data point [True]
# Out of the top  100  features  54 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.1078747993651503
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.8307733412869809
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.6107294751679195
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.6985541376614781
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.7234929129263734
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.5030911562597173
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.4391679564349702
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.8107978257420059
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.595008368988449
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.498227710381488
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.4031650824514248
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.7570867230927614
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.6460863139245137
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.4931979176793455
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.4421204305564523
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.741720532584378
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.6866788323199389
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.5666836155008146
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.4840120419929288
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.7607209866933915
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.6453964477299616
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5726297464097267
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.4469936962313432
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.7260968929328566
# For values of best alpha =  100 The train log loss is: 0.0585571153549904
# For values of best alpha =  100 The cross validation log loss is: 1.4031650824514248
# For values of best alpha =  100 The test log loss is: 1.3927636713320215

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.4031650824514248
# Number of mis-classified points : 0.5357142857142857
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0212 0.0064 0.0684 0.0202 0.3046 0.5627 0.0036 0.0072 0.0056]]
# Actual Class : 6
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 3
# Predicted Class Probabilities: [[0.0203 0.1573 0.2996 0.0238 0.0286 0.0727 0.2335 0.1369 0.0273]]
# Actual Class : 7
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.08
# Support vector machines : Log Loss: 1.66
# Naive Bayes : Log Loss: 1.30
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.038
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.518
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.126
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.227
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.507

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.6534154034540243
# Log loss (CV) on the stacking classifier : 1.1258732315949933
# Log loss (test) on the stacking classifier : 1.158671059119113
# Number of missclassified point : 0.37142857142857144
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9115768096286516
# Log loss (CV) on the VotingClassifier : 1.192222700521023
# Log loss (test) on the VotingClassifier : 1.2426670821391048
# Number of missclassified point : 0.3669172932330827
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h1>5. Assignments</h1>

# %% [markdown]
# <li> Apply All the models with tf-idf features (Replace CountVectorizer with tfidfVectorizer and run the same cells)</li>
# <li> Instead of using all the words in the dataset, use only the top 1000 words based of tf-idf values</li>

# %%
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000)
    var_count_vec = TfidfVectorizer(max_features=1000)
    text_count_vec = TfidfVectorizer(max_features=1000,min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# one-hot encoding of Gene feature.
gene_tfidf = TfidfVectorizer(max_features=1000)
train_gene_feature_onehotCoding_tfidf = gene_tfidf.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding_tfidf = gene_tfidf.transform(test_df['Gene'])
cv_gene_feature_onehotCoding_tfidf = gene_tfidf.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_tfidf = TfidfVectorizer(max_features=1000)
train_variation_feature_onehotCoding_tfidf = variation_tfidf.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding_tfidf = variation_tfidf.transform(test_df['Variation'])
cv_variation_feature_onehotCoding_tfidf = variation_tfidf.transform(cv_df['Variation'])

# %%
# building a TfidfVectorizer with all the words that occured minimum 3 times in train data
text_tfidf = TfidfVectorizer(max_features=1000)
train_text_feature_onehotCoding_tfidf = text_tfidf.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features_tfidf= text_tfidf.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts_tfidf = train_text_feature_onehotCoding_tfidf.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict_tfidf = dict(zip(list(train_text_features_tfidf),train_text_fea_counts_tfidf))


print("Total number of unique words in train data :", len(train_text_features_tfidf))
print('shape of train_text_feature_onehotCoding_tfidf ',train_text_feature_onehotCoding_tfidf.shape)
# Out:
# Total number of unique words in train data : 1000
# shape of train_text_feature_onehotCoding_tfidf  (2124, 1000)

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding_tfidf = normalize(train_text_feature_onehotCoding_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_tfidf = text_tfidf.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_tfidf = normalize(test_text_feature_onehotCoding_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_tfidf = text_tfidf.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_tfidf = normalize(cv_text_feature_onehotCoding_tfidf, axis=0)

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding_tfidf = hstack((train_gene_feature_onehotCoding_tfidf,train_variation_feature_onehotCoding_tfidf))
test_gene_var_onehotCoding_tfidf = hstack((test_gene_feature_onehotCoding_tfidf,test_variation_feature_onehotCoding_tfidf))
cv_gene_var_onehotCoding_tfidf = hstack((cv_gene_feature_onehotCoding_tfidf,cv_variation_feature_onehotCoding_tfidf))

train_x_onehotCoding_tfidf = hstack((train_gene_var_onehotCoding_tfidf, train_text_feature_onehotCoding_tfidf)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding_tfidf = hstack((test_gene_var_onehotCoding_tfidf, test_text_feature_onehotCoding_tfidf)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding_tfidf = hstack((cv_gene_var_onehotCoding_tfidf, cv_text_feature_onehotCoding_tfidf)).tocsr()
cv_y = np.array(list(cv_df['Class']))


print("One hot encoding features with tfidf:")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding_tfidf.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding_tfidf.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding_tfidf.shape)
# Out:
# One hot encoding features with tfidf:
# (number of data points * number of features) in train data =  (2124, 2230)
# (number of data points * number of features) in test data =  (665, 2230)
# (number of data points * number of features) in cross validation data = (532, 2230)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1860557537891498
# for alpha = 0.0001
# Log Loss : 1.1850726978393962
# for alpha = 0.001
# Log Loss : 1.182863224384022
# for alpha = 0.1
# Log Loss : 1.2006942049837086
# for alpha = 1
# Log Loss : 1.226247827517138
# for alpha = 10
# Log Loss : 1.3889542937608472
# for alpha = 100
# Log Loss : 1.4100826643776976
# for alpha = 1000
# Log Loss : 1.410955615462826
# For values of best alpha =  0.001 The train log loss is: 0.7519780146841085
# For values of best alpha =  0.001 The cross validation log loss is: 1.182863224384022
# For values of best alpha =  0.001 The test log loss is: 1.1930409467204723

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding_tfidf)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding_tfidf.toarray()))
# Out:
# Log Loss : 1.182863224384022
# Number of missclassified point : 0.38533834586466165
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0602 0.0464 0.0132 0.062  0.0388 0.7043 0.069  0.0034 0.0026]]
# Actual Class : 6
# --------------------------------------------------
# 6 Text feature [odds] present in test data point [True]
# 7 Text feature [brca] present in test data point [True]
# 8 Text feature [57] present in test data point [True]
# 9 Text feature [deleterious] present in test data point [True]
# 10 Text feature [basis] present in test data point [True]
# 11 Text feature [classified] present in test data point [True]
# 12 Text feature [history] present in test data point [True]
# 14 Text feature [combined] present in test data point [True]
# 16 Text feature [family] present in test data point [True]
# 17 Text feature [brca1] present in test data point [True]
# 18 Text feature [43] present in test data point [True]
# 19 Text feature [sequence] present in test data point [True]
# 20 Text feature [predicted] present in test data point [True]
# 21 Text feature [expected] present in test data point [True]
# 22 Text feature [evidence] present in test data point [True]
# 23 Text feature [26] present in test data point [True]
# 24 Text feature [brca2] present in test data point [True]
# 26 Text feature [models] present in test data point [True]
# 27 Text feature [model] present in test data point [True]
# 28 Text feature [23] present in test data point [True]
# 29 Text feature [given] present in test data point [True]
# 30 Text feature [substitutions] present in test data point [True]
# 31 Text feature [known] present in test data point [True]
# 32 Text feature [testing] present in test data point [True]
# 33 Text feature [likely] present in test data point [True]
# 34 Text feature [000] present in test data point [True]
# 37 Text feature [variant] present in test data point [True]
# 39 Text feature [42] present in test data point [True]
# 40 Text feature [41] present in test data point [True]
# 42 Text feature [neutral] present in test data point [True]
# 44 Text feature [variants] present in test data point [True]
# 46 Text feature [34] present in test data point [True]
# 47 Text feature [used] present in test data point [True]
# 50 Text feature [data] present in test data point [True]
# 51 Text feature [use] present in test data point [True]
# 53 Text feature [site] present in test data point [True]
# 55 Text feature [35] present in test data point [True]
# 56 Text feature [56] present in test data point [True]
# 57 Text feature [would] present in test data point [True]
# 59 Text feature [significant] present in test data point [True]
# 60 Text feature [tables] present in test data point [True]
# 61 Text feature [25] present in test data point [True]
# 62 Text feature [ring] present in test data point [True]
# 63 Text feature [significance] present in test data point [True]
# 64 Text feature [70] present in test data point [True]
# 66 Text feature [conserved] present in test data point [True]
# 68 Text feature [50] present in test data point [True]
# 69 Text feature [missense] present in test data point [True]
# 71 Text feature [least] present in test data point [True]
# 72 Text feature [approach] present in test data point [True]
# 73 Text feature [although] present in test data point [True]
# 76 Text feature [28] present in test data point [True]
# 77 Text feature [studied] present in test data point [True]
# 78 Text feature [16] present in test data point [True]
# 80 Text feature [majority] present in test data point [True]
# 81 Text feature [individuals] present in test data point [True]
# 82 Text feature [number] present in test data point [True]
# 83 Text feature [overall] present in test data point [True]
# 84 Text feature [three] present in test data point [True]
# 86 Text feature [thus] present in test data point [True]
# 87 Text feature [many] present in test data point [True]
# 88 Text feature [information] present in test data point [True]
# 89 Text feature [54] present in test data point [True]
# 90 Text feature [domains] present in test data point [True]
# 92 Text feature [population] present in test data point [True]
# 93 Text feature [analysis] present in test data point [True]
# 95 Text feature [vus] present in test data point [True]
# 97 Text feature [available] present in test data point [True]
# 98 Text feature [ovarian] present in test data point [True]
# 99 Text feature [29] present in test data point [True]
# Out of the top  100  features  70 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0602 0.0527 0.0133 0.0624 0.0373 0.0347 0.7332 0.0035 0.0026]]
# Actual Class : 7
# --------------------------------------------------
# 16 Text feature [activation] present in test data point [True]
# 18 Text feature [activated] present in test data point [True]
# 21 Text feature [cells] present in test data point [True]
# 22 Text feature [downstream] present in test data point [True]
# 23 Text feature [independent] present in test data point [True]
# 24 Text feature [inhibitor] present in test data point [True]
# 25 Text feature [expressing] present in test data point [True]
# 26 Text feature [growth] present in test data point [True]
# 27 Text feature [contrast] present in test data point [True]
# 28 Text feature [constitutive] present in test data point [True]
# 29 Text feature [phosphorylation] present in test data point [True]
# 30 Text feature [also] present in test data point [True]
# 32 Text feature [signaling] present in test data point [True]
# 33 Text feature [shown] present in test data point [True]
# 34 Text feature [presence] present in test data point [True]
# 35 Text feature [10] present in test data point [True]
# 36 Text feature [factor] present in test data point [True]
# 37 Text feature [however] present in test data point [True]
# 38 Text feature [cell] present in test data point [True]
# 39 Text feature [oncogenic] present in test data point [True]
# 40 Text feature [addition] present in test data point [True]
# 41 Text feature [well] present in test data point [True]
# 42 Text feature [sensitive] present in test data point [True]
# 43 Text feature [inhibitors] present in test data point [True]
# 44 Text feature [activate] present in test data point [True]
# 45 Text feature [higher] present in test data point [True]
# 46 Text feature [mutations] present in test data point [True]
# 47 Text feature [inhibition] present in test data point [True]
# 48 Text feature [treated] present in test data point [True]
# 49 Text feature [potential] present in test data point [True]
# 50 Text feature [compared] present in test data point [True]
# 52 Text feature [similar] present in test data point [True]
# 53 Text feature [increased] present in test data point [True]
# 54 Text feature [activating] present in test data point [True]
# 55 Text feature [constitutively] present in test data point [True]
# 56 Text feature [showed] present in test data point [True]
# 57 Text feature [treatment] present in test data point [True]
# 58 Text feature [recently] present in test data point [True]
# 60 Text feature [may] present in test data point [True]
# 61 Text feature [found] present in test data point [True]
# 63 Text feature [suggest] present in test data point [True]
# 64 Text feature [without] present in test data point [True]
# 65 Text feature [enhanced] present in test data point [True]
# 66 Text feature [concentrations] present in test data point [True]
# 67 Text feature [although] present in test data point [True]
# 68 Text feature [pathways] present in test data point [True]
# 69 Text feature [two] present in test data point [True]
# 70 Text feature [various] present in test data point [True]
# 71 Text feature [results] present in test data point [True]
# 72 Text feature [total] present in test data point [True]
# 73 Text feature [inhibited] present in test data point [True]
# 74 Text feature [12] present in test data point [True]
# 75 Text feature [mutant] present in test data point [True]
# 76 Text feature [different] present in test data point [True]
# 77 Text feature [studies] present in test data point [True]
# 78 Text feature [reported] present in test data point [True]
# 79 Text feature [mutation] present in test data point [True]
# 80 Text feature [24] present in test data point [True]
# 81 Text feature [proliferation] present in test data point [True]
# 82 Text feature [13] present in test data point [True]
# 83 Text feature [absence] present in test data point [True]
# 84 Text feature [consistent] present in test data point [True]
# 85 Text feature [followed] present in test data point [True]
# 86 Text feature [using] present in test data point [True]
# 87 Text feature [described] present in test data point [True]
# 88 Text feature [3b] present in test data point [True]
# 89 Text feature [figure] present in test data point [True]
# 90 Text feature [mechanism] present in test data point [True]
# 91 Text feature [3a] present in test data point [True]
# 92 Text feature [three] present in test data point [True]
# 93 Text feature [discussion] present in test data point [True]
# 94 Text feature [observed] present in test data point [True]
# 95 Text feature [15] present in test data point [True]
# 96 Text feature [pathway] present in test data point [True]
# 97 Text feature [identified] present in test data point [True]
# 98 Text feature [receptor] present in test data point [True]
# 99 Text feature [20] present in test data point [True]
# Out of the top  100  features  77 are present in query point

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.170709553326202
# for alpha = 1e-05
# Log Loss : 1.046396611245673
# for alpha = 0.0001
# Log Loss : 1.0142366028007295
# for alpha = 0.001
# Log Loss : 1.050071482090845
# for alpha = 0.01
# Log Loss : 1.2208675385004515
# for alpha = 0.1
# Log Loss : 1.6224594014261404
# for alpha = 1
# Log Loss : 1.7638066851687266
# for alpha = 10
# Log Loss : 1.7810387994485435
# for alpha = 100
# Log Loss : 1.7830791185756045
# For values of best alpha =  0.0001 The train log loss is: 0.5692246894342055
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0142366028007295
# For values of best alpha =  0.0001 The test log loss is: 1.0557863821920808

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y, cv_x_onehotCoding_tfidf, cv_y, clf)
# Out:
# Log loss : 1.0142366028007295
# Number of mis-classified points : 0.34774436090225563
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding_tfidf.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0525 0.014  0.0031 0.012  0.1805 0.7325 0.0028 0.0017 0.001 ]]
# Actual Class : 6
# --------------------------------------------------
# 58 Text feature [considered] present in test data point [True]
# 76 Text feature [basis] present in test data point [True]
# 79 Text feature [significant] present in test data point [True]
# 91 Text feature [showing] present in test data point [True]
# 92 Text feature [site] present in test data point [True]
# 98 Text feature [42] present in test data point [True]
# 99 Text feature [ring] present in test data point [True]
# 101 Text feature [expected] present in test data point [True]
# 105 Text feature [reduction] present in test data point [True]
# 109 Text feature [brca] present in test data point [True]
# 114 Text feature [odds] present in test data point [True]
# 115 Text feature [enzyme] present in test data point [True]
# 118 Text feature [observation] present in test data point [True]
# 123 Text feature [substitutions] present in test data point [True]
# 126 Text feature [000] present in test data point [True]
# 130 Text feature [confer] present in test data point [True]
# 134 Text feature [frequent] present in test data point [True]
# 141 Text feature [individuals] present in test data point [True]
# 144 Text feature [43] present in test data point [True]
# 148 Text feature [approach] present in test data point [True]
# 152 Text feature [evidence] present in test data point [True]
# 153 Text feature [clinically] present in test data point [True]
# 157 Text feature [predicted] present in test data point [True]
# 158 Text feature [history] present in test data point [True]
# 159 Text feature [57] present in test data point [True]
# 162 Text feature [stained] present in test data point [True]
# 169 Text feature [six] present in test data point [True]
# 178 Text feature [occurs] present in test data point [True]
# 188 Text feature [studied] present in test data point [True]
# 189 Text feature [deleterious] present in test data point [True]
# 192 Text feature [statistical] present in test data point [True]
# 193 Text feature [overall] present in test data point [True]
# 195 Text feature [loss] present in test data point [True]
# 198 Text feature [tables] present in test data point [True]
# 204 Text feature [five] present in test data point [True]
# 213 Text feature [state] present in test data point [True]
# 214 Text feature [status] present in test data point [True]
# 222 Text feature [given] present in test data point [True]
# 224 Text feature [identified] present in test data point [True]
# 225 Text feature [higher] present in test data point [True]
# 235 Text feature [models] present in test data point [True]
# 238 Text feature [acids] present in test data point [True]
# 239 Text feature [classified] present in test data point [True]
# 242 Text feature [therapeutic] present in test data point [True]
# 244 Text feature [population] present in test data point [True]
# 245 Text feature [time] present in test data point [True]
# 246 Text feature [34] present in test data point [True]
# 249 Text feature [staining] present in test data point [True]
# 252 Text feature [important] present in test data point [True]
# 254 Text feature [terminal] present in test data point [True]
# 262 Text feature [classification] present in test data point [True]
# 271 Text feature [frequently] present in test data point [True]
# 274 Text feature [family] present in test data point [True]
# 279 Text feature [lower] present in test data point [True]
# 280 Text feature [amino] present in test data point [True]
# 285 Text feature [including] present in test data point [True]
# 287 Text feature [type] present in test data point [True]
# 289 Text feature [least] present in test data point [True]
# 290 Text feature [following] present in test data point [True]
# 293 Text feature [multiple] present in test data point [True]
# 304 Text feature [group] present in test data point [True]
# 305 Text feature [difference] present in test data point [True]
# 309 Text feature [altered] present in test data point [True]
# 316 Text feature [reaction] present in test data point [True]
# 317 Text feature [23] present in test data point [True]
# 318 Text feature [prior] present in test data point [True]
# 321 Text feature [receptor] present in test data point [True]
# 323 Text feature [binding] present in test data point [True]
# 327 Text feature [20] present in test data point [True]
# 329 Text feature [methods] present in test data point [True]
# 333 Text feature [30] present in test data point [True]
# 334 Text feature [genomic] present in test data point [True]
# 336 Text feature [brca1] present in test data point [True]
# 337 Text feature [information] present in test data point [True]
# 339 Text feature [decrease] present in test data point [True]
# 341 Text feature [according] present in test data point [True]
# 345 Text feature [15] present in test data point [True]
# 346 Text feature [characteristics] present in test data point [True]
# 347 Text feature [affect] present in test data point [True]
# 348 Text feature [35] present in test data point [True]
# 349 Text feature [reports] present in test data point [True]
# 352 Text feature [often] present in test data point [True]
# 354 Text feature [variant] present in test data point [True]
# 355 Text feature [thus] present in test data point [True]
# 357 Text feature [acid] present in test data point [True]
# 358 Text feature [regions] present in test data point [True]
# 363 Text feature [18] present in test data point [True]
# 366 Text feature [significance] present in test data point [True]
# 368 Text feature [range] present in test data point [True]
# 370 Text feature [alleles] present in test data point [True]
# 372 Text feature [wild] present in test data point [True]
# 373 Text feature [domains] present in test data point [True]
# 376 Text feature [number] present in test data point [True]
# 378 Text feature [ovarian] present in test data point [True]
# 379 Text feature [allele] present in test data point [True]
# 380 Text feature [full] present in test data point [True]
# 386 Text feature [sequence] present in test data point [True]
# 391 Text feature [factor] present in test data point [True]
# 393 Text feature [frequency] present in test data point [True]
# 395 Text feature [conserved] present in test data point [True]
# 396 Text feature [confirm] present in test data point [True]
# 398 Text feature [therefore] present in test data point [True]
# 400 Text feature [discussion] present in test data point [True]
# 401 Text feature [shown] present in test data point [True]
# 403 Text feature [members] present in test data point [True]
# 406 Text feature [missense] present in test data point [True]
# 407 Text feature [approximately] present in test data point [True]
# 408 Text feature [25] present in test data point [True]
# 409 Text feature [17] present in test data point [True]
# 412 Text feature [56] present in test data point [True]
# 415 Text feature [calculated] present in test data point [True]
# 416 Text feature [breast] present in test data point [True]
# 420 Text feature [potential] present in test data point [True]
# 421 Text feature [reported] present in test data point [True]
# 425 Text feature [showed] present in test data point [True]
# 427 Text feature [identification] present in test data point [True]
# 428 Text feature [gel] present in test data point [True]
# 435 Text feature [first] present in test data point [True]
# 437 Text feature [10] present in test data point [True]
# 439 Text feature [controls] present in test data point [True]
# 441 Text feature [affected] present in test data point [True]
# 442 Text feature [41] present in test data point [True]
# 447 Text feature [studies] present in test data point [True]
# 448 Text feature [change] present in test data point [True]
# 449 Text feature [alterations] present in test data point [True]
# 450 Text feature [neutral] present in test data point [True]
# 452 Text feature [likely] present in test data point [True]
# 453 Text feature [isolated] present in test data point [True]
# 454 Text feature [age] present in test data point [True]
# 464 Text feature [combined] present in test data point [True]
# 467 Text feature [primer] present in test data point [True]
# 468 Text feature [factors] present in test data point [True]
# 470 Text feature [respectively] present in test data point [True]
# 472 Text feature [also] present in test data point [True]
# 474 Text feature [class] present in test data point [True]
# 476 Text feature [54] present in test data point [True]
# 477 Text feature [length] present in test data point [True]
# 478 Text feature [average] present in test data point [True]
# 482 Text feature [data] present in test data point [True]
# 489 Text feature [yet] present in test data point [True]
# 492 Text feature [go] present in test data point [True]
# 493 Text feature [negative] present in test data point [True]
# 495 Text feature [26] present in test data point [True]
# 496 Text feature [stage] present in test data point [True]
# 498 Text feature [model] present in test data point [True]
# 499 Text feature [may] present in test data point [True]
# Out of the top  500  features  146 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0316 0.0771 0.0095 0.0366 0.022  0.0216 0.7895 0.007  0.0052]]
# Actual Class : 7
# --------------------------------------------------
# 7 Text feature [downstream] present in test data point [True]
# 11 Text feature [oncogenic] present in test data point [True]
# 12 Text feature [enhanced] present in test data point [True]
# 15 Text feature [constitutive] present in test data point [True]
# 16 Text feature [activation] present in test data point [True]
# 21 Text feature [concentrations] present in test data point [True]
# 23 Text feature [oncogene] present in test data point [True]
# 34 Text feature [activate] present in test data point [True]
# 38 Text feature [regulated] present in test data point [True]
# 42 Text feature [pathways] present in test data point [True]
# 43 Text feature [lung] present in test data point [True]
# 55 Text feature [factor] present in test data point [True]
# 60 Text feature [inhibited] present in test data point [True]
# 80 Text feature [leads] present in test data point [True]
# 81 Text feature [3b] present in test data point [True]
# 85 Text feature [fold] present in test data point [True]
# 95 Text feature [expressing] present in test data point [True]
# 97 Text feature [sensitive] present in test data point [True]
# 101 Text feature [000] present in test data point [True]
# 104 Text feature [distinct] present in test data point [True]
# 105 Text feature [activated] present in test data point [True]
# 108 Text feature [epithelial] present in test data point [True]
# 111 Text feature [signaling] present in test data point [True]
# 122 Text feature [inhibitor] present in test data point [True]
# 135 Text feature [increased] present in test data point [True]
# 136 Text feature [blood] present in test data point [True]
# 147 Text feature [2002] present in test data point [True]
# 155 Text feature [overexpression] present in test data point [True]
# 157 Text feature [lead] present in test data point [True]
# 164 Text feature [cancers] present in test data point [True]
# 167 Text feature [frequent] present in test data point [True]
# 169 Text feature [various] present in test data point [True]
# 173 Text feature [adenocarcinoma] present in test data point [True]
# 176 Text feature [derived] present in test data point [True]
# 181 Text feature [leading] present in test data point [True]
# 196 Text feature [activating] present in test data point [True]
# 199 Text feature [presence] present in test data point [True]
# 201 Text feature [express] present in test data point [True]
# 202 Text feature [elevated] present in test data point [True]
# 210 Text feature [malignant] present in test data point [True]
# 221 Text feature [promoter] present in test data point [True]
# 224 Text feature [basal] present in test data point [True]
# 234 Text feature [sirna] present in test data point [True]
# 240 Text feature [promote] present in test data point [True]
# 244 Text feature [fig] present in test data point [True]
# 252 Text feature [cdna] present in test data point [True]
# 253 Text feature [total] present in test data point [True]
# 257 Text feature [conditions] present in test data point [True]
# 258 Text feature [somatic] present in test data point [True]
# 259 Text feature [increase] present in test data point [True]
# 261 Text feature [tissues] present in test data point [True]
# 262 Text feature [s3] present in test data point [True]
# 264 Text feature [org] present in test data point [True]
# 269 Text feature [download] present in test data point [True]
# 272 Text feature [materials] present in test data point [True]
# 274 Text feature [advanced] present in test data point [True]
# 275 Text feature [contrast] present in test data point [True]
# 281 Text feature [cells] present in test data point [True]
# 286 Text feature [nucleotide] present in test data point [True]
# 292 Text feature [2001] present in test data point [True]
# 293 Text feature [additional] present in test data point [True]
# 294 Text feature [factors] present in test data point [True]
# 299 Text feature [high] present in test data point [True]
# 303 Text feature [regions] present in test data point [True]
# 317 Text feature [approximately] present in test data point [True]
# 319 Text feature [phosphorylation] present in test data point [True]
# 325 Text feature [3a] present in test data point [True]
# 338 Text feature [molecular] present in test data point [True]
# 344 Text feature [occur] present in test data point [True]
# 356 Text feature [strongly] present in test data point [True]
# 368 Text feature [potent] present in test data point [True]
# 372 Text feature [suggest] present in test data point [True]
# 375 Text feature [lesions] present in test data point [True]
# 381 Text feature [2000] present in test data point [True]
# 387 Text feature [mutant] present in test data point [True]
# 388 Text feature [consistent] present in test data point [True]
# 389 Text feature [position] present in test data point [True]
# 391 Text feature [mechanisms] present in test data point [True]
# 394 Text feature [indicates] present in test data point [True]
# 398 Text feature [www] present in test data point [True]
# 407 Text feature [inhibition] present in test data point [True]
# 409 Text feature [14] present in test data point [True]
# 410 Text feature [contribute] present in test data point [True]
# 411 Text feature [positive] present in test data point [True]
# 412 Text feature [independent] present in test data point [True]
# 414 Text feature [spectrum] present in test data point [True]
# 418 Text feature [treated] present in test data point [True]
# 421 Text feature [caused] present in test data point [True]
# 424 Text feature [egfr] present in test data point [True]
# 425 Text feature [demonstrated] present in test data point [True]
# 428 Text feature [24] present in test data point [True]
# 430 Text feature [12] present in test data point [True]
# 437 Text feature [genomic] present in test data point [True]
# 440 Text feature [molecule] present in test data point [True]
# 443 Text feature [process] present in test data point [True]
# 446 Text feature [2003] present in test data point [True]
# 447 Text feature [signals] present in test data point [True]
# 449 Text feature [carcinoma] present in test data point [True]
# 450 Text feature [mutated] present in test data point [True]
# 453 Text feature [days] present in test data point [True]
# 464 Text feature [seen] present in test data point [True]
# 466 Text feature [sensitivity] present in test data point [True]
# 469 Text feature [growth] present in test data point [True]
# 472 Text feature [fact] present in test data point [True]
# 475 Text feature [corresponding] present in test data point [True]
# 476 Text feature [taken] present in test data point [True]
# 477 Text feature [inhibitory] present in test data point [True]
# 478 Text feature [given] present in test data point [True]
# 483 Text feature [transcription] present in test data point [True]
# 485 Text feature [constitutively] present in test data point [True]
# 488 Text feature [level] present in test data point [True]
# 490 Text feature [properties] present in test data point [True]
# 495 Text feature [early] present in test data point [True]
# 499 Text feature [coding] present in test data point [True]
# Out of the top  500  features  114 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1778156012588203
# for alpha = 1e-05
# Log Loss : 1.0782820166388736
# for alpha = 0.0001
# Log Loss : 1.0455163904335367
# for alpha = 0.001
# Log Loss : 1.118354394630404
# for alpha = 0.01
# Log Loss : 1.4033099520731935
# for alpha = 0.1
# Log Loss : 1.8776176224338883
# for alpha = 1
# Log Loss : 1.9402892232724607
# For values of best alpha =  0.0001 The train log loss is: 0.5624344279578267
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0455163904335367
# For values of best alpha =  0.0001 The test log loss is: 1.0779174153602806

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y, cv_x_onehotCoding_tfidf, cv_y, clf)
# Out:
# Log loss : 1.0455163904335367
# Number of mis-classified points : 0.35714285714285715
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[4.780e-02 1.370e-02 2.300e-03 1.290e-02 1.566e-01 7.617e-01 3.400e-03
#   1.100e-03 6.000e-04]]
# Actual Class : 6
# --------------------------------------------------
# 71 Text feature [considered] present in test data point [True]
# 76 Text feature [basis] present in test data point [True]
# 79 Text feature [significant] present in test data point [True]
# 89 Text feature [showing] present in test data point [True]
# 93 Text feature [site] present in test data point [True]
# 97 Text feature [ring] present in test data point [True]
# 98 Text feature [42] present in test data point [True]
# 100 Text feature [expected] present in test data point [True]
# 104 Text feature [brca] present in test data point [True]
# 106 Text feature [enzyme] present in test data point [True]
# 115 Text feature [substitutions] present in test data point [True]
# 117 Text feature [odds] present in test data point [True]
# 118 Text feature [reduction] present in test data point [True]
# 119 Text feature [confer] present in test data point [True]
# 125 Text feature [000] present in test data point [True]
# 127 Text feature [observation] present in test data point [True]
# 139 Text feature [57] present in test data point [True]
# 144 Text feature [43] present in test data point [True]
# 148 Text feature [frequent] present in test data point [True]
# 149 Text feature [evidence] present in test data point [True]
# 150 Text feature [individuals] present in test data point [True]
# 153 Text feature [approach] present in test data point [True]
# 156 Text feature [history] present in test data point [True]
# 157 Text feature [clinically] present in test data point [True]
# 160 Text feature [predicted] present in test data point [True]
# 173 Text feature [stained] present in test data point [True]
# 174 Text feature [deleterious] present in test data point [True]
# 176 Text feature [occurs] present in test data point [True]
# 182 Text feature [six] present in test data point [True]
# 184 Text feature [studied] present in test data point [True]
# 188 Text feature [state] present in test data point [True]
# 200 Text feature [overall] present in test data point [True]
# 203 Text feature [tables] present in test data point [True]
# 204 Text feature [loss] present in test data point [True]
# 209 Text feature [statistical] present in test data point [True]
# 211 Text feature [models] present in test data point [True]
# 214 Text feature [given] present in test data point [True]
# 215 Text feature [status] present in test data point [True]
# 222 Text feature [classified] present in test data point [True]
# 228 Text feature [five] present in test data point [True]
# 232 Text feature [34] present in test data point [True]
# 233 Text feature [therapeutic] present in test data point [True]
# 241 Text feature [time] present in test data point [True]
# 245 Text feature [higher] present in test data point [True]
# 247 Text feature [identified] present in test data point [True]
# 255 Text feature [population] present in test data point [True]
# 259 Text feature [staining] present in test data point [True]
# 260 Text feature [lower] present in test data point [True]
# 265 Text feature [family] present in test data point [True]
# 271 Text feature [frequently] present in test data point [True]
# 273 Text feature [acids] present in test data point [True]
# 276 Text feature [important] present in test data point [True]
# 285 Text feature [terminal] present in test data point [True]
# 292 Text feature [classification] present in test data point [True]
# 293 Text feature [group] present in test data point [True]
# 294 Text feature [23] present in test data point [True]
# 295 Text feature [reaction] present in test data point [True]
# 296 Text feature [type] present in test data point [True]
# 298 Text feature [including] present in test data point [True]
# 299 Text feature [least] present in test data point [True]
# 302 Text feature [following] present in test data point [True]
# 303 Text feature [decrease] present in test data point [True]
# 304 Text feature [amino] present in test data point [True]
# 306 Text feature [difference] present in test data point [True]
# 312 Text feature [multiple] present in test data point [True]
# 313 Text feature [binding] present in test data point [True]
# 315 Text feature [receptor] present in test data point [True]
# 316 Text feature [characteristics] present in test data point [True]
# 318 Text feature [prior] present in test data point [True]
# 323 Text feature [altered] present in test data point [True]
# 325 Text feature [30] present in test data point [True]
# 326 Text feature [20] present in test data point [True]
# 330 Text feature [genomic] present in test data point [True]
# 333 Text feature [35] present in test data point [True]
# 335 Text feature [brca1] present in test data point [True]
# 338 Text feature [affect] present in test data point [True]
# 343 Text feature [15] present in test data point [True]
# 345 Text feature [thus] present in test data point [True]
# 348 Text feature [significance] present in test data point [True]
# 349 Text feature [56] present in test data point [True]
# 351 Text feature [acid] present in test data point [True]
# 352 Text feature [ovarian] present in test data point [True]
# 355 Text feature [information] present in test data point [True]
# 360 Text feature [according] present in test data point [True]
# 361 Text feature [domains] present in test data point [True]
# 362 Text feature [18] present in test data point [True]
# 368 Text feature [alleles] present in test data point [True]
# 372 Text feature [regions] present in test data point [True]
# 374 Text feature [number] present in test data point [True]
# 375 Text feature [methods] present in test data point [True]
# 381 Text feature [calculated] present in test data point [True]
# 382 Text feature [factor] present in test data point [True]
# 384 Text feature [often] present in test data point [True]
# 385 Text feature [confirm] present in test data point [True]
# 388 Text feature [wild] present in test data point [True]
# 389 Text feature [missense] present in test data point [True]
# 390 Text feature [sequence] present in test data point [True]
# 394 Text feature [conserved] present in test data point [True]
# 396 Text feature [therefore] present in test data point [True]
# 397 Text feature [potential] present in test data point [True]
# 398 Text feature [17] present in test data point [True]
# 399 Text feature [reports] present in test data point [True]
# 401 Text feature [reported] present in test data point [True]
# 403 Text feature [allele] present in test data point [True]
# 404 Text feature [25] present in test data point [True]
# 406 Text feature [frequency] present in test data point [True]
# 407 Text feature [breast] present in test data point [True]
# 409 Text feature [41] present in test data point [True]
# 412 Text feature [range] present in test data point [True]
# 415 Text feature [full] present in test data point [True]
# 418 Text feature [members] present in test data point [True]
# 422 Text feature [identification] present in test data point [True]
# 423 Text feature [variant] present in test data point [True]
# 424 Text feature [change] present in test data point [True]
# 430 Text feature [likely] present in test data point [True]
# 431 Text feature [approximately] present in test data point [True]
# 436 Text feature [shown] present in test data point [True]
# 437 Text feature [gel] present in test data point [True]
# 441 Text feature [discussion] present in test data point [True]
# 442 Text feature [10] present in test data point [True]
# 443 Text feature [studies] present in test data point [True]
# 445 Text feature [isolated] present in test data point [True]
# 446 Text feature [54] present in test data point [True]
# 448 Text feature [age] present in test data point [True]
# 449 Text feature [first] present in test data point [True]
# 452 Text feature [showed] present in test data point [True]
# 454 Text feature [factors] present in test data point [True]
# 456 Text feature [26] present in test data point [True]
# 459 Text feature [primer] present in test data point [True]
# 460 Text feature [combined] present in test data point [True]
# 464 Text feature [neutral] present in test data point [True]
# 469 Text feature [yet] present in test data point [True]
# 472 Text feature [affected] present in test data point [True]
# 473 Text feature [alterations] present in test data point [True]
# 478 Text feature [go] present in test data point [True]
# 479 Text feature [stage] present in test data point [True]
# 480 Text feature [respectively] present in test data point [True]
# 483 Text feature [model] present in test data point [True]
# 484 Text feature [four] present in test data point [True]
# 485 Text feature [length] present in test data point [True]
# 488 Text feature [average] present in test data point [True]
# 490 Text feature [also] present in test data point [True]
# 495 Text feature [er] present in test data point [True]
# 498 Text feature [may] present in test data point [True]
# Out of the top  500  features  144 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0302 0.0806 0.0118 0.0332 0.0225 0.0217 0.7882 0.0063 0.0054]]
# Actual Class : 7
# --------------------------------------------------
# 5 Text feature [downstream] present in test data point [True]
# 10 Text feature [enhanced] present in test data point [True]
# 11 Text feature [concentrations] present in test data point [True]
# 18 Text feature [oncogenic] present in test data point [True]
# 23 Text feature [activation] present in test data point [True]
# 26 Text feature [oncogene] present in test data point [True]
# 30 Text feature [constitutive] present in test data point [True]
# 31 Text feature [regulated] present in test data point [True]
# 35 Text feature [activate] present in test data point [True]
# 38 Text feature [lung] present in test data point [True]
# 52 Text feature [factor] present in test data point [True]
# 54 Text feature [inhibited] present in test data point [True]
# 59 Text feature [pathways] present in test data point [True]
# 68 Text feature [3b] present in test data point [True]
# 77 Text feature [fold] present in test data point [True]
# 81 Text feature [leads] present in test data point [True]
# 87 Text feature [distinct] present in test data point [True]
# 89 Text feature [2002] present in test data point [True]
# 91 Text feature [sensitive] present in test data point [True]
# 102 Text feature [increased] present in test data point [True]
# 110 Text feature [000] present in test data point [True]
# 116 Text feature [expressing] present in test data point [True]
# 122 Text feature [epithelial] present in test data point [True]
# 126 Text feature [lead] present in test data point [True]
# 135 Text feature [adenocarcinoma] present in test data point [True]
# 136 Text feature [activating] present in test data point [True]
# 141 Text feature [blood] present in test data point [True]
# 142 Text feature [various] present in test data point [True]
# 159 Text feature [inhibitor] present in test data point [True]
# 160 Text feature [derived] present in test data point [True]
# 164 Text feature [signaling] present in test data point [True]
# 168 Text feature [activated] present in test data point [True]
# 170 Text feature [cancers] present in test data point [True]
# 180 Text feature [frequent] present in test data point [True]
# 181 Text feature [sirna] present in test data point [True]
# 184 Text feature [leading] present in test data point [True]
# 185 Text feature [overexpression] present in test data point [True]
# 187 Text feature [presence] present in test data point [True]
# 191 Text feature [regions] present in test data point [True]
# 192 Text feature [additional] present in test data point [True]
# 193 Text feature [elevated] present in test data point [True]
# 199 Text feature [increase] present in test data point [True]
# 210 Text feature [materials] present in test data point [True]
# 219 Text feature [tissues] present in test data point [True]
# 227 Text feature [org] present in test data point [True]
# 228 Text feature [fig] present in test data point [True]
# 235 Text feature [somatic] present in test data point [True]
# 239 Text feature [basal] present in test data point [True]
# 240 Text feature [2001] present in test data point [True]
# 245 Text feature [express] present in test data point [True]
# 246 Text feature [approximately] present in test data point [True]
# 249 Text feature [conditions] present in test data point [True]
# 251 Text feature [s3] present in test data point [True]
# 255 Text feature [high] present in test data point [True]
# 266 Text feature [malignant] present in test data point [True]
# 270 Text feature [consistent] present in test data point [True]
# 272 Text feature [lesions] present in test data point [True]
# 275 Text feature [download] present in test data point [True]
# 278 Text feature [contrast] present in test data point [True]
# 280 Text feature [indicates] present in test data point [True]
# 283 Text feature [factors] present in test data point [True]
# 289 Text feature [promote] present in test data point [True]
# 290 Text feature [2000] present in test data point [True]
# 291 Text feature [advanced] present in test data point [True]
# 293 Text feature [3a] present in test data point [True]
# 294 Text feature [cdna] present in test data point [True]
# 296 Text feature [nucleotide] present in test data point [True]
# 302 Text feature [cells] present in test data point [True]
# 303 Text feature [total] present in test data point [True]
# 304 Text feature [www] present in test data point [True]
# 305 Text feature [promoter] present in test data point [True]
# 308 Text feature [strongly] present in test data point [True]
# 317 Text feature [suggest] present in test data point [True]
# 322 Text feature [phosphorylation] present in test data point [True]
# 335 Text feature [spectrum] present in test data point [True]
# 338 Text feature [molecular] present in test data point [True]
# 346 Text feature [mutant] present in test data point [True]
# 353 Text feature [position] present in test data point [True]
# 355 Text feature [positive] present in test data point [True]
# 358 Text feature [occur] present in test data point [True]
# 365 Text feature [24] present in test data point [True]
# 375 Text feature [caused] present in test data point [True]
# 383 Text feature [treated] present in test data point [True]
# 389 Text feature [contribute] present in test data point [True]
# 391 Text feature [two] present in test data point [True]
# 392 Text feature [12] present in test data point [True]
# 394 Text feature [egfr] present in test data point [True]
# 395 Text feature [signals] present in test data point [True]
# 403 Text feature [process] present in test data point [True]
# 405 Text feature [2003] present in test data point [True]
# 418 Text feature [independent] present in test data point [True]
# 420 Text feature [taken] present in test data point [True]
# 421 Text feature [demonstrated] present in test data point [True]
# 426 Text feature [14] present in test data point [True]
# 428 Text feature [affecting] present in test data point [True]
# 435 Text feature [level] present in test data point [True]
# 438 Text feature [potent] present in test data point [True]
# 439 Text feature [sensitivity] present in test data point [True]
# 447 Text feature [motif] present in test data point [True]
# 448 Text feature [molecule] present in test data point [True]
# 449 Text feature [mechanisms] present in test data point [True]
# 452 Text feature [genomic] present in test data point [True]
# 455 Text feature [mutants] present in test data point [True]
# 458 Text feature [transcription] present in test data point [True]
# 460 Text feature [carcinoma] present in test data point [True]
# 462 Text feature [fact] present in test data point [True]
# 465 Text feature [seen] present in test data point [True]
# 473 Text feature [within] present in test data point [True]
# 475 Text feature [harboring] present in test data point [True]
# 476 Text feature [also] present in test data point [True]
# 479 Text feature [inhibitory] present in test data point [True]
# 480 Text feature [product] present in test data point [True]
# 481 Text feature [activity] present in test data point [True]
# 486 Text feature [days] present in test data point [True]
# 488 Text feature [statistical] present in test data point [True]
# 489 Text feature [sequencing] present in test data point [True]
# 490 Text feature [melanoma] present in test data point [True]
# 494 Text feature [sites] present in test data point [True]
# 497 Text feature [major] present in test data point [True]
# 499 Text feature [endogenous] present in test data point [True]
# Out of the top  500  features  120 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1201129909593608
# for C = 0.0001
# Log Loss : 1.1295051777884606
# for C = 0.001
# Log Loss : 1.129963995964713
# for C = 0.01
# Log Loss : 1.3568849971813906
# for C = 0.1
# Log Loss : 1.645202567341264
# for C = 1
# Log Loss : 1.7836253052202735
# for C = 10
# Log Loss : 1.7836251282939282
# for C = 100
# Log Loss : 1.7836251951752806
# For values of best alpha =  1e-05 The train log loss is: 0.6192484063653677
# For values of best alpha =  1e-05 The cross validation log loss is: 1.1201129909593608
# For values of best alpha =  1e-05 The test log loss is: 1.2210859966227512

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y,cv_x_onehotCoding_tfidf,cv_y, clf)
# Out:
# Log loss : 1.1201129909593608
# Number of mis-classified points : 0.35714285714285715
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding_tfidf,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0641 0.0828 0.0095 0.0533 0.2369 0.5083 0.0423 0.0016 0.0012]]
# Actual Class : 6
# --------------------------------------------------
# 49 Text feature [significant] present in test data point [True]
# 50 Text feature [clinically] present in test data point [True]
# 60 Text feature [overall] present in test data point [True]
# 61 Text feature [affected] present in test data point [True]
# 106 Text feature [reports] present in test data point [True]
# 108 Text feature [42] present in test data point [True]
# 114 Text feature [frequent] present in test data point [True]
# 116 Text feature [stained] present in test data point [True]
# 117 Text feature [occurs] present in test data point [True]
# 119 Text feature [considered] present in test data point [True]
# 121 Text feature [site] present in test data point [True]
# 123 Text feature [showing] present in test data point [True]
# 124 Text feature [reduction] present in test data point [True]
# 125 Text feature [basis] present in test data point [True]
# 132 Text feature [alleles] present in test data point [True]
# 135 Text feature [loss] present in test data point [True]
# 136 Text feature [acids] present in test data point [True]
# 137 Text feature [type] present in test data point [True]
# 139 Text feature [negative] present in test data point [True]
# 142 Text feature [six] present in test data point [True]
# 146 Text feature [five] present in test data point [True]
# 147 Text feature [range] present in test data point [True]
# 155 Text feature [observation] present in test data point [True]
# 157 Text feature [according] present in test data point [True]
# 158 Text feature [terminal] present in test data point [True]
# 161 Text feature [approximately] present in test data point [True]
# 162 Text feature [000] present in test data point [True]
# 164 Text feature [showed] present in test data point [True]
# 165 Text feature [amino] present in test data point [True]
# 171 Text feature [multiple] present in test data point [True]
# 173 Text feature [history] present in test data point [True]
# 174 Text feature [members] present in test data point [True]
# 176 Text feature [expected] present in test data point [True]
# 177 Text feature [altered] present in test data point [True]
# 180 Text feature [controls] present in test data point [True]
# 181 Text feature [statistical] present in test data point [True]
# 182 Text feature [acid] present in test data point [True]
# 183 Text feature [population] present in test data point [True]
# 185 Text feature [identified] present in test data point [True]
# 187 Text feature [wild] present in test data point [True]
# 192 Text feature [confer] present in test data point [True]
# 194 Text feature [sporadic] present in test data point [True]
# 197 Text feature [including] present in test data point [True]
# 200 Text feature [staining] present in test data point [True]
# 201 Text feature [35] present in test data point [True]
# 202 Text feature [breast] present in test data point [True]
# 203 Text feature [introduction] present in test data point [True]
# 261 Text feature [predicted] present in test data point [True]
# 262 Text feature [status] present in test data point [True]
# 263 Text feature [following] present in test data point [True]
# 269 Text feature [classification] present in test data point [True]
# 270 Text feature [average] present in test data point [True]
# 271 Text feature [stage] present in test data point [True]
# 277 Text feature [receptor] present in test data point [True]
# 287 Text feature [ring] present in test data point [True]
# 288 Text feature [important] present in test data point [True]
# 291 Text feature [least] present in test data point [True]
# 296 Text feature [full] present in test data point [True]
# 297 Text feature [first] present in test data point [True]
# 299 Text feature [studied] present in test data point [True]
# 302 Text feature [difference] present in test data point [True]
# 315 Text feature [shown] present in test data point [True]
# 316 Text feature [yet] present in test data point [True]
# 317 Text feature [evidence] present in test data point [True]
# 324 Text feature [time] present in test data point [True]
# 325 Text feature [20] present in test data point [True]
# 326 Text feature [prior] present in test data point [True]
# 327 Text feature [regions] present in test data point [True]
# 329 Text feature [discussion] present in test data point [True]
# 331 Text feature [individuals] present in test data point [True]
# 333 Text feature [43] present in test data point [True]
# 335 Text feature [brca] present in test data point [True]
# 337 Text feature [genomic] present in test data point [True]
# 338 Text feature [given] present in test data point [True]
# 339 Text feature [methods] present in test data point [True]
# 340 Text feature [able] present in test data point [True]
# 341 Text feature [classified] present in test data point [True]
# 342 Text feature [er] present in test data point [True]
# 345 Text feature [family] present in test data point [True]
# 347 Text feature [individual] present in test data point [True]
# 348 Text feature [gene] present in test data point [True]
# 350 Text feature [often] present in test data point [True]
# 351 Text feature [length] present in test data point [True]
# 353 Text feature [class] present in test data point [True]
# 356 Text feature [allele] present in test data point [True]
# 358 Text feature [information] present in test data point [True]
# 361 Text feature [enzyme] present in test data point [True]
# 364 Text feature [number] present in test data point [True]
# 365 Text feature [brca2] present in test data point [True]
# 366 Text feature [change] present in test data point [True]
# 368 Text feature [odds] present in test data point [True]
# 373 Text feature [sequence] present in test data point [True]
# 374 Text feature [conserved] present in test data point [True]
# 375 Text feature [gel] present in test data point [True]
# 376 Text feature [buffer] present in test data point [True]
# 377 Text feature [15] present in test data point [True]
# 379 Text feature [data] present in test data point [True]
# 383 Text feature [reaction] present in test data point [True]
# 384 Text feature [variant] present in test data point [True]
# 389 Text feature [characteristics] present in test data point [True]
# 391 Text feature [higher] present in test data point [True]
# 392 Text feature [primer] present in test data point [True]
# 402 Text feature [domains] present in test data point [True]
# 408 Text feature [significance] present in test data point [True]
# 409 Text feature [therapeutic] present in test data point [True]
# 410 Text feature [34] present in test data point [True]
# 411 Text feature [thus] present in test data point [True]
# 416 Text feature [binding] present in test data point [True]
# 419 Text feature [30] present in test data point [True]
# 422 Text feature [tables] present in test data point [True]
# 425 Text feature [affect] present in test data point [True]
# 428 Text feature [part] present in test data point [True]
# 431 Text feature [independent] present in test data point [True]
# 437 Text feature [normal] present in test data point [True]
# 442 Text feature [strong] present in test data point [True]
# 443 Text feature [identification] present in test data point [True]
# 444 Text feature [mutant] present in test data point [True]
# 448 Text feature [study] present in test data point [True]
# 450 Text feature [frequently] present in test data point [True]
# 455 Text feature [hours] present in test data point [True]
# 457 Text feature [approach] present in test data point [True]
# 460 Text feature [10] present in test data point [True]
# 462 Text feature [age] present in test data point [True]
# 463 Text feature [studies] present in test data point [True]
# 464 Text feature [isolated] present in test data point [True]
# 466 Text feature [deleterious] present in test data point [True]
# 467 Text feature [18] present in test data point [True]
# 468 Text feature [may] present in test data point [True]
# 471 Text feature [result] present in test data point [True]
# 477 Text feature [located] present in test data point [True]
# 481 Text feature [protein] present in test data point [True]
# 483 Text feature [57] present in test data point [True]
# 484 Text feature [factor] present in test data point [True]
# 485 Text feature [established] present in test data point [True]
# 486 Text feature [substitutions] present in test data point [True]
# 490 Text feature [previous] present in test data point [True]
# 491 Text feature [positive] present in test data point [True]
# 493 Text feature [confirm] present in test data point [True]
# 495 Text feature [41] present in test data point [True]
# 499 Text feature [numbers] present in test data point [True]
# Out of the top  500  features  140 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0578 0.1539 0.0144 0.0385 0.0564 0.031  0.6329 0.0086 0.0065]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [concentrations] present in test data point [True]
# 4 Text feature [enhanced] present in test data point [True]
# 5 Text feature [2002] present in test data point [True]
# 7 Text feature [regulated] present in test data point [True]
# 11 Text feature [lung] present in test data point [True]
# 13 Text feature [major] present in test data point [True]
# 25 Text feature [adenocarcinoma] present in test data point [True]
# 26 Text feature [3b] present in test data point [True]
# 28 Text feature [additional] present in test data point [True]
# 30 Text feature [downstream] present in test data point [True]
# 31 Text feature [2000] present in test data point [True]
# 36 Text feature [sirna] present in test data point [True]
# 38 Text feature [consistent] present in test data point [True]
# 40 Text feature [various] present in test data point [True]
# 63 Text feature [indicates] present in test data point [True]
# 65 Text feature [fold] present in test data point [True]
# 66 Text feature [oncogene] present in test data point [True]
# 71 Text feature [sensitivity] present in test data point [True]
# 73 Text feature [high] present in test data point [True]
# 74 Text feature [leads] present in test data point [True]
# 75 Text feature [antibodies] present in test data point [True]
# 76 Text feature [directly] present in test data point [True]
# 77 Text feature [activation] present in test data point [True]
# 82 Text feature [approximately] present in test data point [True]
# 83 Text feature [treated] present in test data point [True]
# 84 Text feature [sensitive] present in test data point [True]
# 85 Text feature [download] present in test data point [True]
# 87 Text feature [malignant] present in test data point [True]
# 89 Text feature [lesions] present in test data point [True]
# 91 Text feature [regions] present in test data point [True]
# 92 Text feature [3a] present in test data point [True]
# 93 Text feature [org] present in test data point [True]
# 94 Text feature [braf] present in test data point [True]
# 96 Text feature [distinct] present in test data point [True]
# 98 Text feature [harboring] present in test data point [True]
# 99 Text feature [factor] present in test data point [True]
# 100 Text feature [32] present in test data point [True]
# 102 Text feature [activated] present in test data point [True]
# 104 Text feature [express] present in test data point [True]
# 105 Text feature [pathways] present in test data point [True]
# 106 Text feature [egfr] present in test data point [True]
# 108 Text feature [demonstrated] present in test data point [True]
# 109 Text feature [inhibitory] present in test data point [True]
# 110 Text feature [motif] present in test data point [True]
# 112 Text feature [stage] present in test data point [True]
# 117 Text feature [increased] present in test data point [True]
# 119 Text feature [cancers] present in test data point [True]
# 174 Text feature [spectrum] present in test data point [True]
# 176 Text feature [expressing] present in test data point [True]
# 177 Text feature [materials] present in test data point [True]
# 178 Text feature [contrast] present in test data point [True]
# 179 Text feature [within] present in test data point [True]
# 180 Text feature [activate] present in test data point [True]
# 183 Text feature [derived] present in test data point [True]
# 184 Text feature [melanoma] present in test data point [True]
# 186 Text feature [presence] present in test data point [True]
# 188 Text feature [conditions] present in test data point [True]
# 190 Text feature [elevated] present in test data point [True]
# 192 Text feature [12] present in test data point [True]
# 193 Text feature [constitutive] present in test data point [True]
# 194 Text feature [40] present in test data point [True]
# 196 Text feature [two] present in test data point [True]
# 197 Text feature [affecting] present in test data point [True]
# 199 Text feature [nucleotide] present in test data point [True]
# 201 Text feature [progression] present in test data point [True]
# 202 Text feature [recently] present in test data point [True]
# 203 Text feature [respectively] present in test data point [True]
# 206 Text feature [ii] present in test data point [True]
# 207 Text feature [mediated] present in test data point [True]
# 208 Text feature [inhibited] present in test data point [True]
# 210 Text feature [flag] present in test data point [True]
# 212 Text feature [driven] present in test data point [True]
# 213 Text feature [mutation] present in test data point [True]
# 214 Text feature [chain] present in test data point [True]
# 216 Text feature [activating] present in test data point [True]
# 217 Text feature [fact] present in test data point [True]
# 218 Text feature [statistical] present in test data point [True]
# 220 Text feature [direct] present in test data point [True]
# 221 Text feature [furthermore] present in test data point [True]
# 222 Text feature [due] present in test data point [True]
# 223 Text feature [also] present in test data point [True]
# 224 Text feature [mg] present in test data point [True]
# 226 Text feature [basal] present in test data point [True]
# 227 Text feature [basis] present in test data point [True]
# 230 Text feature [epithelial] present in test data point [True]
# 231 Text feature [increase] present in test data point [True]
# 234 Text feature [11] present in test data point [True]
# 235 Text feature [chromosome] present in test data point [True]
# 236 Text feature [potent] present in test data point [True]
# 238 Text feature [endogenous] present in test data point [True]
# 239 Text feature [deletion] present in test data point [True]
# 241 Text feature [might] present in test data point [True]
# 242 Text feature [level] present in test data point [True]
# 244 Text feature [000] present in test data point [True]
# 245 Text feature [molecular] present in test data point [True]
# 246 Text feature [remains] present in test data point [True]
# 247 Text feature [specifically] present in test data point [True]
# 249 Text feature [oncogenic] present in test data point [True]
# 252 Text feature [shown] present in test data point [True]
# 254 Text feature [2007] present in test data point [True]
# 255 Text feature [50] present in test data point [True]
# 256 Text feature [tissues] present in test data point [True]
# 258 Text feature [suggest] present in test data point [True]
# 259 Text feature [cdna] present in test data point [True]
# 260 Text feature [observations] present in test data point [True]
# 262 Text feature [iii] present in test data point [True]
# 263 Text feature [inhibitor] present in test data point [True]
# 264 Text feature [http] present in test data point [True]
# 266 Text feature [mutants] present in test data point [True]
# 267 Text feature [leading] present in test data point [True]
# 270 Text feature [associated] present in test data point [True]
# 271 Text feature [process] present in test data point [True]
# 272 Text feature [carried] present in test data point [True]
# 273 Text feature [report] present in test data point [True]
# 274 Text feature [activity] present in test data point [True]
# 275 Text feature [factors] present in test data point [True]
# 277 Text feature [product] present in test data point [True]
# 278 Text feature [examined] present in test data point [True]
# 380 Text feature [affinity] present in test data point [True]
# 386 Text feature [determined] present in test data point [True]
# 389 Text feature [34] present in test data point [True]
# 390 Text feature [resistant] present in test data point [True]
# 392 Text feature [culture] present in test data point [True]
# 395 Text feature [disease] present in test data point [True]
# 397 Text feature [2003] present in test data point [True]
# 398 Text feature [signaling] present in test data point [True]
# 399 Text feature [either] present in test data point [True]
# 400 Text feature [one] present in test data point [True]
# 402 Text feature [taken] present in test data point [True]
# 403 Text feature [sequencing] present in test data point [True]
# 405 Text feature [published] present in test data point [True]
# 406 Text feature [decrease] present in test data point [True]
# 408 Text feature [cause] present in test data point [True]
# 411 Text feature [frequent] present in test data point [True]
# 413 Text feature [29] present in test data point [True]
# 414 Text feature [effect] present in test data point [True]
# 415 Text feature [transcription] present in test data point [True]
# 417 Text feature [2001] present in test data point [True]
# 420 Text feature [positive] present in test data point [True]
# 421 Text feature [blood] present in test data point [True]
# 423 Text feature [early] present in test data point [True]
# 424 Text feature [analysis] present in test data point [True]
# 425 Text feature [www] present in test data point [True]
# 426 Text feature [37] present in test data point [True]
# 428 Text feature [subjected] present in test data point [True]
# 431 Text feature [subunit] present in test data point [True]
# 433 Text feature [cells] present in test data point [True]
# 435 Text feature [contribute] present in test data point [True]
# 436 Text feature [trials] present in test data point [True]
# 437 Text feature [reporter] present in test data point [True]
# 438 Text feature [s3] present in test data point [True]
# 439 Text feature [specific] present in test data point [True]
# 442 Text feature [days] present in test data point [True]
# 443 Text feature [total] present in test data point [True]
# 444 Text feature [carrying] present in test data point [True]
# 447 Text feature [experiments] present in test data point [True]
# 448 Text feature [4a] present in test data point [True]
# 450 Text feature [form] present in test data point [True]
# 452 Text feature [somatic] present in test data point [True]
# 453 Text feature [part] present in test data point [True]
# 455 Text feature [cohort] present in test data point [True]
# 459 Text feature [sites] present in test data point [True]
# 465 Text feature [signals] present in test data point [True]
# 466 Text feature [kit] present in test data point [True]
# 469 Text feature [structure] present in test data point [True]
# 470 Text feature [data] present in test data point [True]
# 472 Text feature [caused] present in test data point [True]
# 476 Text feature [figures] present in test data point [True]
# 478 Text feature [purified] present in test data point [True]
# 479 Text feature [least] present in test data point [True]
# 483 Text feature [established] present in test data point [True]
# 485 Text feature [rna] present in test data point [True]
# 486 Text feature [mechanisms] present in test data point [True]
# 487 Text feature [signal] present in test data point [True]
# 488 Text feature [large] present in test data point [True]
# 489 Text feature [without] present in test data point [True]
# 491 Text feature [carcinoma] present in test data point [True]
# 492 Text feature [thus] present in test data point [True]
# 493 Text feature [contact] present in test data point [True]
# 498 Text feature [showed] present in test data point [True]
# 499 Text feature [negative] present in test data point [True]
# Out of the top  500  features  181 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding_tfidf, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.1898465207684417
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.240541064247387
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.1693804265594987
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2299969221091756
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.164581291767645
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2229942456422276
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.163475590436026
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2190301535395833
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1630641292932795
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.21868340388102
# For values of best estimator =  2000 The train log loss is: 0.8479626119983271
# For values of best estimator =  2000 The cross validation log loss is: 1.1630641292932795
# For values of best estimator =  2000 The test log loss is: 1.1954877840897815

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y,cv_x_onehotCoding_tfidf,cv_y, clf)
# Out:
# Log loss : 1.1630641292932793
# Number of mis-classified points : 0.40789473684210525
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0521 0.009  0.007  0.0276 0.1535 0.7338 0.0126 0.0025 0.002 ]]
# Actual Class : 6
# --------------------------------------------------
# 3 Text feature [function] present in test data point [True]
# 7 Text feature [missense] present in test data point [True]
# 10 Text feature [loss] present in test data point [True]
# 13 Text feature [protein] present in test data point [True]
# 14 Text feature [pathogenic] present in test data point [True]
# 15 Text feature [treatment] present in test data point [True]
# 18 Text feature [brca1] present in test data point [True]
# 20 Text feature [cells] present in test data point [True]
# 22 Text feature [receptor] present in test data point [True]
# 23 Text feature [variants] present in test data point [True]
# 25 Text feature [deleterious] present in test data point [True]
# 27 Text feature [growth] present in test data point [True]
# 28 Text feature [functional] present in test data point [True]
# 32 Text feature [therapeutic] present in test data point [True]
# 41 Text feature [classified] present in test data point [True]
# 44 Text feature [brca2] present in test data point [True]
# 45 Text feature [cell] present in test data point [True]
# 50 Text feature [patients] present in test data point [True]
# 51 Text feature [neutral] present in test data point [True]
# 53 Text feature [brca] present in test data point [True]
# 55 Text feature [57] present in test data point [True]
# 58 Text feature [ring] present in test data point [True]
# 59 Text feature [odds] present in test data point [True]
# 60 Text feature [treated] present in test data point [True]
# 65 Text feature [variant] present in test data point [True]
# 70 Text feature [ovarian] present in test data point [True]
# 72 Text feature [predicted] present in test data point [True]
# 77 Text feature [clinical] present in test data point [True]
# 79 Text feature [dna] present in test data point [True]
# 85 Text feature [expected] present in test data point [True]
# 87 Text feature [binding] present in test data point [True]
# 90 Text feature [lines] present in test data point [True]
# 91 Text feature [affect] present in test data point [True]
# 94 Text feature [sensitivity] present in test data point [True]
# Out of the top  100  features  34 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1011 0.089  0.0211 0.1301 0.0504 0.0442 0.5515 0.0071 0.0057]]
# Actuall Class : 7
# --------------------------------------------------
# 1 Text feature [activating] present in test data point [True]
# 3 Text feature [function] present in test data point [True]
# 4 Text feature [activation] present in test data point [True]
# 5 Text feature [suppressor] present in test data point [True]
# 6 Text feature [inhibitors] present in test data point [True]
# 7 Text feature [missense] present in test data point [True]
# 8 Text feature [activated] present in test data point [True]
# 9 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [loss] present in test data point [True]
# 11 Text feature [constitutive] present in test data point [True]
# 12 Text feature [oncogenic] present in test data point [True]
# 13 Text feature [protein] present in test data point [True]
# 15 Text feature [treatment] present in test data point [True]
# 16 Text feature [inhibitor] present in test data point [True]
# 17 Text feature [signaling] present in test data point [True]
# 19 Text feature [constitutively] present in test data point [True]
# 20 Text feature [cells] present in test data point [True]
# 22 Text feature [receptor] present in test data point [True]
# 24 Text feature [therapy] present in test data point [True]
# 27 Text feature [growth] present in test data point [True]
# 28 Text feature [functional] present in test data point [True]
# 30 Text feature [stability] present in test data point [True]
# 32 Text feature [therapeutic] present in test data point [True]
# 35 Text feature [expression] present in test data point [True]
# 37 Text feature [activate] present in test data point [True]
# 39 Text feature [trials] present in test data point [True]
# 40 Text feature [downstream] present in test data point [True]
# 43 Text feature [inhibition] present in test data point [True]
# 45 Text feature [cell] present in test data point [True]
# 49 Text feature [oncogene] present in test data point [True]
# 50 Text feature [patients] present in test data point [True]
# 52 Text feature [efficacy] present in test data point [True]
# 54 Text feature [functions] present in test data point [True]
# 57 Text feature [proteins] present in test data point [True]
# 58 Text feature [ring] present in test data point [True]
# 60 Text feature [treated] present in test data point [True]
# 61 Text feature [advanced] present in test data point [True]
# 63 Text feature [null] present in test data point [True]
# 66 Text feature [repair] present in test data point [True]
# 68 Text feature [response] present in test data point [True]
# 70 Text feature [ovarian] present in test data point [True]
# 71 Text feature [drug] present in test data point [True]
# 72 Text feature [predicted] present in test data point [True]
# 74 Text feature [inhibited] present in test data point [True]
# 75 Text feature [resistance] present in test data point [True]
# 76 Text feature [p53] present in test data point [True]
# 77 Text feature [clinical] present in test data point [True]
# 79 Text feature [dna] present in test data point [True]
# 80 Text feature [proliferation] present in test data point [True]
# 81 Text feature [tagged] present in test data point [True]
# 83 Text feature [mammalian] present in test data point [True]
# 86 Text feature [activity] present in test data point [True]
# 87 Text feature [binding] present in test data point [True]
# 89 Text feature [survival] present in test data point [True]
# 90 Text feature [lines] present in test data point [True]
# 91 Text feature [affect] present in test data point [True]
# 94 Text feature [sensitivity] present in test data point [True]
# 96 Text feature [nsclc] present in test data point [True]
# 98 Text feature [stimulation] present in test data point [True]
# Out of the top  100  features  59 are present in query point

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding_tfidf, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding_tfidf))))
sig_clf2.fit(train_x_onehotCoding_tfidf, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding_tfidf))))
sig_clf3.fit(train_x_onehotCoding_tfidf, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding_tfidf))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding_tfidf, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding_tfidf))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding_tfidf))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.05
# Support vector machines : Log Loss: 1.78
# Naive Bayes : Log Loss: 1.18
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.040
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.528
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.159
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.178
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.279

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding_tfidf, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding_tfidf))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding_tfidf))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding_tfidf))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding_tfidf))
# Out:
# Log loss (train) on the stacking classifier : 0.8090045733514492
# Log loss (CV) on the stacking classifier : 1.1591803952156203
# Log loss (test) on the stacking classifier : 1.1511310930483203
# Number of missclassified point : 0.3804511278195489
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding_tfidf, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding_tfidf)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding_tfidf)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding_tfidf)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding_tfidf))
# Out:
# Log loss (train) on the VotingClassifier : 0.956266024493583
# Log loss (CV) on the VotingClassifier : 1.184154596927351
# Log loss (test) on the VotingClassifier : 1.1940225827125355
# Number of missclassified point : 0.37894736842105264
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Assignment part2
# <li>Apply Logistic regression with CountVectorizer Features, including both unigrams and bigrams</li>
# <li> Try any of the feature engineering techniques discussed in the course to reduce the CV and test log-loss to a value less than 1.0</li>

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
from sklearn.feature_extraction.text import CountVectorizer
def get_impfeature_names_lr(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer(max_features=1000,ngram_range=(1,2))
    var_count_vec = CountVectorizer(max_features=1000,ngram_range=(1,2))
    text_count_vec = CountVectorizer(max_features=1000,min_df=3,ngram_range=(1,2))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
# one-hot encoding of Gene feature.
gene_lr_bi = CountVectorizer(max_features=1000,ngram_range=(1,2))
train_gene_feature_onehotCoding_lr_bi = gene_lr_bi.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding_lr_bi = gene_lr_bi.transform(test_df['Gene'])
cv_gene_feature_onehotCoding_lr_bi = gene_lr_bi.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_lr_bi = CountVectorizer(max_features=1000,ngram_range=(1,2))
train_variation_feature_onehotCoding_lr_bi = variation_lr_bi.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding_lr_bi = variation_lr_bi.transform(test_df['Variation'])
cv_variation_feature_onehotCoding_lr_bi = variation_lr_bi.transform(cv_df['Variation'])

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_lr_bi = CountVectorizer(max_features=1000,ngram_range=(1,2),min_df=3)
train_text_feature_onehotCoding_lr_bi = text_lr_bi.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features_lr_bi= text_lr_bi.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts_lr_bi = train_text_feature_onehotCoding_lr_bi.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict_lr_bi = dict(zip(list(train_text_features_lr_bi),train_text_fea_counts_lr_bi))


print("Total number of unique words in train data :", len(train_text_features_lr_bi))
# Out:
# Total number of unique words in train data : 1000

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding_lr_bi = normalize(train_text_feature_onehotCoding_lr_bi, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_lr_bi = text_lr_bi.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_lr_bi = normalize(test_text_feature_onehotCoding_lr_bi, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_lr_bi = text_lr_bi.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_lr_bi = normalize(cv_text_feature_onehotCoding_lr_bi, axis=0)

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding_lr_bi = hstack((train_gene_feature_onehotCoding_lr_bi,train_variation_feature_onehotCoding_lr_bi))
test_gene_var_onehotCoding_lr_bi = hstack((test_gene_feature_onehotCoding_lr_bi,test_variation_feature_onehotCoding_lr_bi))
cv_gene_var_onehotCoding_lr_bi = hstack((cv_gene_feature_onehotCoding_lr_bi,cv_variation_feature_onehotCoding_lr_bi))

train_x_onehotCoding_lr_bi = hstack((train_gene_var_onehotCoding_lr_bi, train_text_feature_onehotCoding_lr_bi)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding_lr_bi = hstack((test_gene_var_onehotCoding_lr_bi, test_text_feature_onehotCoding_lr_bi)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding_lr_bi = hstack((cv_gene_var_onehotCoding_lr_bi, cv_text_feature_onehotCoding_lr_bi)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features with uni and bigrams:")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding_lr_bi.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding_lr_bi.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding_lr_bi.shape)
# Out:
# One hot encoding features with uni and bigrams:
# (number of data points * number of features) in train data =  (2124, 2230)
# (number of data points * number of features) in test data =  (665, 2230)
# (number of data points * number of features) in cross validation data = (532, 2230)

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha_lr_bi = [10 ** x for x in range(-6, 3)]
cv_log_error_array_lr_bi = []
for i in alpha_lr_bi:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
    cv_log_error_array_lr_bi.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha_lr_bi, cv_log_error_array_lr_bi,c='g')
for i, txt in enumerate(np.round(cv_log_error_array_lr_bi,3)):
    ax.annotate((alpha_lr_bi[i],str(txt)), (alpha_lr_bi[i],cv_log_error_array_lr_bi[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha_lr_bi = np.argmin(cv_log_error_array_lr_bi)
clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_lr_bi)
print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_lr_bi)
print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1560306718835371
# for alpha = 1e-05
# Log Loss : 1.0480433953183141
# for alpha = 0.0001
# Log Loss : 1.0302722840916507
# for alpha = 0.001
# Log Loss : 1.0740086792293768
# for alpha = 0.01
# Log Loss : 1.2974510603274767
# for alpha = 0.1
# Log Loss : 1.694003278766973
# for alpha = 1
# Log Loss : 1.7497135530148722
# for alpha = 10
# Log Loss : 1.755797822562387
# for alpha = 100
# Log Loss : 1.7564672457482706
# For values of best alpha =  0.0001 The train log loss is: 0.5693190514231191
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0317249731495757
# For values of best alpha =  0.0001 The test log loss is: 1.0735489186762666

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_lr_bi, train_y, cv_x_onehotCoding_lr_bi, cv_y, clf)
# Out:
# Log loss : 1.0302722840916507
# Number of mis-classified points : 0.35902255639097747
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names_lr_bi(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding_lr_bi.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0859 0.0154 0.0055 0.0226 0.2247 0.6319 0.0095 0.0026 0.0018]]
# Actual Class : 6
# --------------------------------------------------
# 77 Text feature [basis] present in test data point [True]
# 80 Text feature [showing] present in test data point [True]
# 89 Text feature [enzyme] present in test data point [True]
# 98 Text feature [42] present in test data point [True]
# 101 Text feature [site] present in test data point [True]
# 105 Text feature [ring] present in test data point [True]
# 107 Text feature [confer] present in test data point [True]
# 111 Text feature [expected] present in test data point [True]
# 117 Text feature [significant] present in test data point [True]
# 132 Text feature [observation] present in test data point [True]
# 138 Text feature [000] present in test data point [True]
# 155 Text feature [history] present in test data point [True]
# 167 Text feature [staining] present in test data point [True]
# 168 Text feature [evidence] present in test data point [True]
# 182 Text feature [state] present in test data point [True]
# 186 Text feature [43] present in test data point [True]
# 200 Text feature [population] present in test data point [True]
# 203 Text feature [following] present in test data point [True]
# 206 Text feature [statistical] present in test data point [True]
# 208 Text feature [loss] present in test data point [True]
# 213 Text feature [multiple] present in test data point [True]
# 215 Text feature [considered] present in test data point [True]
# 220 Text feature [substitutions] present in test data point [True]
# 231 Text feature [terminal] present in test data point [True]
# 238 Text feature [alleles] present in test data point [True]
# 239 Text feature [family] present in test data point [True]
# 246 Text feature [overall] present in test data point [True]
# 248 Text feature [six] present in test data point [True]
# 252 Text feature [reduction] present in test data point [True]
# 258 Text feature [frequent] present in test data point [True]
# 261 Text feature [domains] present in test data point [True]
# 263 Text feature [binding] present in test data point [True]
# 265 Text feature [34] present in test data point [True]
# 267 Text feature [predicted] present in test data point [True]
# 271 Text feature [including] present in test data point [True]
# 274 Text feature [unique] present in test data point [True]
# 279 Text feature [time] present in test data point [True]
# 280 Text feature [least] present in test data point [True]
# 285 Text feature [brca] present in test data point [True]
# 288 Text feature [frequently] present in test data point [True]
# 291 Text feature [number] present in test data point [True]
# 293 Text feature [breast] present in test data point [True]
# 294 Text feature [lower] present in test data point [True]
# 295 Text feature [identified] present in test data point [True]
# 300 Text feature [higher] present in test data point [True]
# 303 Text feature [information] present in test data point [True]
# 308 Text feature [affected] present in test data point [True]
# 310 Text feature [receptor] present in test data point [True]
# 314 Text feature [frequency] present in test data point [True]
# 315 Text feature [thus] present in test data point [True]
# 317 Text feature [individuals] present in test data point [True]
# 326 Text feature [important] present in test data point [True]
# 327 Text feature [difference] present in test data point [True]
# 329 Text feature [full] present in test data point [True]
# 330 Text feature [members] present in test data point [True]
# 333 Text feature [therapeutic] present in test data point [True]
# 335 Text feature [given] present in test data point [True]
# 340 Text feature [conserved] present in test data point [True]
# 341 Text feature [class] present in test data point [True]
# 343 Text feature [classification] present in test data point [True]
# 345 Text feature [first] present in test data point [True]
# 347 Text feature [negative] present in test data point [True]
# 355 Text feature [shown] present in test data point [True]
# 357 Text feature [affect] present in test data point [True]
# 358 Text feature [35] present in test data point [True]
# 362 Text feature [status] present in test data point [True]
# 363 Text feature [group] present in test data point [True]
# 364 Text feature [type] present in test data point [True]
# 366 Text feature [five] present in test data point [True]
# 372 Text feature [factor] present in test data point [True]
# 377 Text feature [23] present in test data point [True]
# 385 Text feature [15] present in test data point [True]
# 386 Text feature [studied] present in test data point [True]
# 390 Text feature [age] present in test data point [True]
# 393 Text feature [range] present in test data point [True]
# 396 Text feature [brca1] present in test data point [True]
# 398 Text feature [allele] present in test data point [True]
# 404 Text feature [20] present in test data point [True]
# 405 Text feature [factors] present in test data point [True]
# 407 Text feature [18] present in test data point [True]
# 410 Text feature [reported] present in test data point [True]
# 412 Text feature [length] present in test data point [True]
# 417 Text feature [therefore] present in test data point [True]
# 422 Text feature [acids] present in test data point [True]
# 424 Text feature [average] present in test data point [True]
# 425 Text feature [introduction] present in test data point [True]
# 426 Text feature [yet] present in test data point [True]
# 427 Text feature [also] present in test data point [True]
# 430 Text feature [wild] present in test data point [True]
# 432 Text feature [26] present in test data point [True]
# 434 Text feature [likely] present in test data point [True]
# 446 Text feature [deleterious] present in test data point [True]
# 447 Text feature [according] present in test data point [True]
# 452 Text feature [10] present in test data point [True]
# 454 Text feature [may] present in test data point [True]
# 455 Text feature [41] present in test data point [True]
# 456 Text feature [majority] present in test data point [True]
# 458 Text feature [approach] present in test data point [True]
# 459 Text feature [17] present in test data point [True]
# 463 Text feature [isolated] present in test data point [True]
# 464 Text feature [example] present in test data point [True]
# 468 Text feature [75] present in test data point [True]
# 472 Text feature [dna] present in test data point [True]
# 476 Text feature [70] present in test data point [True]
# 477 Text feature [altered] present in test data point [True]
# 485 Text feature [report] present in test data point [True]
# 488 Text feature [gene] present in test data point [True]
# 489 Text feature [reaction] present in test data point [True]
# 495 Text feature [genomic] present in test data point [True]
# Out of the top  500  features  109 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.018  0.0473 0.0042 0.0172 0.0062 0.0076 0.8965 0.0021 0.001 ]]
# Actual Class : 7
# --------------------------------------------------
# 9 Text feature [concentrations] present in test data point [True]
# 30 Text feature [constitutive] present in test data point [True]
# 34 Text feature [downstream] present in test data point [True]
# 41 Text feature [oncogene] present in test data point [True]
# 49 Text feature [enhanced] present in test data point [True]
# 65 Text feature [derived] present in test data point [True]
# 69 Text feature [pathways] present in test data point [True]
# 72 Text feature [fold] present in test data point [True]
# 74 Text feature [sensitive] present in test data point [True]
# 75 Text feature [regulated] present in test data point [True]
# 77 Text feature [somatic] present in test data point [True]
# 78 Text feature [cancers] present in test data point [True]
# 79 Text feature [s3] present in test data point [True]
# 83 Text feature [inhibited] present in test data point [True]
# 92 Text feature [constitutively] present in test data point [True]
# 93 Text feature [approximately] present in test data point [True]
# 95 Text feature [oncogenic] present in test data point [True]
# 96 Text feature [blood] present in test data point [True]
# 114 Text feature [nucleotide] present in test data point [True]
# 118 Text feature [prostate] present in test data point [True]
# 121 Text feature [inhibitor] present in test data point [True]
# 143 Text feature [3b] present in test data point [True]
# 146 Text feature [expressing] present in test data point [True]
# 150 Text feature [absence] present in test data point [True]
# 160 Text feature [malignant] present in test data point [True]
# 162 Text feature [activated] present in test data point [True]
# 166 Text feature [frequent] present in test data point [True]
# 176 Text feature [additional] present in test data point [True]
# 177 Text feature [contribute] present in test data point [True]
# 180 Text feature [basal] present in test data point [True]
# 189 Text feature [activation] present in test data point [True]
# 190 Text feature [egfr] present in test data point [True]
# 198 Text feature [promoter] present in test data point [True]
# 199 Text feature [amplified] present in test data point [True]
# 205 Text feature [distinct] present in test data point [True]
# 210 Text feature [carcinoma] present in test data point [True]
# 211 Text feature [elevated] present in test data point [True]
# 214 Text feature [day] present in test data point [True]
# 216 Text feature [lung] present in test data point [True]
# 219 Text feature [mutant] present in test data point [True]
# 226 Text feature [presence] present in test data point [True]
# 229 Text feature [molecular] present in test data point [True]
# 230 Text feature [high] present in test data point [True]
# 231 Text feature [treated] present in test data point [True]
# 236 Text feature [2002] present in test data point [True]
# 258 Text feature [sirna] present in test data point [True]
# 262 Text feature [12] present in test data point [True]
# 270 Text feature [lead] present in test data point [True]
# 275 Text feature [leading] present in test data point [True]
# 289 Text feature [properties] present in test data point [True]
# 296 Text feature [nrf2] present in test data point [True]
# 297 Text feature [transcription] present in test data point [True]
# 304 Text feature [factor] present in test data point [True]
# 309 Text feature [fig] present in test data point [True]
# 314 Text feature [activate] present in test data point [True]
# 315 Text feature [coding] present in test data point [True]
# 318 Text feature [1a] present in test data point [True]
# 324 Text feature [mutants] present in test data point [True]
# 327 Text feature [induction] present in test data point [True]
# 328 Text feature [3a] present in test data point [True]
# 329 Text feature [growth] present in test data point [True]
# 346 Text feature [overexpression] present in test data point [True]
# 352 Text feature [occur] present in test data point [True]
# 357 Text feature [regions] present in test data point [True]
# 359 Text feature [000] present in test data point [True]
# 362 Text feature [inhibition] present in test data point [True]
# 363 Text feature [conditions] present in test data point [True]
# 364 Text feature [leads] present in test data point [True]
# 365 Text feature [promote] present in test data point [True]
# 367 Text feature [materials] present in test data point [True]
# 368 Text feature [demonstrated] present in test data point [True]
# 369 Text feature [independent] present in test data point [True]
# 376 Text feature [mechanisms] present in test data point [True]
# 377 Text feature [suggest] present in test data point [True]
# 380 Text feature [evaluated] present in test data point [True]
# 381 Text feature [signaling] present in test data point [True]
# 387 Text feature [sensitivity] present in test data point [True]
# 391 Text feature [2003] present in test data point [True]
# 394 Text feature [adenocarcinoma] present in test data point [True]
# 395 Text feature [mutated] present in test data point [True]
# 396 Text feature [events] present in test data point [True]
# 399 Text feature [molecule] present in test data point [True]
# 400 Text feature [early] present in test data point [True]
# 401 Text feature [epithelial] present in test data point [True]
# 406 Text feature [increased] present in test data point [True]
# 414 Text feature [position] present in test data point [True]
# 416 Text feature [common] present in test data point [True]
# 417 Text feature [activating] present in test data point [True]
# 429 Text feature [led] present in test data point [True]
# 430 Text feature [recently] present in test data point [True]
# 431 Text feature [luciferase] present in test data point [True]
# 432 Text feature [cells] present in test data point [True]
# 434 Text feature [major] present in test data point [True]
# 436 Text feature [concentration] present in test data point [True]
# 437 Text feature [caused] present in test data point [True]
# 441 Text feature [activity] present in test data point [True]
# 442 Text feature [forms] present in test data point [True]
# 443 Text feature [consistent] present in test data point [True]
# 448 Text feature [4a] present in test data point [True]
# 451 Text feature [total] present in test data point [True]
# 457 Text feature [factors] present in test data point [True]
# 458 Text feature [tumors] present in test data point [True]
# 459 Text feature [2b] present in test data point [True]
# 463 Text feature [thus] present in test data point [True]
# 467 Text feature [increase] present in test data point [True]
# 468 Text feature [progression] present in test data point [True]
# 470 Text feature [showed] present in test data point [True]
# 471 Text feature [2000] present in test data point [True]
# 478 Text feature [tissues] present in test data point [True]
# 480 Text feature [respectively] present in test data point [True]
# 481 Text feature [target] present in test data point [True]
# 482 Text feature [treatment] present in test data point [True]
# 483 Text feature [without] present in test data point [True]
# 484 Text feature [various] present in test data point [True]
# 489 Text feature [two] present in test data point [True]
# 490 Text feature [effect] present in test data point [True]
# 491 Text feature [amplification] present in test data point [True]
# 494 Text feature [report] present in test data point [True]
# 498 Text feature [metastatic] present in test data point [True]
# Out of the top  500  features  119 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha_lr_bi = [10 ** x for x in range(-6, 1)]
cv_log_error_array_lr_bi = []
for i in alpha_lr_bi:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
    cv_log_error_array_lr_bi.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha_lr_bi, cv_log_error_array_lr_bi,c='g')
for i, txt in enumerate(np.round(cv_log_error_array_lr_bi,3)):
    ax.annotate((alpha_lr_bi[i],str(txt)), (alpha_lr_bi[i],cv_log_error_array_lr_bi[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha_lr_bi = np.argmin(cv_log_error_array_lr_bi)
clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_lr_bi)
print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_lr_bi)
print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1617092919252632
# for alpha = 1e-05
# Log Loss : 1.066764227822412
# for alpha = 0.0001
# Log Loss : 1.0317249731495757
# for alpha = 0.001
# Log Loss : 1.1369121068926065
# for alpha = 0.01
# Log Loss : 1.3284748819372758
# for alpha = 0.1
# Log Loss : 1.5853839239871717
# for alpha = 1
# Log Loss : 1.6985608009678028
# For values of best alpha =  0.0001 The train log loss is: 0.5693190514231191
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0317249731495757
# For values of best alpha =  0.0001 The test log loss is: 1.0735489186762666

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_lr_bi, train_y, cv_x_onehotCoding_lr_bi, cv_y, clf)
# Out:
# Log loss : 1.0317249731495757
# Number of mis-classified points : 0.36278195488721804
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0859 0.0154 0.0055 0.0226 0.2247 0.6319 0.0095 0.0026 0.0018]]
# Actual Class : 6
# --------------------------------------------------
# 76 Text feature [showing] present in test data point [True]
# 82 Text feature [basis] present in test data point [True]
# 87 Text feature [enzyme] present in test data point [True]
# 104 Text feature [confer] present in test data point [True]
# 105 Text feature [site] present in test data point [True]
# 106 Text feature [42] present in test data point [True]
# 107 Text feature [ring] present in test data point [True]
# 113 Text feature [expected] present in test data point [True]
# 118 Text feature [significant] present in test data point [True]
# 132 Text feature [observation] present in test data point [True]
# 135 Text feature [000] present in test data point [True]
# 153 Text feature [history] present in test data point [True]
# 165 Text feature [evidence] present in test data point [True]
# 173 Text feature [staining] present in test data point [True]
# 175 Text feature [state] present in test data point [True]
# 199 Text feature [43] present in test data point [True]
# 210 Text feature [substitutions] present in test data point [True]
# 214 Text feature [loss] present in test data point [True]
# 215 Text feature [population] present in test data point [True]
# 218 Text feature [following] present in test data point [True]
# 226 Text feature [multiple] present in test data point [True]
# 235 Text feature [terminal] present in test data point [True]
# 237 Text feature [statistical] present in test data point [True]
# 242 Text feature [considered] present in test data point [True]
# 245 Text feature [family] present in test data point [True]
# 246 Text feature [binding] present in test data point [True]
# 247 Text feature [alleles] present in test data point [True]
# 250 Text feature [34] present in test data point [True]
# 255 Text feature [overall] present in test data point [True]
# 257 Text feature [brca] present in test data point [True]
# 265 Text feature [reduction] present in test data point [True]
# 266 Text feature [predicted] present in test data point [True]
# 267 Text feature [domains] present in test data point [True]
# 269 Text feature [frequent] present in test data point [True]
# 279 Text feature [including] present in test data point [True]
# 283 Text feature [lower] present in test data point [True]
# 285 Text feature [time] present in test data point [True]
# 290 Text feature [unique] present in test data point [True]
# 291 Text feature [six] present in test data point [True]
# 292 Text feature [frequently] present in test data point [True]
# 303 Text feature [least] present in test data point [True]
# 304 Text feature [breast] present in test data point [True]
# 307 Text feature [receptor] present in test data point [True]
# 309 Text feature [therapeutic] present in test data point [True]
# 310 Text feature [number] present in test data point [True]
# 311 Text feature [identified] present in test data point [True]
# 314 Text feature [information] present in test data point [True]
# 318 Text feature [thus] present in test data point [True]
# 319 Text feature [difference] present in test data point [True]
# 324 Text feature [given] present in test data point [True]
# 325 Text feature [higher] present in test data point [True]
# 329 Text feature [frequency] present in test data point [True]
# 330 Text feature [full] present in test data point [True]
# 332 Text feature [first] present in test data point [True]
# 333 Text feature [affected] present in test data point [True]
# 334 Text feature [group] present in test data point [True]
# 338 Text feature [members] present in test data point [True]
# 340 Text feature [important] present in test data point [True]
# 341 Text feature [conserved] present in test data point [True]
# 350 Text feature [35] present in test data point [True]
# 353 Text feature [individuals] present in test data point [True]
# 354 Text feature [factor] present in test data point [True]
# 355 Text feature [status] present in test data point [True]
# 356 Text feature [23] present in test data point [True]
# 357 Text feature [class] present in test data point [True]
# 365 Text feature [shown] present in test data point [True]
# 376 Text feature [studied] present in test data point [True]
# 381 Text feature [classification] present in test data point [True]
# 384 Text feature [five] present in test data point [True]
# 387 Text feature [factors] present in test data point [True]
# 388 Text feature [age] present in test data point [True]
# 389 Text feature [brca1] present in test data point [True]
# 391 Text feature [15] present in test data point [True]
# 395 Text feature [reported] present in test data point [True]
# 398 Text feature [20] present in test data point [True]
# 400 Text feature [affect] present in test data point [True]
# 401 Text feature [yet] present in test data point [True]
# 404 Text feature [negative] present in test data point [True]
# 408 Text feature [type] present in test data point [True]
# 420 Text feature [also] present in test data point [True]
# 421 Text feature [majority] present in test data point [True]
# 424 Text feature [likely] present in test data point [True]
# 425 Text feature [41] present in test data point [True]
# 426 Text feature [range] present in test data point [True]
# 427 Text feature [length] present in test data point [True]
# 428 Text feature [therefore] present in test data point [True]
# 430 Text feature [26] present in test data point [True]
# 431 Text feature [deleterious] present in test data point [True]
# 432 Text feature [18] present in test data point [True]
# 433 Text feature [report] present in test data point [True]
# 434 Text feature [average] present in test data point [True]
# 436 Text feature [allele] present in test data point [True]
# 437 Text feature [acids] present in test data point [True]
# 440 Text feature [example] present in test data point [True]
# 445 Text feature [introduction] present in test data point [True]
# 447 Text feature [75] present in test data point [True]
# 449 Text feature [10] present in test data point [True]
# 450 Text feature [isolated] present in test data point [True]
# 455 Text feature [may] present in test data point [True]
# 461 Text feature [70] present in test data point [True]
# 462 Text feature [17] present in test data point [True]
# 466 Text feature [approach] present in test data point [True]
# 468 Text feature [according] present in test data point [True]
# 473 Text feature [dna] present in test data point [True]
# 474 Text feature [clinical] present in test data point [True]
# 483 Text feature [reaction] present in test data point [True]
# Out of the top  500  features  106 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.018  0.0473 0.0042 0.0172 0.0062 0.0076 0.8965 0.0021 0.001 ]]
# Actual Class : 7
# --------------------------------------------------
# 7 Text feature [concentrations] present in test data point [True]
# 41 Text feature [downstream] present in test data point [True]
# 44 Text feature [enhanced] present in test data point [True]
# 53 Text feature [oncogene] present in test data point [True]
# 56 Text feature [constitutive] present in test data point [True]
# 68 Text feature [fold] present in test data point [True]
# 73 Text feature [regulated] present in test data point [True]
# 78 Text feature [derived] present in test data point [True]
# 81 Text feature [somatic] present in test data point [True]
# 85 Text feature [blood] present in test data point [True]
# 99 Text feature [pathways] present in test data point [True]
# 106 Text feature [cancers] present in test data point [True]
# 108 Text feature [oncogenic] present in test data point [True]
# 112 Text feature [s3] present in test data point [True]
# 116 Text feature [approximately] present in test data point [True]
# 117 Text feature [inhibited] present in test data point [True]
# 118 Text feature [sensitive] present in test data point [True]
# 122 Text feature [additional] present in test data point [True]
# 125 Text feature [prostate] present in test data point [True]
# 135 Text feature [nucleotide] present in test data point [True]
# 156 Text feature [distinct] present in test data point [True]
# 157 Text feature [inhibitor] present in test data point [True]
# 171 Text feature [egfr] present in test data point [True]
# 173 Text feature [3b] present in test data point [True]
# 175 Text feature [contribute] present in test data point [True]
# 176 Text feature [sirna] present in test data point [True]
# 182 Text feature [2002] present in test data point [True]
# 183 Text feature [carcinoma] present in test data point [True]
# 186 Text feature [expressing] present in test data point [True]
# 187 Text feature [basal] present in test data point [True]
# 188 Text feature [lung] present in test data point [True]
# 191 Text feature [activated] present in test data point [True]
# 194 Text feature [constitutively] present in test data point [True]
# 198 Text feature [elevated] present in test data point [True]
# 205 Text feature [absence] present in test data point [True]
# 206 Text feature [frequent] present in test data point [True]
# 208 Text feature [malignant] present in test data point [True]
# 221 Text feature [mutant] present in test data point [True]
# 223 Text feature [presence] present in test data point [True]
# 226 Text feature [molecular] present in test data point [True]
# 227 Text feature [lead] present in test data point [True]
# 228 Text feature [leading] present in test data point [True]
# 231 Text feature [amplified] present in test data point [True]
# 238 Text feature [activation] present in test data point [True]
# 239 Text feature [high] present in test data point [True]
# 241 Text feature [promoter] present in test data point [True]
# 242 Text feature [regions] present in test data point [True]
# 244 Text feature [coding] present in test data point [True]
# 248 Text feature [12] present in test data point [True]
# 250 Text feature [transcription] present in test data point [True]
# 265 Text feature [fig] present in test data point [True]
# 268 Text feature [treated] present in test data point [True]
# 271 Text feature [materials] present in test data point [True]
# 272 Text feature [factor] present in test data point [True]
# 292 Text feature [day] present in test data point [True]
# 310 Text feature [mutants] present in test data point [True]
# 320 Text feature [overexpression] present in test data point [True]
# 322 Text feature [2003] present in test data point [True]
# 323 Text feature [leads] present in test data point [True]
# 324 Text feature [1a] present in test data point [True]
# 339 Text feature [3a] present in test data point [True]
# 340 Text feature [epithelial] present in test data point [True]
# 342 Text feature [sensitivity] present in test data point [True]
# 345 Text feature [properties] present in test data point [True]
# 348 Text feature [activate] present in test data point [True]
# 353 Text feature [nrf2] present in test data point [True]
# 356 Text feature [000] present in test data point [True]
# 360 Text feature [position] present in test data point [True]
# 362 Text feature [cause] present in test data point [True]
# 364 Text feature [molecule] present in test data point [True]
# 365 Text feature [major] present in test data point [True]
# 366 Text feature [demonstrated] present in test data point [True]
# 371 Text feature [luciferase] present in test data point [True]
# 372 Text feature [tissues] present in test data point [True]
# 380 Text feature [mutated] present in test data point [True]
# 382 Text feature [two] present in test data point [True]
# 385 Text feature [growth] present in test data point [True]
# 387 Text feature [suggest] present in test data point [True]
# 389 Text feature [consistent] present in test data point [True]
# 390 Text feature [promote] present in test data point [True]
# 391 Text feature [concentration] present in test data point [True]
# 392 Text feature [events] present in test data point [True]
# 398 Text feature [occur] present in test data point [True]
# 401 Text feature [increased] present in test data point [True]
# 402 Text feature [thus] present in test data point [True]
# 403 Text feature [adenocarcinoma] present in test data point [True]
# 409 Text feature [harboring] present in test data point [True]
# 410 Text feature [induction] present in test data point [True]
# 415 Text feature [activity] present in test data point [True]
# 423 Text feature [respectively] present in test data point [True]
# 425 Text feature [2000] present in test data point [True]
# 428 Text feature [independent] present in test data point [True]
# 429 Text feature [conditions] present in test data point [True]
# 430 Text feature [factors] present in test data point [True]
# 431 Text feature [2b] present in test data point [True]
# 432 Text feature [4a] present in test data point [True]
# 433 Text feature [common] present in test data point [True]
# 435 Text feature [evaluated] present in test data point [True]
# 437 Text feature [activating] present in test data point [True]
# 438 Text feature [approach] present in test data point [True]
# 440 Text feature [early] present in test data point [True]
# 442 Text feature [forms] present in test data point [True]
# 443 Text feature [increase] present in test data point [True]
# 445 Text feature [total] present in test data point [True]
# 451 Text feature [recently] present in test data point [True]
# 455 Text feature [cells] present in test data point [True]
# 456 Text feature [signaling] present in test data point [True]
# 457 Text feature [caused] present in test data point [True]
# 460 Text feature [inhibition] present in test data point [True]
# 462 Text feature [corresponding] present in test data point [True]
# 463 Text feature [transcriptional] present in test data point [True]
# 467 Text feature [report] present in test data point [True]
# 468 Text feature [metastatic] present in test data point [True]
# 471 Text feature [showed] present in test data point [True]
# 473 Text feature [mechanisms] present in test data point [True]
# 474 Text feature [2001] present in test data point [True]
# 479 Text feature [measured] present in test data point [True]
# 480 Text feature [target] present in test data point [True]
# 484 Text feature [led] present in test data point [True]
# 485 Text feature [characterized] present in test data point [True]
# 486 Text feature [various] present in test data point [True]
# 488 Text feature [reporter] present in test data point [True]
# 489 Text feature [effect] present in test data point [True]
# 491 Text feature [activities] present in test data point [True]
# Out of the top  500  features  124 are present in query point
