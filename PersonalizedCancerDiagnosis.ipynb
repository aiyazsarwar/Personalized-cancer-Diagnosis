# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
#from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from sklearn.ensemble import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 76.0108109000139 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sort_values()
test_class_distribution = test_df['Class'].value_counts().sort_values()
cv_class_distribution = cv_df['Class'].value_counts().sort_values()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 9 : 609 ( 28.672 %)
# Number of data points in class 8 : 439 ( 20.669 %)
# Number of data points in class 7 : 363 ( 17.09 %)
# Number of data points in class 6 : 289 ( 13.606 %)
# Number of data points in class 5 : 176 ( 8.286 %)
# Number of data points in class 4 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 2 : 24 ( 1.13 %)
# Number of data points in class 1 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 9 : 191 ( 28.722 %)
# Number of data points in class 8 : 137 ( 20.602 %)
# Number of data points in class 7 : 114 ( 17.143 %)
# Number of data points in class 6 : 91 ( 13.684 %)
# Number of data points in class 5 : 55 ( 8.271 %)
# Number of data points in class 4 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 2 : 7 ( 1.053 %)
# Number of data points in class 1 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 9 : 153 ( 28.759 %)
# Number of data points in class 8 : 110 ( 20.677 %)
# Number of data points in class 7 : 91 ( 17.105 %)
# Number of data points in class 6 : 72 ( 13.534 %)
# Number of data points in class 5 : 44 ( 8.271 %)
# Number of data points in class 4 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 2 : 6 ( 1.128 %)
# Number of data points in class 1 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
    
ran_model_log_loss_cv = log_loss(y_cv,cv_predicted_y, eps=1e-15)

print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
    
ran_model_log_loss_test = log_loss(y_test,test_predicted_y, eps=1e-15)

print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.5591571879785118
# Log loss on Test Data using Random Model 2.47419911121577
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 228
# BRCA1     171
# TP53      108
# EGFR       93
# PTEN       86
# BRCA2      78
# KIT        64
# BRAF       63
# ERBB2      45
# ALK        42
# PDGFRA     41
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 228 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 926     PDGFRA
# 486       TP53
# 619      FBXW7
# 2028    MAP2K1
# 1666      FLT3
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1a',
#  'arid2',
#  'atm',
#  'atrx',
#  'aurka',
#  'axin1',
#  'axl',
#  'b2m',
#  'bap1',
#  'bcl2',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fam58a',
#  'fanca',
#  'fancc',
#  'fat1',
#  'fbxw7',
#  'fgf19',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt1',
#  'flt3',
#  'foxa1',
#  'foxo1',
#  'foxp1',
#  'gata3',
#  'gna11',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'ikzf1',
#  'il7r',
#  'inpp4b',
#  'jak1',
#  'jak2',
#  'jun',
#  'kdm5a',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'kmt2a',
#  'kmt2b',
#  'kmt2c',
#  'kmt2d',
#  'knstrn',
#  'kras',
#  'lats1',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm2',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'mycn',
#  'myd88',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pax8',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pik3r3',
#  'pim1',
#  'pms1',
#  'pms2',
#  'pole',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51b',
#  'rad51c',
#  'raf1',
#  'rara',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rnf43',
#  'ros1',
#  'rras2',
#  'runx1',
#  'rxra',
#  'sdhb',
#  'sdhc',
#  'setd2',
#  'sf3b1',
#  'shoc2',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf7l2',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tp53bp1',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vhl',
#  'whsc1',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 227)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
gene_feat_log_loss_train = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
gene_feat_log_loss_cv = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
gene_feat_log_loss_test = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1657177146447026
# For values of alpha =  0.0001 The log loss is: 1.1467029792466508
# For values of alpha =  0.001 The log loss is: 1.195053474354139
# For values of alpha =  0.01 The log loss is: 1.3321557991146964
# For values of alpha =  0.1 The log loss is: 1.4269964879891979
# For values of alpha =  1 The log loss is: 1.4704826465143628
# For values of best alpha =  0.0001 The train log loss is: 1.0047718818417672
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1467029792466508
# For values of best alpha =  0.0001 The test log loss is: 1.2095780305499841

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  228  genes in train dataset?
# Ans
# 1. In test data 633 out of 665 : 95.18796992481204
# 2. In cross validation data 519 out of  532 : 97.55639097744361

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1929
# Truncating_Mutations    64
# Deletion                42
# Amplification           42
# Fusions                 21
# Overexpression           5
# Q61L                     3
# G12V                     3
# T58I                     3
# ETV6-NTRK3_Fusion        2
# T286A                    2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1929 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.03013183 0.04990584 0.06967985 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1961)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
var_feat_log_loss_train = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
var_feat_log_loss_cv = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
var_feat_log_loss_test = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7237521856911864
# For values of alpha =  0.0001 The log loss is: 1.7154343814951554
# For values of alpha =  0.001 The log loss is: 1.71311491020675
# For values of alpha =  0.01 The log loss is: 1.719972779978264
# For values of alpha =  0.1 The log loss is: 1.7241217828052968
# For values of alpha =  1 The log loss is: 1.7268703102207748
# For values of best alpha =  0.001 The train log loss is: 1.0313666873912235
# For values of best alpha =  0.001 The cross validation log loss is: 1.71311491020675
# For values of best alpha =  0.001 The test log loss is: 1.7009212326958498

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1929  genes in test and cross validation data sets?
# Ans
# 1. In test data 71 out of 665 : 10.676691729323307
# 2. In cross validation data 54 out of  532 : 10.150375939849624

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 52519

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({3: 5064, 4: 3731, 6: 2945, 5: 2573, 8: 1982, 9: 1736, 7: 1710, 10: 1453, 12: 1380, 11: 1292, 13: 1233, 14: 845, 18: 824, 15: 806, 16: 707, 20: 592, 24: 527, 19: 525, 17: 525, 21: 509, 23: 487, 22: 414, 38: 372, 28: 356, 32: 348, 30: 345, 25: 338, 27: 332, 26: 327, 36: 301, 33: 294, 29: 284, 31: 276, 50: 271, 35: 243, 34: 243, 40: 216, 46: 203, 39: 198, 42: 194, 44: 189, 37: 185, 48: 180, 54: 164, 45: 161, 43: 161, 41: 158, 52: 154, 49: 153, 47: 153, 57: 150, 51: 149, 56: 148, 60: 133, 66: 129, 58: 126, 59: 125, 61: 118, 55: 115, 74: 114, 65: 110, 53: 105, 63: 102, 71: 101, 76: 100, 67: 100, 69: 98, 73: 97, 64: 97, 72: 95, 68: 93, 70: 92, 62: 90, 92: 87, 78: 86, 84: 85, 100: 76, 75: 72, 80: 71, 86: 70, 82: 68, 79: 68, 77: 68, 81: 66, 105: 64, 94: 63, 98: 62, 87: 61, 85: 60, 93: 59, 112: 58, 107: 58, 95: 58, 89: 58, 83: 58, 91: 57, 108: 56, 97: 56, 90: 56, 120: 54, 104: 51, 96: 51, 135: 50, 113: 50, 141: 49, 115: 47, 114: 46, 88: 46, 109: 45, 106: 45, 102: 45, 99: 45, 124: 43, 128: 42, 101: 42, 130: 41, 111: 41, 103: 41, 140: 40, 129: 40, 122: 40, 117: 40, 110: 40, 123: 39, 144: 38, 143: 38, 138: 38, 133: 38, 125: 38, 118: 38, 116: 38, 162: 37, 150: 37, 142: 37, 131: 37, 127: 36, 156: 35, 126: 35, 151: 34, 132: 34, 168: 33, 136: 33, 121: 33, 153: 32, 158: 30, 137: 30, 180: 29, 169: 29, 152: 29, 145: 29, 139: 29, 209: 28, 190: 28, 171: 28, 149: 28, 148: 28, 119: 28, 161: 27, 154: 27, 134: 27, 175: 26, 166: 26, 196: 25, 179: 25, 202: 24, 200: 24, 183: 24, 165: 24, 163: 24, 147: 24, 146: 24, 234: 23, 223: 23, 221: 23, 199: 23, 197: 23, 192: 23, 167: 23, 159: 23, 228: 22, 219: 22, 210: 22, 189: 22, 185: 22, 176: 22, 174: 22, 155: 22, 272: 21, 243: 21, 203: 21, 184: 21, 177: 21, 164: 21, 157: 21, 279: 20, 225: 20, 212: 20, 206: 20, 204: 20, 182: 20, 181: 20, 178: 20, 173: 20, 172: 20, 280: 19, 265: 19, 233: 19, 222: 19, 216: 19, 207: 19, 186: 19, 170: 19, 160: 19, 290: 18, 237: 18, 232: 18, 230: 18, 227: 18, 214: 18, 188: 18, 372: 17, 303: 17, 294: 17, 268: 17, 251: 17, 250: 17, 242: 17, 224: 17, 218: 17, 215: 17, 208: 17, 194: 17, 193: 17, 301: 16, 295: 16, 261: 16, 260: 16, 244: 16, 241: 16, 229: 16, 220: 16, 187: 16, 333: 15, 331: 15, 312: 15, 298: 15, 282: 15, 276: 15, 271: 15, 254: 15, 252: 15, 205: 15, 191: 15, 337: 14, 330: 14, 326: 14, 313: 14, 304: 14, 292: 14, 273: 14, 270: 14, 264: 14, 246: 14, 226: 14, 217: 14, 213: 14, 201: 14, 198: 14, 195: 14, 380: 13, 360: 13, 344: 13, 318: 13, 278: 13, 262: 13, 245: 13, 236: 13, 231: 13, 468: 12, 366: 12, 354: 12, 335: 12, 325: 12, 300: 12, 299: 12, 288: 12, 269: 12, 258: 12, 257: 12, 256: 12, 253: 12, 247: 12, 211: 12, 463: 11, 403: 11, 391: 11, 349: 11, 348: 11, 322: 11, 311: 11, 302: 11, 287: 11, 286: 11, 281: 11, 274: 11, 238: 11, 448: 10, 430: 10, 405: 10, 377: 10, 367: 10, 343: 10, 341: 10, 324: 10, 307: 10, 296: 10, 285: 10, 266: 10, 249: 10, 240: 10, 640: 9, 616: 9, 550: 9, 506: 9, 478: 9, 460: 9, 459: 9, 442: 9, 436: 9, 431: 9, 429: 9, 427: 9, 420: 9, 396: 9, 389: 9, 386: 9, 364: 9, 357: 9, 355: 9, 353: 9, 327: 9, 323: 9, 320: 9, 317: 9, 308: 9, 293: 9, 263: 9, 259: 9, 248: 9, 235: 9, 662: 8, 534: 8, 503: 8, 470: 8, 461: 8, 433: 8, 409: 8, 399: 8, 397: 8, 395: 8, 394: 8, 376: 8, 352: 8, 346: 8, 345: 8, 310: 8, 297: 8, 289: 8, 284: 8, 283: 8, 275: 8, 255: 8, 869: 7, 679: 7, 675: 7, 674: 7, 615: 7, 577: 7, 544: 7, 543: 7, 536: 7, 510: 7, 504: 7, 492: 7, 482: 7, 469: 7, 446: 7, 445: 7, 440: 7, 422: 7, 419: 7, 414: 7, 410: 7, 398: 7, 392: 7, 387: 7, 384: 7, 382: 7, 375: 7, 373: 7, 365: 7, 363: 7, 356: 7, 351: 7, 329: 7, 319: 7, 314: 7, 309: 7, 267: 7, 239: 7, 961: 6, 885: 6, 851: 6, 792: 6, 729: 6, 705: 6, 696: 6, 664: 6, 647: 6, 635: 6, 634: 6, 599: 6, 585: 6, 583: 6, 580: 6, 579: 6, 576: 6, 574: 6, 573: 6, 563: 6, 562: 6, 552: 6, 541: 6, 540: 6, 523: 6, 512: 6, 487: 6, 486: 6, 477: 6, 466: 6, 465: 6, 458: 6, 455: 6, 444: 6, 434: 6, 432: 6, 418: 6, 413: 6, 408: 6, 404: 6, 400: 6, 390: 6, 385: 6, 379: 6, 370: 6, 369: 6, 358: 6, 342: 6, 338: 6, 332: 6, 328: 6, 277: 6, 21 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
text_feat_log_loss_train = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
text_feat_log_loss_cv = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
text_feat_log_loss_test = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.2837459096831674
# For values of alpha =  0.0001 The log loss is: 1.1514911445164409
# For values of alpha =  0.001 The log loss is: 1.142193339659903
# For values of alpha =  0.01 The log loss is: 1.2523017787361674
# For values of alpha =  0.1 The log loss is: 1.4737151112764482
# For values of alpha =  1 The log loss is: 1.6628287637539167
# For values of best alpha =  0.001 The train log loss is: 0.6577423680613717
# For values of best alpha =  0.001 The cross validation log loss is: 1.142193339659903
# For values of best alpha =  0.001 The test log loss is: 1.1719303011134463

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 96.263 % of word of test data appeared in train data
# 97.04 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 54707)
# (number of data points * number of features) in test data =  (665, 54707)
# (number of data points * number of features) in cross validation data = (532, 54707)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
nb_log_loss_train = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
nb_log_loss_cv = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
nb_log_loss_test = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.3174935564532755
# for alpha = 0.0001
# Log Loss : 1.315906968645129
# for alpha = 0.001
# Log Loss : 1.3183449448031084
# for alpha = 0.1
# Log Loss : 1.3166811896271227
# for alpha = 1
# Log Loss : 1.3047661717776622
# for alpha = 10
# Log Loss : 1.3995741199097096
# for alpha = 100
# Log Loss : 1.3677064500242069
# for alpha = 1000
# Log Loss : 1.293715823127756
# For values of best alpha =  1000 The train log loss is: 1.0643144511923024
# For values of best alpha =  1000 The cross validation log loss is: 1.293715823127756
# For values of best alpha =  1000 The test log loss is: 1.3199654413019961

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.293715823127756
# Number of missclassified point : 0.43796992481203006
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.1468 0.2143 0.0668 0.1416 0.0865 0.0983 0.2142 0.0086 0.0229]]
# Actual Class : 2
# --------------------------------------------------
# 15 Text feature [identified] present in test data point [True]
# 16 Text feature [sequencing] present in test data point [True]
# 17 Text feature [novel] present in test data point [True]
# 21 Text feature [clinical] present in test data point [True]
# 23 Text feature [detection] present in test data point [True]
# 25 Text feature [present] present in test data point [True]
# 28 Text feature [identify] present in test data point [True]
# 29 Text feature [using] present in test data point [True]
# 30 Text feature [different] present in test data point [True]
# 31 Text feature [including] present in test data point [True]
# 33 Text feature [new] present in test data point [True]
# 35 Text feature [case] present in test data point [True]
# 37 Text feature [gene] present in test data point [True]
# 38 Text feature [pcr] present in test data point [True]
# 41 Text feature [revealed] present in test data point [True]
# 44 Text feature [patient] present in test data point [True]
# 46 Text feature [15] present in test data point [True]
# 47 Text feature [specific] present in test data point [True]
# 49 Text feature [may] present in test data point [True]
# 52 Text feature [samples] present in test data point [True]
# 53 Text feature [fusion] present in test data point [True]
# 59 Text feature [12] present in test data point [True]
# 60 Text feature [found] present in test data point [True]
# 61 Text feature [also] present in test data point [True]
# 66 Text feature [highly] present in test data point [True]
# 67 Text feature [observed] present in test data point [True]
# 68 Text feature [40] present in test data point [True]
# 69 Text feature [performed] present in test data point [True]
# 70 Text feature [10] present in test data point [True]
# 71 Text feature [one] present in test data point [True]
# 75 Text feature [tissue] present in test data point [True]
# 76 Text feature [characterized] present in test data point [True]
# 78 Text feature [detected] present in test data point [True]
# 80 Text feature [analysis] present in test data point [True]
# 83 Text feature [small] present in test data point [True]
# 84 Text feature [16] present in test data point [True]
# 87 Text feature [table] present in test data point [True]
# 88 Text feature [addition] present in test data point [True]
# 92 Text feature [tumor] present in test data point [True]
# 94 Text feature [cases] present in test data point [True]
# 95 Text feature [known] present in test data point [True]
# Out of the top  100  features  41 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.000e+00 1.000e-04 0.000e+00 1.000e-04 2.000e-04 0.000e+00 9.896e-01
#   9.800e-03 1.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 17 Text feature [kinase] present in test data point [True]
# 18 Text feature [downstream] present in test data point [True]
# 19 Text feature [presence] present in test data point [True]
# 20 Text feature [inhibitor] present in test data point [True]
# 21 Text feature [cell] present in test data point [True]
# 23 Text feature [well] present in test data point [True]
# 24 Text feature [potential] present in test data point [True]
# 25 Text feature [contrast] present in test data point [True]
# 26 Text feature [independent] present in test data point [True]
# 27 Text feature [activating] present in test data point [True]
# 28 Text feature [shown] present in test data point [True]
# 29 Text feature [cells] present in test data point [True]
# 30 Text feature [showed] present in test data point [True]
# 31 Text feature [expressing] present in test data point [True]
# 32 Text feature [previously] present in test data point [True]
# 33 Text feature [recently] present in test data point [True]
# 34 Text feature [activation] present in test data point [True]
# 35 Text feature [compared] present in test data point [True]
# 36 Text feature [treated] present in test data point [True]
# 37 Text feature [also] present in test data point [True]
# 38 Text feature [similar] present in test data point [True]
# 39 Text feature [obtained] present in test data point [True]
# 40 Text feature [higher] present in test data point [True]
# 41 Text feature [growth] present in test data point [True]
# 42 Text feature [10] present in test data point [True]
# 43 Text feature [however] present in test data point [True]
# 44 Text feature [found] present in test data point [True]
# 45 Text feature [addition] present in test data point [True]
# 46 Text feature [suggest] present in test data point [True]
# 47 Text feature [may] present in test data point [True]
# 48 Text feature [observed] present in test data point [True]
# 49 Text feature [inhibition] present in test data point [True]
# 50 Text feature [factor] present in test data point [True]
# 51 Text feature [total] present in test data point [True]
# 52 Text feature [described] present in test data point [True]
# 53 Text feature [12] present in test data point [True]
# 54 Text feature [mutations] present in test data point [True]
# 55 Text feature [including] present in test data point [True]
# 56 Text feature [1a] present in test data point [True]
# 57 Text feature [constitutively] present in test data point [True]
# 58 Text feature [without] present in test data point [True]
# 59 Text feature [concentrations] present in test data point [True]
# 60 Text feature [approximately] present in test data point [True]
# 63 Text feature [activated] present in test data point [True]
# 64 Text feature [respectively] present in test data point [True]
# 65 Text feature [using] present in test data point [True]
# 66 Text feature [3b] present in test data point [True]
# 67 Text feature [3a] present in test data point [True]
# 68 Text feature [proliferation] present in test data point [True]
# 69 Text feature [confirmed] present in test data point [True]
# 70 Text feature [inhibitors] present in test data point [True]
# 71 Text feature [suggests] present in test data point [True]
# 72 Text feature [furthermore] present in test data point [True]
# 73 Text feature [various] present in test data point [True]
# 74 Text feature [new] present in test data point [True]
# 75 Text feature [identified] present in test data point [True]
# 76 Text feature [reported] present in test data point [True]
# 77 Text feature [studies] present in test data point [True]
# 79 Text feature [although] present in test data point [True]
# 80 Text feature [per] present in test data point [True]
# 81 Text feature [similarly] present in test data point [True]
# 82 Text feature [followed] present in test data point [True]
# 83 Text feature [occur] present in test data point [True]
# 84 Text feature [inhibited] present in test data point [True]
# 85 Text feature [different] present in test data point [True]
# 86 Text feature [interestingly] present in test data point [True]
# 87 Text feature [consistent] present in test data point [True]
# 88 Text feature [either] present in test data point [True]
# 89 Text feature [sensitive] present in test data point [True]
# 90 Text feature [15] present in test data point [True]
# 91 Text feature [therapeutic] present in test data point [True]
# 92 Text feature [hours] present in test data point [True]
# 93 Text feature [mutant] present in test data point [True]
# 94 Text feature [mutation] present in test data point [True]
# 95 Text feature [confirm] present in test data point [True]
# 96 Text feature [recent] present in test data point [True]
# 97 Text feature [mechanism] present in test data point [True]
# 98 Text feature [less] present in test data point [True]
# 99 Text feature [molecular] present in test data point [True]
# Out of the top  100  features  79 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
knn_log_loss_train = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
knn_log_loss_cv = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
knn_log_loss_test = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.1049561907383738
# for alpha = 11
# Log Loss : 1.0539313259098966
# for alpha = 15
# Log Loss : 1.0374678814810312
# for alpha = 21
# Log Loss : 1.0416250628188717
# for alpha = 31
# Log Loss : 1.0647229569193175
# for alpha = 41
# Log Loss : 1.0638004012193887
# for alpha = 51
# Log Loss : 1.0666843901379968
# for alpha = 99
# Log Loss : 1.073902487347784
# For values of best alpha =  15 The train log loss is: 0.6554417934589064
# For values of best alpha =  15 The cross validation log loss is: 1.0374678814810312
# For values of best alpha =  15 The test log loss is: 1.1160796715407628

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0374678814810312
# Number of mis-classified points : 0.3533834586466165
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 2
# The  15  nearest neighbours of the test points belongs to classes [7 7 7 7 7 7 7 7 2 7 7 7 7 7 7]
# Fequency of nearest points : Counter({7: 14, 2: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 15 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7 7 7 7 7 7 7 7 7 7 2]
# Fequency of nearest points : Counter({7: 14, 2: 1})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
lr_log_loss_train1 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
lr_log_loss_cv1 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
lr_log_loss_test1 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3342228513113994
# for alpha = 1e-05
# Log Loss : 1.3041521035845756
# for alpha = 0.0001
# Log Loss : 1.1073395271860431
# for alpha = 0.001
# Log Loss : 1.0918673717076315
# for alpha = 0.01
# Log Loss : 1.1584946956595479
# for alpha = 0.1
# Log Loss : 1.451636013270232
# for alpha = 1
# Log Loss : 1.6607476915340216
# for alpha = 10
# Log Loss : 1.6926555019428742
# for alpha = 100
# Log Loss : 1.6961605395780137
# For values of best alpha =  0.001 The train log loss is: 0.528148104225811
# For values of best alpha =  0.001 The cross validation log loss is: 1.0918673717076315
# For values of best alpha =  0.001 The test log loss is: 1.0881534059577134

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0918673717076315
# Number of mis-classified points : 0.35526315789473684
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1683 0.1648 0.0358 0.1437 0.0711 0.0845 0.3141 0.0051 0.0125]]
# Actual Class : 2
# --------------------------------------------------
# 36 Text feature [3t3] present in test data point [True]
# 129 Text feature [transform] present in test data point [True]
# 212 Text feature [murine] present in test data point [True]
# 326 Text feature [activation] present in test data point [True]
# 483 Text feature [resected] present in test data point [True]
# Out of the top  500  features  5 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.000e+00 2.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00 9.906e-01
#   8.900e-03 1.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 30 Text feature [stat] present in test data point [True]
# 32 Text feature [constitutively] present in test data point [True]
# 34 Text feature [transforming] present in test data point [True]
# 62 Text feature [flt1] present in test data point [True]
# 68 Text feature [activated] present in test data point [True]
# 71 Text feature [constitutive] present in test data point [True]
# 74 Text feature [mitogen] present in test data point [True]
# 86 Text feature [stat5] present in test data point [True]
# 87 Text feature [pstat5] present in test data point [True]
# 94 Text feature [rac] present in test data point [True]
# 103 Text feature [tk1] present in test data point [True]
# 107 Text feature [starved] present in test data point [True]
# 109 Text feature [thymoma] present in test data point [True]
# 118 Text feature [transformation] present in test data point [True]
# 124 Text feature [inhibitor] present in test data point [True]
# 128 Text feature [inhibited] present in test data point [True]
# 129 Text feature [transform] present in test data point [True]
# 131 Text feature [autophosphorylated] present in test data point [True]
# 140 Text feature [tk2] present in test data point [True]
# 172 Text feature [janus] present in test data point [True]
# 188 Text feature [downstream] present in test data point [True]
# 197 Text feature [tyrosine] present in test data point [True]
# 198 Text feature [oncogene] present in test data point [True]
# 204 Text feature [py20] present in test data point [True]
# 212 Text feature [murine] present in test data point [True]
# 235 Text feature [jak] present in test data point [True]
# 244 Text feature [filters] present in test data point [True]
# 246 Text feature [balb] present in test data point [True]
# 273 Text feature [stat3] present in test data point [True]
# 293 Text feature [interleukin] present in test data point [True]
# 297 Text feature [refractory] present in test data point [True]
# 300 Text feature [ligand] present in test data point [True]
# 321 Text feature [independently] present in test data point [True]
# 323 Text feature [mapk] present in test data point [True]
# 326 Text feature [activation] present in test data point [True]
# 333 Text feature [grew] present in test data point [True]
# 353 Text feature [intermittently] present in test data point [True]
# 362 Text feature [concentrations] present in test data point [True]
# 364 Text feature [manageable] present in test data point [True]
# 373 Text feature [1781] present in test data point [True]
# 379 Text feature [extracellular] present in test data point [True]
# 397 Text feature [tk] present in test data point [True]
# 411 Text feature [dramatic] present in test data point [True]
# 413 Text feature [enhance] present in test data point [True]
# 422 Text feature [activating] present in test data point [True]
# 437 Text feature [cdnas] present in test data point [True]
# 446 Text feature [doses] present in test data point [True]
# 452 Text feature [independence] present in test data point [True]
# 456 Text feature [overexpression] present in test data point [True]
# 480 Text feature [proliferation] present in test data point [True]
# 487 Text feature [phosphotyrosine] present in test data point [True]
# 498 Text feature [expressing] present in test data point [True]
# Out of the top  500  features  52 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
lr_log_loss_train2 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
lr_log_loss_cv2 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
lr_log_loss_test2 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3066959051073033
# for alpha = 1e-05
# Log Loss : 1.2790175790373146
# for alpha = 0.0001
# Log Loss : 1.1324510307811648
# for alpha = 0.001
# Log Loss : 1.0910878220520284
# for alpha = 0.01
# Log Loss : 1.185026282972386
# for alpha = 0.1
# Log Loss : 1.3814329015068278
# for alpha = 1
# Log Loss : 1.606520879324575
# For values of best alpha =  0.001 The train log loss is: 0.5251968560481574
# For values of best alpha =  0.001 The cross validation log loss is: 1.0910878220520284
# For values of best alpha =  0.001 The test log loss is: 1.0954251377678559

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0910878220520284
# Number of mis-classified points : 0.34962406015037595
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1638 0.1702 0.0502 0.1284 0.0804 0.0948 0.2863 0.0076 0.0183]]
# Actual Class : 2
# --------------------------------------------------
# 89 Text feature [3t3] present in test data point [True]
# 253 Text feature [transform] present in test data point [True]
# Out of the top  500  features  2 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[1.000e-04 3.000e-04 0.000e+00 1.000e-04 0.000e+00 0.000e+00 9.931e-01
#   6.300e-03 2.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 74 Text feature [transforming] present in test data point [True]
# 85 Text feature [constitutively] present in test data point [True]
# 88 Text feature [stat] present in test data point [True]
# 118 Text feature [flt1] present in test data point [True]
# 169 Text feature [1781] present in test data point [True]
# 179 Text feature [activated] present in test data point [True]
# 181 Text feature [thymoma] present in test data point [True]
# 183 Text feature [mitogen] present in test data point [True]
# 194 Text feature [stat5] present in test data point [True]
# 196 Text feature [tk1] present in test data point [True]
# 210 Text feature [pstat5] present in test data point [True]
# 213 Text feature [constitutive] present in test data point [True]
# 249 Text feature [starved] present in test data point [True]
# 253 Text feature [transform] present in test data point [True]
# 266 Text feature [transformation] present in test data point [True]
# 282 Text feature [inhibitor] present in test data point [True]
# 293 Text feature [inhibited] present in test data point [True]
# 302 Text feature [rac] present in test data point [True]
# 304 Text feature [tk2] present in test data point [True]
# 328 Text feature [downstream] present in test data point [True]
# 342 Text feature [autophosphorylated] present in test data point [True]
# 360 Text feature [balb] present in test data point [True]
# 374 Text feature [tyrosine] present in test data point [True]
# 381 Text feature [hip1] present in test data point [True]
# 384 Text feature [activating] present in test data point [True]
# 401 Text feature [oncogene] present in test data point [True]
# 415 Text feature [stat3] present in test data point [True]
# 431 Text feature [janus] present in test data point [True]
# 443 Text feature [interleukin] present in test data point [True]
# 456 Text feature [filters] present in test data point [True]
# 463 Text feature [manageable] present in test data point [True]
# 485 Text feature [jak] present in test data point [True]
# 488 Text feature [extracellular] present in test data point [True]
# Out of the top  500  features  33 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
svm_log_loss_train1 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
svm_log_loss_cv1 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
svm_log_loss_test1 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.3146145670877367
# for C = 0.0001
# Log Loss : 1.2371691429308795
# for C = 0.001
# Log Loss : 1.1339433403519878
# for C = 0.01
# Log Loss : 1.1449089759353035
# for C = 0.1
# Log Loss : 1.3713069486928189
# for C = 1
# Log Loss : 1.6833650414907717
# for C = 10
# Log Loss : 1.696759231591497
# for C = 100
# Log Loss : 1.6967590889067528
# For values of best alpha =  0.001 The train log loss is: 0.5274278418921878
# For values of best alpha =  0.001 The cross validation log loss is: 1.1339433403519878
# For values of best alpha =  0.001 The test log loss is: 1.1246401787525544

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1339433403519878
# Number of mis-classified points : 0.35714285714285715
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1549 0.1865 0.0444 0.1128 0.0844 0.0933 0.3066 0.0068 0.0103]]
# Actual Class : 2
# --------------------------------------------------
# 355 Text feature [3t3] present in test data point [True]
# 494 Text feature [cta] present in test data point [True]
# Out of the top  500  features  2 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[2.060e-02 3.600e-03 4.000e-04 1.560e-02 4.000e-03 7.000e-04 9.387e-01
#   1.380e-02 2.400e-03]]
# Actual Class : 7
# --------------------------------------------------
# 125 Text feature [1781] present in test data point [True]
# 165 Text feature [13q12] present in test data point [True]
# 300 Text feature [lymphocytic] present in test data point [True]
# 302 Text feature [hip1] present in test data point [True]
# 349 Text feature [thymoma] present in test data point [True]
# 351 Text feature [tk1] present in test data point [True]
# 357 Text feature [transforming] present in test data point [True]
# 398 Text feature [tk2] present in test data point [True]
# 440 Text feature [constitutively] present in test data point [True]
# 493 Text feature [stat] present in test data point [True]
# 494 Text feature [cta] present in test data point [True]
# Out of the top  500  features  11 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
rf_log_loss_train = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
rf_log_loss_cv = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
rf_log_loss_test = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2613026824169737
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1667459288494644
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2468423614834925
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.163868526843632
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2438634465258502
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.161992255537185
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2407188756306713
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1587561210031554
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.239355291427684
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.1593808830558558
# For values of best estimator =  1000 The train log loss is: 0.6787596928231501
# For values of best estimator =  1000 The cross validation log loss is: 1.1587561210031554
# For values of best estimator =  1000 The test log loss is: 1.1705417855342262

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1587561210031554
# Number of mis-classified points : 0.40225563909774437
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.2211 0.1945 0.0249 0.2916 0.064  0.0588 0.1257 0.0081 0.0113]]
# Actual Class : 2
# --------------------------------------------------
# 2 Text feature [activation] present in test data point [True]
# 19 Text feature [growth] present in test data point [True]
# 22 Text feature [activate] present in test data point [True]
# 34 Text feature [cell] present in test data point [True]
# 38 Text feature [3t3] present in test data point [True]
# 41 Text feature [cells] present in test data point [True]
# 43 Text feature [patients] present in test data point [True]
# 46 Text feature [transform] present in test data point [True]
# 55 Text feature [protein] present in test data point [True]
# 58 Text feature [clinical] present in test data point [True]
# 72 Text feature [dna] present in test data point [True]
# 95 Text feature [lines] present in test data point [True]
# 96 Text feature [kit] present in test data point [True]
# Out of the top  100  features  13 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0284 0.0481 0.013  0.0266 0.0295 0.0225 0.8226 0.0045 0.0048]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [activated] present in test data point [True]
# 4 Text feature [constitutive] present in test data point [True]
# 5 Text feature [inhibitors] present in test data point [True]
# 6 Text feature [tyrosine] present in test data point [True]
# 9 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [treatment] present in test data point [True]
# 11 Text feature [inhibitor] present in test data point [True]
# 13 Text feature [signaling] present in test data point [True]
# 14 Text feature [function] present in test data point [True]
# 15 Text feature [constitutively] present in test data point [True]
# 17 Text feature [loss] present in test data point [True]
# 19 Text feature [growth] present in test data point [True]
# 22 Text feature [activate] present in test data point [True]
# 23 Text feature [receptor] present in test data point [True]
# 24 Text feature [erk] present in test data point [True]
# 25 Text feature [functional] present in test data point [True]
# 26 Text feature [therapy] present in test data point [True]
# 27 Text feature [oncogenic] present in test data point [True]
# 28 Text feature [drug] present in test data point [True]
# 29 Text feature [resistance] present in test data point [True]
# 30 Text feature [months] present in test data point [True]
# 31 Text feature [therapeutic] present in test data point [True]
# 33 Text feature [kinases] present in test data point [True]
# 34 Text feature [cell] present in test data point [True]
# 35 Text feature [akt] present in test data point [True]
# 36 Text feature [proliferation] present in test data point [True]
# 37 Text feature [ic50] present in test data point [True]
# 39 Text feature [trials] present in test data point [True]
# 40 Text feature [efficacy] present in test data point [True]
# 41 Text feature [cells] present in test data point [True]
# 42 Text feature [downstream] present in test data point [True]
# 43 Text feature [patients] present in test data point [True]
# 44 Text feature [ba] present in test data point [True]
# 45 Text feature [transforming] present in test data point [True]
# 46 Text feature [transform] present in test data point [True]
# 50 Text feature [inhibited] present in test data point [True]
# 51 Text feature [mutant] present in test data point [True]
# 52 Text feature [frameshift] present in test data point [True]
# 54 Text feature [imatinib] present in test data point [True]
# 55 Text feature [protein] present in test data point [True]
# 56 Text feature [potency] present in test data point [True]
# 57 Text feature [f3] present in test data point [True]
# 58 Text feature [clinical] present in test data point [True]
# 59 Text feature [advanced] present in test data point [True]
# 61 Text feature [oncogene] present in test data point [True]
# 63 Text feature [expressing] present in test data point [True]
# 65 Text feature [neutral] present in test data point [True]
# 66 Text feature [mapk] present in test data point [True]
# 67 Text feature [ligand] present in test data point [True]
# 68 Text feature [autophosphorylation] present in test data point [True]
# 69 Text feature [harboring] present in test data point [True]
# 70 Text feature [inhibition] present in test data point [True]
# 71 Text feature [extracellular] present in test data point [True]
# 72 Text feature [dna] present in test data point [True]
# 75 Text feature [repair] present in test data point [True]
# 78 Text feature [survival] present in test data point [True]
# 81 Text feature [concentrations] present in test data point [True]
# 82 Text feature [transformation] present in test data point [True]
# 83 Text feature [ras] present in test data point [True]
# 84 Text feature [receptors] present in test data point [True]
# 86 Text feature [erk1] present in test data point [True]
# 92 Text feature [sensitivity] present in test data point [True]
# 94 Text feature [tkis] present in test data point [True]
# 95 Text feature [lines] present in test data point [True]
# 96 Text feature [kit] present in test data point [True]
# 97 Text feature [respond] present in test data point [True]
# 98 Text feature [mek] present in test data point [True]
# 99 Text feature [treated] present in test data point [True]
# Out of the top  100  features  71 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
rf_log_loss_train2 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
rf_log_loss_cv2 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
rf_log_loss_test2 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 1.9831012193229536
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.6690196395914778
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.572356056978827
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.6589891703307849
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.667380000406369
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.399446190778093
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.3968758797386411
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.619577430506644
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5267157131999256
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.4480106746121975
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.3394518441110959
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.6656219581015803
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.5529850845682935
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.444412077323425
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.3597307833113885
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.6607824134583489
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.5904506955587012
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.4928528476684868
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.3855078544124126
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.7206696164995743
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.5788341942603217
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5021662234932038
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.3607623052752003
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.7071696517024861
# For values of best alpha =  100 The train log loss is: 0.06809011288006735
# For values of best alpha =  100 The cross validation log loss is: 1.3394518441111953
# For values of best alpha =  100 The test log loss is: 1.3877073415048007

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.3394518441111456
# Number of mis-classified points : 0.4718045112781955
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0231 0.105  0.2864 0.0216 0.0328 0.037  0.3693 0.0735 0.0513]]
# Actual Class : 2
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 3
# Predicted Class Probabilities: [[0.0184 0.0781 0.4019 0.0185 0.0267 0.0301 0.3527 0.0444 0.0293]]
# Actual Class : 7
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

estimators =[('sig_clf1', sig_clf1),('sig_clf2',sig_clf2),('sig_clf3',sig_clf3)]

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(estimators=estimators,final_estimator=lr, stack_method='predict_proba')
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.10
# Support vector machines : Log Loss: 1.68
# Naive Bayes : Log Loss: 1.32
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 1.822
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.757
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.435
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.102
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.029
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.039

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=1)
sclf = StackingClassifier(estimators=estimators,final_estimator=lr, stack_method='predict_proba')
sclf.fit(train_x_onehotCoding, train_y)

log_error_train = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error_cv = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error_test = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 1.039234324904857
# Log loss (CV) on the stacking classifier : 1.039234324904857
# Log loss (test) on the stacking classifier : 1.039234324904857
# Number of missclassified point : 0.34135338345864663
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)

mvc_log_loss_train  = log_loss(train_y, vclf.predict_proba(train_x_onehotCoding))
mvc_log_loss_cv  = log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding))
mvc_log_loss_test  = log_loss(test_y, vclf.predict_proba(test_x_onehotCoding))

print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.8663460049882042
# Log loss (CV) on the VotingClassifier : 1.2174924374631744
# Log loss (test) on the VotingClassifier : 1.2047504835260767
# Number of missclassified point : 0.362406015037594
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h1>5. Assignments</h1>

# %% [markdown]
# <li> Apply All the models with tf-idf features (Replace CountVectorizer with tfidfVectorizer and run the same cells)</li>
# <li> Instead of using all the words in the dataset, use only the top 1000 words based of tf-idf values</li>

# %%
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000)
    var_count_vec = TfidfVectorizer(max_features=1000)
    text_count_vec = TfidfVectorizer(max_features=1000,min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# one-hot encoding of Gene feature.
gene_tfidf = TfidfVectorizer(max_features=1000)
train_gene_feature_onehotCoding_tfidf = gene_tfidf.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding_tfidf = gene_tfidf.transform(test_df['Gene'])
cv_gene_feature_onehotCoding_tfidf = gene_tfidf.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_tfidf = TfidfVectorizer(max_features=1000)
train_variation_feature_onehotCoding_tfidf = variation_tfidf.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding_tfidf = variation_tfidf.transform(test_df['Variation'])
cv_variation_feature_onehotCoding_tfidf = variation_tfidf.transform(cv_df['Variation'])

# %%
# building a TfidfVectorizer with all the words that occured minimum 3 times in train data
text_tfidf = TfidfVectorizer(max_features=1000)
train_text_feature_onehotCoding_tfidf = text_tfidf.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features_tfidf= text_tfidf.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts_tfidf = train_text_feature_onehotCoding_tfidf.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict_tfidf = dict(zip(list(train_text_features_tfidf),train_text_fea_counts_tfidf))


print("Total number of unique words in train data :", len(train_text_features_tfidf))
print('shape of train_text_feature_onehotCoding_tfidf ',train_text_feature_onehotCoding_tfidf.shape)
# Out:
# Total number of unique words in train data : 1000
# shape of train_text_feature_onehotCoding_tfidf  (2124, 1000)

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding_tfidf = normalize(train_text_feature_onehotCoding_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_tfidf = text_tfidf.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_tfidf = normalize(test_text_feature_onehotCoding_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_tfidf = text_tfidf.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_tfidf = normalize(cv_text_feature_onehotCoding_tfidf, axis=0)

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding_tfidf = hstack((train_gene_feature_onehotCoding_tfidf,train_variation_feature_onehotCoding_tfidf))
test_gene_var_onehotCoding_tfidf = hstack((test_gene_feature_onehotCoding_tfidf,test_variation_feature_onehotCoding_tfidf))
cv_gene_var_onehotCoding_tfidf = hstack((cv_gene_feature_onehotCoding_tfidf,cv_variation_feature_onehotCoding_tfidf))

train_x_onehotCoding_tfidf = hstack((train_gene_var_onehotCoding_tfidf, train_text_feature_onehotCoding_tfidf)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding_tfidf = hstack((test_gene_var_onehotCoding_tfidf, test_text_feature_onehotCoding_tfidf)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding_tfidf = hstack((cv_gene_var_onehotCoding_tfidf, cv_text_feature_onehotCoding_tfidf)).tocsr()
cv_y = np.array(list(cv_df['Class']))


print("One hot encoding features with tfidf:")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding_tfidf.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding_tfidf.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding_tfidf.shape)
# Out:
# One hot encoding features with tfidf:
# (number of data points * number of features) in train data =  (2124, 2227)
# (number of data points * number of features) in test data =  (665, 2227)
# (number of data points * number of features) in cross validation data = (532, 2227)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
nb_log_loss_train2 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
nb_log_loss_cv2 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
nb_log_loss_test2 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1781592571668564
# for alpha = 0.0001
# Log Loss : 1.1774095488364285
# for alpha = 0.001
# Log Loss : 1.1760349673130641
# for alpha = 0.1
# Log Loss : 1.1903555651948483
# for alpha = 1
# Log Loss : 1.215293166465865
# for alpha = 10
# Log Loss : 1.412770252716452
# for alpha = 100
# Log Loss : 1.4170818001233063
# for alpha = 1000
# Log Loss : 1.4145199856026758
# For values of best alpha =  0.001 The train log loss is: 0.7196945218499241
# For values of best alpha =  0.001 The cross validation log loss is: 1.1760349673130641
# For values of best alpha =  0.001 The test log loss is: 1.2036831340376948

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding_tfidf)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding_tfidf.toarray()))
# Out:
# Log Loss : 1.1760349673130641
# Number of missclassified point : 0.38721804511278196
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.059  0.0491 0.0156 0.057  0.0319 0.0331 0.7462 0.0041 0.0041]]
# Actual Class : 2
# --------------------------------------------------
# 16 Text feature [activation] present in test data point [True]
# 20 Text feature [cells] present in test data point [True]
# 27 Text feature [shown] present in test data point [True]
# 28 Text feature [also] present in test data point [True]
# 29 Text feature [cell] present in test data point [True]
# 30 Text feature [10] present in test data point [True]
# 32 Text feature [growth] present in test data point [True]
# 35 Text feature [similar] present in test data point [True]
# 38 Text feature [however] present in test data point [True]
# 42 Text feature [addition] present in test data point [True]
# 46 Text feature [previously] present in test data point [True]
# 48 Text feature [factor] present in test data point [True]
# 49 Text feature [may] present in test data point [True]
# 53 Text feature [3b] present in test data point [True]
# 55 Text feature [showed] present in test data point [True]
# 57 Text feature [activate] present in test data point [True]
# 66 Text feature [3a] present in test data point [True]
# 68 Text feature [found] present in test data point [True]
# 72 Text feature [fig] present in test data point [True]
# 75 Text feature [20] present in test data point [True]
# 76 Text feature [described] present in test data point [True]
# 78 Text feature [total] present in test data point [True]
# 79 Text feature [including] present in test data point [True]
# 81 Text feature [observed] present in test data point [True]
# 82 Text feature [different] present in test data point [True]
# 86 Text feature [using] present in test data point [True]
# 87 Text feature [results] present in test data point [True]
# 89 Text feature [respectively] present in test data point [True]
# 91 Text feature [12] present in test data point [True]
# 92 Text feature [15] present in test data point [True]
# 93 Text feature [two] present in test data point [True]
# 95 Text feature [figure] present in test data point [True]
# 96 Text feature [discussion] present in test data point [True]
# 99 Text feature [clinical] present in test data point [True]
# Out of the top  100  features  34 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0602 0.0536 0.0184 0.0582 0.0325 0.0338 0.7349 0.0041 0.0042]]
# Actual Class : 7
# --------------------------------------------------
# 16 Text feature [activation] present in test data point [True]
# 18 Text feature [activated] present in test data point [True]
# 19 Text feature [kinase] present in test data point [True]
# 20 Text feature [cells] present in test data point [True]
# 21 Text feature [downstream] present in test data point [True]
# 22 Text feature [inhibitor] present in test data point [True]
# 24 Text feature [expressing] present in test data point [True]
# 25 Text feature [contrast] present in test data point [True]
# 26 Text feature [independent] present in test data point [True]
# 27 Text feature [shown] present in test data point [True]
# 28 Text feature [also] present in test data point [True]
# 29 Text feature [cell] present in test data point [True]
# 30 Text feature [10] present in test data point [True]
# 31 Text feature [constitutive] present in test data point [True]
# 32 Text feature [growth] present in test data point [True]
# 33 Text feature [sensitive] present in test data point [True]
# 34 Text feature [treated] present in test data point [True]
# 35 Text feature [similar] present in test data point [True]
# 38 Text feature [however] present in test data point [True]
# 39 Text feature [compared] present in test data point [True]
# 40 Text feature [signaling] present in test data point [True]
# 41 Text feature [inhibitors] present in test data point [True]
# 42 Text feature [addition] present in test data point [True]
# 43 Text feature [treatment] present in test data point [True]
# 44 Text feature [well] present in test data point [True]
# 45 Text feature [constitutively] present in test data point [True]
# 46 Text feature [previously] present in test data point [True]
# 47 Text feature [mutations] present in test data point [True]
# 48 Text feature [factor] present in test data point [True]
# 49 Text feature [may] present in test data point [True]
# 50 Text feature [higher] present in test data point [True]
# 51 Text feature [presence] present in test data point [True]
# 52 Text feature [activating] present in test data point [True]
# 53 Text feature [3b] present in test data point [True]
# 54 Text feature [phosphorylation] present in test data point [True]
# 55 Text feature [showed] present in test data point [True]
# 56 Text feature [inhibition] present in test data point [True]
# 57 Text feature [activate] present in test data point [True]
# 58 Text feature [tyrosine] present in test data point [True]
# 59 Text feature [without] present in test data point [True]
# 60 Text feature [suggest] present in test data point [True]
# 61 Text feature [proliferation] present in test data point [True]
# 62 Text feature [although] present in test data point [True]
# 63 Text feature [increased] present in test data point [True]
# 64 Text feature [mutant] present in test data point [True]
# 65 Text feature [potential] present in test data point [True]
# 66 Text feature [3a] present in test data point [True]
# 67 Text feature [oncogenic] present in test data point [True]
# 68 Text feature [found] present in test data point [True]
# 73 Text feature [pathways] present in test data point [True]
# 74 Text feature [recently] present in test data point [True]
# 75 Text feature [20] present in test data point [True]
# 76 Text feature [described] present in test data point [True]
# 77 Text feature [inhibited] present in test data point [True]
# 78 Text feature [total] present in test data point [True]
# 79 Text feature [including] present in test data point [True]
# 80 Text feature [mutation] present in test data point [True]
# 81 Text feature [observed] present in test data point [True]
# 82 Text feature [different] present in test data point [True]
# 83 Text feature [mechanism] present in test data point [True]
# 84 Text feature [24] present in test data point [True]
# 85 Text feature [absence] present in test data point [True]
# 86 Text feature [using] present in test data point [True]
# 87 Text feature [results] present in test data point [True]
# 88 Text feature [either] present in test data point [True]
# 89 Text feature [respectively] present in test data point [True]
# 90 Text feature [consistent] present in test data point [True]
# 91 Text feature [12] present in test data point [True]
# 92 Text feature [15] present in test data point [True]
# 93 Text feature [two] present in test data point [True]
# 94 Text feature [previous] present in test data point [True]
# 95 Text feature [figure] present in test data point [True]
# 96 Text feature [discussion] present in test data point [True]
# 97 Text feature [active] present in test data point [True]
# 98 Text feature [therapeutic] present in test data point [True]
# 99 Text feature [clinical] present in test data point [True]
# Out of the top  100  features  76 are present in query point

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
lr_log_loss_train12 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
lr_log_loss_cv12 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
lr_log_loss_test12 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1923289700264739
# for alpha = 1e-05
# Log Loss : 1.0574633112223817
# for alpha = 0.0001
# Log Loss : 0.9919241165571845
# for alpha = 0.001
# Log Loss : 1.0212010286759845
# for alpha = 0.01
# Log Loss : 1.2316366194000619
# for alpha = 0.1
# Log Loss : 1.6551760854330704
# for alpha = 1
# Log Loss : 1.795691065867027
# for alpha = 10
# Log Loss : 1.8121222300292956
# for alpha = 100
# Log Loss : 1.8139706326247753
# For values of best alpha =  0.0001 The train log loss is: 0.5418962868552746
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9919241165571845
# For values of best alpha =  0.0001 The test log loss is: 1.018164298141385

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y, cv_x_onehotCoding_tfidf, cv_y, clf)
# Out:
# Log loss : 0.9919241165571845
# Number of mis-classified points : 0.325187969924812
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding_tfidf.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0661 0.0785 0.0016 0.03   0.0076 0.0012 0.8062 0.0079 0.0009]]
# Actual Class : 2
# --------------------------------------------------
# 19 Text feature [activation] present in test data point [True]
# 39 Text feature [3t3] present in test data point [True]
# 43 Text feature [3b] present in test data point [True]
# 44 Text feature [2a] present in test data point [True]
# 46 Text feature [approximately] present in test data point [True]
# 50 Text feature [activate] present in test data point [True]
# 71 Text feature [bone] present in test data point [True]
# 108 Text feature [malignant] present in test data point [True]
# 155 Text feature [2b] present in test data point [True]
# 156 Text feature [factors] present in test data point [True]
# 180 Text feature [3a] present in test data point [True]
# 218 Text feature [total] present in test data point [True]
# 220 Text feature [form] present in test data point [True]
# 223 Text feature [previously] present in test data point [True]
# 236 Text feature [adenocarcinoma] present in test data point [True]
# 237 Text feature [factor] present in test data point [True]
# 252 Text feature [common] present in test data point [True]
# 285 Text feature [obtained] present in test data point [True]
# 286 Text feature [cells] present in test data point [True]
# 303 Text feature [positive] present in test data point [True]
# 318 Text feature [22] present in test data point [True]
# 320 Text feature [72] present in test data point [True]
# 334 Text feature [transcription] present in test data point [True]
# 344 Text feature [tumors] present in test data point [True]
# 374 Text feature [fig] present in test data point [True]
# 375 Text feature [cdna] present in test data point [True]
# 376 Text feature [tumor] present in test data point [True]
# 390 Text feature [biochemical] present in test data point [True]
# 399 Text feature [like] present in test data point [True]
# 405 Text feature [tissue] present in test data point [True]
# 411 Text feature [14] present in test data point [True]
# 424 Text feature [respectively] present in test data point [True]
# 434 Text feature [kit] present in test data point [True]
# 446 Text feature [materials] present in test data point [True]
# 450 Text feature [vector] present in test data point [True]
# 451 Text feature [lines] present in test data point [True]
# 469 Text feature [blot] present in test data point [True]
# 474 Text feature [features] present in test data point [True]
# 485 Text feature [represent] present in test data point [True]
# 488 Text feature [showed] present in test data point [True]
# 491 Text feature [reverse] present in test data point [True]
# 492 Text feature [numbers] present in test data point [True]
# 495 Text feature [specific] present in test data point [True]
# Out of the top  500  features  43 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0103 0.0426 0.0219 0.0131 0.0081 0.0044 0.892  0.0046 0.003 ]]
# Actual Class : 7
# --------------------------------------------------
# 6 Text feature [downstream] present in test data point [True]
# 7 Text feature [insertion] present in test data point [True]
# 14 Text feature [activated] present in test data point [True]
# 15 Text feature [codon] present in test data point [True]
# 17 Text feature [inhibited] present in test data point [True]
# 19 Text feature [activation] present in test data point [True]
# 31 Text feature [constitutive] present in test data point [True]
# 34 Text feature [inhibitor] present in test data point [True]
# 35 Text feature [oncogene] present in test data point [True]
# 37 Text feature [ligand] present in test data point [True]
# 38 Text feature [overexpression] present in test data point [True]
# 43 Text feature [3b] present in test data point [True]
# 44 Text feature [2a] present in test data point [True]
# 46 Text feature [approximately] present in test data point [True]
# 50 Text feature [activate] present in test data point [True]
# 51 Text feature [itd] present in test data point [True]
# 52 Text feature [src] present in test data point [True]
# 57 Text feature [express] present in test data point [True]
# 61 Text feature [size] present in test data point [True]
# 64 Text feature [specimens] present in test data point [True]
# 67 Text feature [mapk] present in test data point [True]
# 71 Text feature [bone] present in test data point [True]
# 72 Text feature [versus] present in test data point [True]
# 76 Text feature [pathways] present in test data point [True]
# 81 Text feature [enhanced] present in test data point [True]
# 91 Text feature [days] present in test data point [True]
# 98 Text feature [61] present in test data point [True]
# 100 Text feature [provided] present in test data point [True]
# 101 Text feature [without] present in test data point [True]
# 102 Text feature [per] present in test data point [True]
# 104 Text feature [75] present in test data point [True]
# 106 Text feature [potent] present in test data point [True]
# 107 Text feature [signaling] present in test data point [True]
# 108 Text feature [malignant] present in test data point [True]
# 114 Text feature [tyrosine] present in test data point [True]
# 118 Text feature [phosphorylated] present in test data point [True]
# 119 Text feature [expressing] present in test data point [True]
# 120 Text feature [transformation] present in test data point [True]
# 123 Text feature [transforming] present in test data point [True]
# 125 Text feature [concentrations] present in test data point [True]
# 129 Text feature [presence] present in test data point [True]
# 131 Text feature [oncogenic] present in test data point [True]
# 136 Text feature [occur] present in test data point [True]
# 143 Text feature [high] present in test data point [True]
# 147 Text feature [raf] present in test data point [True]
# 150 Text feature [hours] present in test data point [True]
# 152 Text feature [ras] present in test data point [True]
# 155 Text feature [2b] present in test data point [True]
# 156 Text feature [factors] present in test data point [True]
# 157 Text feature [000] present in test data point [True]
# 158 Text feature [pdgfr] present in test data point [True]
# 164 Text feature [calculated] present in test data point [True]
# 167 Text feature [erk] present in test data point [True]
# 175 Text feature [mutant] present in test data point [True]
# 177 Text feature [distinct] present in test data point [True]
# 180 Text feature [3a] present in test data point [True]
# 181 Text feature [combination] present in test data point [True]
# 187 Text feature [leading] present in test data point [True]
# 201 Text feature [stably] present in test data point [True]
# 208 Text feature [tissues] present in test data point [True]
# 210 Text feature [cultured] present in test data point [True]
# 212 Text feature [constitutively] present in test data point [True]
# 217 Text feature [increased] present in test data point [True]
# 218 Text feature [total] present in test data point [True]
# 220 Text feature [form] present in test data point [True]
# 223 Text feature [previously] present in test data point [True]
# 225 Text feature [caused] present in test data point [True]
# 228 Text feature [sites] present in test data point [True]
# 229 Text feature [sensitive] present in test data point [True]
# 237 Text feature [factor] present in test data point [True]
# 240 Text feature [genomic] present in test data point [True]
# 242 Text feature [derived] present in test data point [True]
# 245 Text feature [contrast] present in test data point [True]
# 252 Text feature [common] present in test data point [True]
# 255 Text feature [properties] present in test data point [True]
# 256 Text feature [suggest] present in test data point [True]
# 261 Text feature [receptors] present in test data point [True]
# 267 Text feature [bp] present in test data point [True]
# 270 Text feature [blood] present in test data point [True]
# 272 Text feature [mechanisms] present in test data point [True]
# 273 Text feature [fraction] present in test data point [True]
# 274 Text feature [prior] present in test data point [True]
# 276 Text feature [proliferation] present in test data point [True]
# 285 Text feature [obtained] present in test data point [True]
# 286 Text feature [cells] present in test data point [True]
# 287 Text feature [fold] present in test data point [True]
# 289 Text feature [open] present in test data point [True]
# 295 Text feature [2000] present in test data point [True]
# 298 Text feature [kinases] present in test data point [True]
# 302 Text feature [24] present in test data point [True]
# 303 Text feature [positive] present in test data point [True]
# 314 Text feature [added] present in test data point [True]
# 317 Text feature [52] present in test data point [True]
# 318 Text feature [22] present in test data point [True]
# 320 Text feature [72] present in test data point [True]
# 322 Text feature [coding] present in test data point [True]
# 329 Text feature [2002] present in test data point [True]
# 333 Text feature [clones] present in test data point [True]
# 334 Text feature [transcription] present in test data point [True]
# 336 Text feature [somatic] present in test data point [True]
# 342 Text feature [ph] present in test data point [True]
# 344 Text feature [tumors] present in test data point [True]
# 352 Text feature [www] present in test data point [True]
# 358 Text feature [mm] present in test data point [True]
# 362 Text feature [examined] present in test data point [True]
# 363 Text feature [greater] present in test data point [True]
# 367 Text feature [membrane] present in test data point [True]
# 375 Text feature [cdna] present in test data point [True]
# 377 Text feature [increase] present in test data point [True]
# 379 Text feature [gain] present in test data point [True]
# 386 Text feature [strongly] present in test data point [True]
# 388 Text feature [regulated] present in test data point [True]
# 391 Text feature [colony] present in test data point [True]
# 393 Text feature [constructs] present in test data point [True]
# 395 Text feature [gfp] present in test data point [True]
# 399 Text feature [like] present in test data point [True]
# 401 Text feature [various] present in test data point [True]
# 402 Text feature [use] present in test data point [True]
# 404 Text feature [double] present in test data point [True]
# 405 Text feature [tissue] present in test data point [True]
# 409 Text feature [mutants] present in test data point [True]
# 411 Text feature [14] present in test data point [True]
# 412 Text feature [extracellular] present in test data point [True]
# 415 Text feature [fact] present in test data point [True]
# 416 Text feature [org] present in test data point [True]
# 418 Text feature [initial] present in test data point [True]
# 420 Text feature [1a] present in test data point [True]
# 421 Text feature [leukemia] present in test data point [True]
# 422 Text feature [higher] present in test data point [True]
# 424 Text feature [respectively] present in test data point [True]
# 427 Text feature [observations] present in test data point [True]
# 429 Text feature [medium] present in test data point [True]
# 431 Text feature [51] present in test data point [True]
# 432 Text feature [note] present in test data point [True]
# 434 Text feature [kit] present in test data point [True]
# 437 Text feature [colonies] present in test data point [True]
# 445 Text feature [end] present in test data point [True]
# 446 Text feature [materials] present in test data point [True]
# 448 Text feature [phosphorylation] present in test data point [True]
# 450 Text feature [vector] present in test data point [True]
# 451 Text feature [lines] present in test data point [True]
# 454 Text feature [additional] present in test data point [True]
# 458 Text feature [green] present in test data point [True]
# 460 Text feature [induction] present in test data point [True]
# 461 Text feature [serum] present in test data point [True]
# 463 Text feature [leads] present in test data point [True]
# 467 Text feature [forms] present in test data point [True]
# 468 Text feature [signals] present in test data point [True]
# 469 Text feature [blot] present in test data point [True]
# 470 Text feature [culture] present in test data point [True]
# 473 Text feature [jak2] present in test data point [True]
# 474 Text feature [features] present in test data point [True]
# 478 Text feature [de] present in test data point [True]
# 479 Text feature [mechanism] present in test data point [True]
# 482 Text feature [displayed] present in test data point [True]
# 483 Text feature [59] present in test data point [True]
# 484 Text feature [free] present in test data point [True]
# 485 Text feature [represent] present in test data point [True]
# 487 Text feature [wt] present in test data point [True]
# 488 Text feature [showed] present in test data point [True]
# 491 Text feature [reverse] present in test data point [True]
# 492 Text feature [numbers] present in test data point [True]
# 495 Text feature [specific] present in test data point [True]
# 497 Text feature [position] present in test data point [True]
# 499 Text feature [dose] present in test data point [True]
# Out of the top  500  features  165 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
lr_log_loss_train22 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
lr_log_loss_cv22 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
lr_log_loss_test22 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2138245188542607
# for alpha = 1e-05
# Log Loss : 1.0888865679811723
# for alpha = 0.0001
# Log Loss : 1.0101168874317024
# for alpha = 0.001
# Log Loss : 1.0873272113239025
# for alpha = 0.01
# Log Loss : 1.3950558534304354
# for alpha = 0.1
# Log Loss : 1.7689625323608569
# for alpha = 1
# Log Loss : 1.8587428867963798
# For values of best alpha =  0.0001 The train log loss is: 0.5312557252184251
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0101168874317024
# For values of best alpha =  0.0001 The test log loss is: 1.030731463007708

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y, cv_x_onehotCoding_tfidf, cv_y, clf)
# Out:
# Log loss : 1.0101168874317024
# Number of mis-classified points : 0.32706766917293234
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_tfidf,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0663 0.0852 0.0013 0.0207 0.007  0.0014 0.8121 0.0049 0.0011]]
# Actual Class : 2
# --------------------------------------------------
# 25 Text feature [approximately] present in test data point [True]
# 30 Text feature [activation] present in test data point [True]
# 35 Text feature [3b] present in test data point [True]
# 42 Text feature [2a] present in test data point [True]
# 58 Text feature [3t3] present in test data point [True]
# 62 Text feature [activate] present in test data point [True]
# 89 Text feature [bone] present in test data point [True]
# 118 Text feature [malignant] present in test data point [True]
# 147 Text feature [factors] present in test data point [True]
# 149 Text feature [2b] present in test data point [True]
# 160 Text feature [previously] present in test data point [True]
# 170 Text feature [form] present in test data point [True]
# 184 Text feature [3a] present in test data point [True]
# 189 Text feature [common] present in test data point [True]
# 240 Text feature [adenocarcinoma] present in test data point [True]
# 241 Text feature [total] present in test data point [True]
# 250 Text feature [factor] present in test data point [True]
# 258 Text feature [obtained] present in test data point [True]
# 260 Text feature [positive] present in test data point [True]
# 266 Text feature [22] present in test data point [True]
# 281 Text feature [transcription] present in test data point [True]
# 318 Text feature [cells] present in test data point [True]
# 321 Text feature [like] present in test data point [True]
# 332 Text feature [tumor] present in test data point [True]
# 363 Text feature [72] present in test data point [True]
# 364 Text feature [respectively] present in test data point [True]
# 367 Text feature [fig] present in test data point [True]
# 377 Text feature [materials] present in test data point [True]
# 383 Text feature [biochemical] present in test data point [True]
# 392 Text feature [blot] present in test data point [True]
# 395 Text feature [cdna] present in test data point [True]
# 397 Text feature [tissue] present in test data point [True]
# 410 Text feature [numbers] present in test data point [True]
# 422 Text feature [tumors] present in test data point [True]
# 430 Text feature [specific] present in test data point [True]
# 431 Text feature [kit] present in test data point [True]
# 434 Text feature [represent] present in test data point [True]
# 440 Text feature [developed] present in test data point [True]
# 479 Text feature [vector] present in test data point [True]
# 480 Text feature [features] present in test data point [True]
# 489 Text feature [showed] present in test data point [True]
# Out of the top  500  features  41 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0093 0.045  0.0281 0.0118 0.0076 0.0047 0.8872 0.0042 0.0021]]
# Actual Class : 7
# --------------------------------------------------
# 5 Text feature [downstream] present in test data point [True]
# 9 Text feature [insertion] present in test data point [True]
# 11 Text feature [codon] present in test data point [True]
# 14 Text feature [inhibited] present in test data point [True]
# 23 Text feature [activated] present in test data point [True]
# 25 Text feature [approximately] present in test data point [True]
# 30 Text feature [activation] present in test data point [True]
# 32 Text feature [ligand] present in test data point [True]
# 34 Text feature [inhibitor] present in test data point [True]
# 35 Text feature [3b] present in test data point [True]
# 42 Text feature [2a] present in test data point [True]
# 49 Text feature [oncogene] present in test data point [True]
# 50 Text feature [overexpression] present in test data point [True]
# 54 Text feature [constitutive] present in test data point [True]
# 57 Text feature [itd] present in test data point [True]
# 60 Text feature [express] present in test data point [True]
# 62 Text feature [activate] present in test data point [True]
# 63 Text feature [size] present in test data point [True]
# 72 Text feature [src] present in test data point [True]
# 83 Text feature [enhanced] present in test data point [True]
# 86 Text feature [versus] present in test data point [True]
# 89 Text feature [bone] present in test data point [True]
# 92 Text feature [provided] present in test data point [True]
# 94 Text feature [high] present in test data point [True]
# 95 Text feature [specimens] present in test data point [True]
# 97 Text feature [75] present in test data point [True]
# 98 Text feature [per] present in test data point [True]
# 101 Text feature [without] present in test data point [True]
# 102 Text feature [mapk] present in test data point [True]
# 104 Text feature [phosphorylated] present in test data point [True]
# 105 Text feature [61] present in test data point [True]
# 107 Text feature [occur] present in test data point [True]
# 111 Text feature [pathways] present in test data point [True]
# 112 Text feature [presence] present in test data point [True]
# 117 Text feature [days] present in test data point [True]
# 118 Text feature [malignant] present in test data point [True]
# 119 Text feature [calculated] present in test data point [True]
# 121 Text feature [potent] present in test data point [True]
# 124 Text feature [raf] present in test data point [True]
# 128 Text feature [signaling] present in test data point [True]
# 136 Text feature [concentrations] present in test data point [True]
# 140 Text feature [distinct] present in test data point [True]
# 143 Text feature [000] present in test data point [True]
# 147 Text feature [factors] present in test data point [True]
# 148 Text feature [tyrosine] present in test data point [True]
# 149 Text feature [2b] present in test data point [True]
# 150 Text feature [expressing] present in test data point [True]
# 154 Text feature [genomic] present in test data point [True]
# 158 Text feature [mutant] present in test data point [True]
# 160 Text feature [previously] present in test data point [True]
# 163 Text feature [sites] present in test data point [True]
# 164 Text feature [bp] present in test data point [True]
# 165 Text feature [hours] present in test data point [True]
# 167 Text feature [tissues] present in test data point [True]
# 170 Text feature [form] present in test data point [True]
# 172 Text feature [2002] present in test data point [True]
# 182 Text feature [oncogenic] present in test data point [True]
# 184 Text feature [3a] present in test data point [True]
# 185 Text feature [increased] present in test data point [True]
# 186 Text feature [caused] present in test data point [True]
# 189 Text feature [common] present in test data point [True]
# 192 Text feature [cultured] present in test data point [True]
# 193 Text feature [transforming] present in test data point [True]
# 194 Text feature [fraction] present in test data point [True]
# 200 Text feature [sensitive] present in test data point [True]
# 206 Text feature [suggest] present in test data point [True]
# 210 Text feature [ras] present in test data point [True]
# 213 Text feature [transformation] present in test data point [True]
# 215 Text feature [2000] present in test data point [True]
# 216 Text feature [erk] present in test data point [True]
# 222 Text feature [prior] present in test data point [True]
# 223 Text feature [greater] present in test data point [True]
# 226 Text feature [derived] present in test data point [True]
# 230 Text feature [pdgfr] present in test data point [True]
# 231 Text feature [leading] present in test data point [True]
# 241 Text feature [total] present in test data point [True]
# 245 Text feature [fold] present in test data point [True]
# 250 Text feature [factor] present in test data point [True]
# 254 Text feature [blood] present in test data point [True]
# 255 Text feature [stably] present in test data point [True]
# 258 Text feature [obtained] present in test data point [True]
# 260 Text feature [positive] present in test data point [True]
# 263 Text feature [coding] present in test data point [True]
# 265 Text feature [contrast] present in test data point [True]
# 266 Text feature [22] present in test data point [True]
# 277 Text feature [constructs] present in test data point [True]
# 281 Text feature [transcription] present in test data point [True]
# 287 Text feature [somatic] present in test data point [True]
# 289 Text feature [24] present in test data point [True]
# 291 Text feature [combination] present in test data point [True]
# 296 Text feature [constitutively] present in test data point [True]
# 298 Text feature [properties] present in test data point [True]
# 301 Text feature [note] present in test data point [True]
# 303 Text feature [ph] present in test data point [True]
# 305 Text feature [increase] present in test data point [True]
# 313 Text feature [gfp] present in test data point [True]
# 314 Text feature [use] present in test data point [True]
# 315 Text feature [52] present in test data point [True]
# 317 Text feature [added] present in test data point [True]
# 318 Text feature [cells] present in test data point [True]
# 320 Text feature [examined] present in test data point [True]
# 321 Text feature [like] present in test data point [True]
# 322 Text feature [kinases] present in test data point [True]
# 331 Text feature [receptors] present in test data point [True]
# 337 Text feature [strongly] present in test data point [True]
# 338 Text feature [membrane] present in test data point [True]
# 342 Text feature [proliferation] present in test data point [True]
# 345 Text feature [mm] present in test data point [True]
# 346 Text feature [mechanisms] present in test data point [True]
# 351 Text feature [www] present in test data point [True]
# 354 Text feature [mutants] present in test data point [True]
# 359 Text feature [dose] present in test data point [True]
# 363 Text feature [72] present in test data point [True]
# 364 Text feature [respectively] present in test data point [True]
# 370 Text feature [initial] present in test data point [True]
# 376 Text feature [higher] present in test data point [True]
# 377 Text feature [materials] present in test data point [True]
# 379 Text feature [extracellular] present in test data point [True]
# 380 Text feature [clones] present in test data point [True]
# 382 Text feature [various] present in test data point [True]
# 389 Text feature [additional] present in test data point [True]
# 390 Text feature [regulated] present in test data point [True]
# 392 Text feature [blot] present in test data point [True]
# 395 Text feature [cdna] present in test data point [True]
# 397 Text feature [tissue] present in test data point [True]
# 399 Text feature [fact] present in test data point [True]
# 405 Text feature [colonies] present in test data point [True]
# 406 Text feature [jak2] present in test data point [True]
# 407 Text feature [gain] present in test data point [True]
# 408 Text feature [colony] present in test data point [True]
# 410 Text feature [numbers] present in test data point [True]
# 411 Text feature [org] present in test data point [True]
# 412 Text feature [forms] present in test data point [True]
# 414 Text feature [open] present in test data point [True]
# 417 Text feature [1a] present in test data point [True]
# 421 Text feature [green] present in test data point [True]
# 422 Text feature [tumors] present in test data point [True]
# 425 Text feature [signals] present in test data point [True]
# 426 Text feature [series] present in test data point [True]
# 430 Text feature [specific] present in test data point [True]
# 431 Text feature [kit] present in test data point [True]
# 434 Text feature [represent] present in test data point [True]
# 436 Text feature [wt] present in test data point [True]
# 437 Text feature [observations] present in test data point [True]
# 438 Text feature [49] present in test data point [True]
# 439 Text feature [59] present in test data point [True]
# 440 Text feature [developed] present in test data point [True]
# 443 Text feature [de] present in test data point [True]
# 446 Text feature [end] present in test data point [True]
# 447 Text feature [displayed] present in test data point [True]
# 451 Text feature [medium] present in test data point [True]
# 461 Text feature [double] present in test data point [True]
# 462 Text feature [leukemia] present in test data point [True]
# 465 Text feature [induction] present in test data point [True]
# 466 Text feature [51] present in test data point [True]
# 473 Text feature [consistent] present in test data point [True]
# 475 Text feature [phosphorylation] present in test data point [True]
# 479 Text feature [vector] present in test data point [True]
# 480 Text feature [features] present in test data point [True]
# 488 Text feature [plasma] present in test data point [True]
# 489 Text feature [showed] present in test data point [True]
# 490 Text feature [levels] present in test data point [True]
# 493 Text feature [demonstrated] present in test data point [True]
# 495 Text feature [free] present in test data point [True]
# 497 Text feature [leads] present in test data point [True]
# 498 Text feature [well] present in test data point [True]
# Out of the top  500  features  166 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
svm_log_loss_train12 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
svm_log_loss_cv12 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
svm_log_loss_test12 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1714571096892636
# for C = 0.0001
# Log Loss : 1.1296420542712924
# for C = 0.001
# Log Loss : 1.1101374278039535
# for C = 0.01
# Log Loss : 1.40626407598636
# for C = 0.1
# Log Loss : 1.680134662251638
# for C = 1
# Log Loss : 1.814477937019332
# for C = 10
# Log Loss : 1.8144773247202999
# for C = 100
# Log Loss : 1.8144310611916485
# For values of best alpha =  0.001 The train log loss is: 0.8047885514121019
# For values of best alpha =  0.001 The cross validation log loss is: 1.1101374278039535
# For values of best alpha =  0.001 The test log loss is: 1.1410979655228277

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y,cv_x_onehotCoding_tfidf,cv_y, clf)
# Out:
# Log loss : 1.1101374278039535
# Number of mis-classified points : 0.35150375939849626
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding_tfidf,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.077  0.0841 0.0046 0.0736 0.0165 0.0028 0.7323 0.0059 0.0032]]
# Actual Class : 2
# --------------------------------------------------
# 28 Text feature [activation] present in test data point [True]
# 41 Text feature [activate] present in test data point [True]
# 43 Text feature [2a] present in test data point [True]
# 47 Text feature [3b] present in test data point [True]
# 49 Text feature [approximately] present in test data point [True]
# 54 Text feature [factors] present in test data point [True]
# 65 Text feature [3t3] present in test data point [True]
# 66 Text feature [bone] present in test data point [True]
# 67 Text feature [2b] present in test data point [True]
# 224 Text feature [3a] present in test data point [True]
# 227 Text feature [factor] present in test data point [True]
# 228 Text feature [previously] present in test data point [True]
# 238 Text feature [malignant] present in test data point [True]
# 239 Text feature [represent] present in test data point [True]
# 260 Text feature [transcription] present in test data point [True]
# 280 Text feature [form] present in test data point [True]
# 281 Text feature [22] present in test data point [True]
# 283 Text feature [like] present in test data point [True]
# 284 Text feature [cells] present in test data point [True]
# 288 Text feature [numbers] present in test data point [True]
# 304 Text feature [adenocarcinoma] present in test data point [True]
# 307 Text feature [common] present in test data point [True]
# 325 Text feature [showed] present in test data point [True]
# 338 Text feature [positive] present in test data point [True]
# 341 Text feature [found] present in test data point [True]
# 343 Text feature [kit] present in test data point [True]
# 345 Text feature [blot] present in test data point [True]
# 355 Text feature [total] present in test data point [True]
# 359 Text feature [cdna] present in test data point [True]
# 366 Text feature [specific] present in test data point [True]
# 370 Text feature [may] present in test data point [True]
# 378 Text feature [obtained] present in test data point [True]
# 382 Text feature [nih] present in test data point [True]
# 403 Text feature [characteristics] present in test data point [True]
# 405 Text feature [72] present in test data point [True]
# 406 Text feature [five] present in test data point [True]
# 410 Text feature [reverse] present in test data point [True]
# 411 Text feature [domain] present in test data point [True]
# 434 Text feature [primer] present in test data point [True]
# 436 Text feature [fig] present in test data point [True]
# 438 Text feature [lines] present in test data point [True]
# 449 Text feature [vector] present in test data point [True]
# 454 Text feature [14] present in test data point [True]
# 456 Text feature [tumors] present in test data point [True]
# 464 Text feature [strong] present in test data point [True]
# 470 Text feature [cell] present in test data point [True]
# 486 Text feature [biochemical] present in test data point [True]
# 489 Text feature [1996] present in test data point [True]
# 490 Text feature [signal] present in test data point [True]
# 492 Text feature [growth] present in test data point [True]
# 496 Text feature [structures] present in test data point [True]
# 497 Text feature [respectively] present in test data point [True]
# 499 Text feature [tumor] present in test data point [True]
# Out of the top  500  features  53 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0527 0.051  0.0109 0.0765 0.03   0.0134 0.7569 0.0042 0.0045]]
# Actual Class : 7
# --------------------------------------------------
# 17 Text feature [codon] present in test data point [True]
# 20 Text feature [downstream] present in test data point [True]
# 21 Text feature [inhibited] present in test data point [True]
# 24 Text feature [activated] present in test data point [True]
# 28 Text feature [activation] present in test data point [True]
# 29 Text feature [insertion] present in test data point [True]
# 30 Text feature [constitutive] present in test data point [True]
# 35 Text feature [ligand] present in test data point [True]
# 41 Text feature [activate] present in test data point [True]
# 43 Text feature [2a] present in test data point [True]
# 47 Text feature [3b] present in test data point [True]
# 48 Text feature [phosphorylated] present in test data point [True]
# 49 Text feature [approximately] present in test data point [True]
# 51 Text feature [raf] present in test data point [True]
# 54 Text feature [factors] present in test data point [True]
# 55 Text feature [erk] present in test data point [True]
# 56 Text feature [inhibitor] present in test data point [True]
# 58 Text feature [sensitive] present in test data point [True]
# 60 Text feature [oncogene] present in test data point [True]
# 61 Text feature [src] present in test data point [True]
# 63 Text feature [versus] present in test data point [True]
# 64 Text feature [without] present in test data point [True]
# 66 Text feature [bone] present in test data point [True]
# 67 Text feature [2b] present in test data point [True]
# 68 Text feature [prior] present in test data point [True]
# 69 Text feature [constitutively] present in test data point [True]
# 70 Text feature [concentrations] present in test data point [True]
# 81 Text feature [size] present in test data point [True]
# 83 Text feature [overexpression] present in test data point [True]
# 84 Text feature [high] present in test data point [True]
# 85 Text feature [75] present in test data point [True]
# 86 Text feature [express] present in test data point [True]
# 87 Text feature [mutant] present in test data point [True]
# 138 Text feature [hours] present in test data point [True]
# 139 Text feature [signaling] present in test data point [True]
# 141 Text feature [fold] present in test data point [True]
# 176 Text feature [000] present in test data point [True]
# 194 Text feature [occur] present in test data point [True]
# 195 Text feature [presence] present in test data point [True]
# 196 Text feature [61] present in test data point [True]
# 197 Text feature [enhanced] present in test data point [True]
# 204 Text feature [added] present in test data point [True]
# 205 Text feature [ph] present in test data point [True]
# 206 Text feature [24] present in test data point [True]
# 207 Text feature [combination] present in test data point [True]
# 208 Text feature [provided] present in test data point [True]
# 209 Text feature [suggest] present in test data point [True]
# 210 Text feature [calculated] present in test data point [True]
# 213 Text feature [gain] present in test data point [True]
# 214 Text feature [pathways] present in test data point [True]
# 222 Text feature [tyrosine] present in test data point [True]
# 223 Text feature [expressing] present in test data point [True]
# 224 Text feature [3a] present in test data point [True]
# 225 Text feature [mapk] present in test data point [True]
# 226 Text feature [transformation] present in test data point [True]
# 227 Text feature [factor] present in test data point [True]
# 228 Text feature [previously] present in test data point [True]
# 229 Text feature [transforming] present in test data point [True]
# 235 Text feature [properties] present in test data point [True]
# 236 Text feature [52] present in test data point [True]
# 237 Text feature [fraction] present in test data point [True]
# 238 Text feature [malignant] present in test data point [True]
# 239 Text feature [represent] present in test data point [True]
# 240 Text feature [proliferation] present in test data point [True]
# 241 Text feature [mutants] present in test data point [True]
# 242 Text feature [wt] present in test data point [True]
# 244 Text feature [ras] present in test data point [True]
# 245 Text feature [independent] present in test data point [True]
# 246 Text feature [akt] present in test data point [True]
# 247 Text feature [per] present in test data point [True]
# 256 Text feature [oncogenic] present in test data point [True]
# 257 Text feature [additional] present in test data point [True]
# 258 Text feature [days] present in test data point [True]
# 259 Text feature [constructs] present in test data point [True]
# 260 Text feature [transcription] present in test data point [True]
# 261 Text feature [mechanisms] present in test data point [True]
# 263 Text feature [itd] present in test data point [True]
# 264 Text feature [specimens] present in test data point [True]
# 275 Text feature [increased] present in test data point [True]
# 279 Text feature [phosphorylation] present in test data point [True]
# 280 Text feature [form] present in test data point [True]
# 281 Text feature [22] present in test data point [True]
# 282 Text feature [receptors] present in test data point [True]
# 283 Text feature [like] present in test data point [True]
# 284 Text feature [cells] present in test data point [True]
# 286 Text feature [leading] present in test data point [True]
# 288 Text feature [numbers] present in test data point [True]
# 289 Text feature [distinct] present in test data point [True]
# 296 Text feature [leukemia] present in test data point [True]
# 300 Text feature [examined] present in test data point [True]
# 301 Text feature [regulated] present in test data point [True]
# 302 Text feature [stably] present in test data point [True]
# 303 Text feature [gfp] present in test data point [True]
# 307 Text feature [common] present in test data point [True]
# 320 Text feature [mm] present in test data point [True]
# 321 Text feature [www] present in test data point [True]
# 322 Text feature [51] present in test data point [True]
# 325 Text feature [showed] present in test data point [True]
# 326 Text feature [tissues] present in test data point [True]
# 327 Text feature [colony] present in test data point [True]
# 328 Text feature [caused] present in test data point [True]
# 329 Text feature [derived] present in test data point [True]
# 330 Text feature [genomic] present in test data point [True]
# 338 Text feature [positive] present in test data point [True]
# 339 Text feature [inhibition] present in test data point [True]
# 340 Text feature [cultured] present in test data point [True]
# 341 Text feature [found] present in test data point [True]
# 342 Text feature [observations] present in test data point [True]
# 343 Text feature [kit] present in test data point [True]
# 344 Text feature [strongly] present in test data point [True]
# 345 Text feature [blot] present in test data point [True]
# 346 Text feature [sensitivity] present in test data point [True]
# 347 Text feature [ba] present in test data point [True]
# 348 Text feature [induction] present in test data point [True]
# 349 Text feature [bp] present in test data point [True]
# 355 Text feature [total] present in test data point [True]
# 356 Text feature [signals] present in test data point [True]
# 357 Text feature [potent] present in test data point [True]
# 358 Text feature [f3] present in test data point [True]
# 359 Text feature [cdna] present in test data point [True]
# 361 Text feature [effective] present in test data point [True]
# 362 Text feature [medium] present in test data point [True]
# 363 Text feature [mechanism] present in test data point [True]
# 365 Text feature [green] present in test data point [True]
# 366 Text feature [specific] present in test data point [True]
# 368 Text feature [2000] present in test data point [True]
# 370 Text feature [may] present in test data point [True]
# 378 Text feature [obtained] present in test data point [True]
# 379 Text feature [activating] present in test data point [True]
# 383 Text feature [contrast] present in test data point [True]
# 384 Text feature [normalized] present in test data point [True]
# 385 Text feature [end] present in test data point [True]
# 386 Text feature [serum] present in test data point [True]
# 401 Text feature [pi3k] present in test data point [True]
# 402 Text feature [sites] present in test data point [True]
# 403 Text feature [characteristics] present in test data point [True]
# 405 Text feature [72] present in test data point [True]
# 406 Text feature [five] present in test data point [True]
# 408 Text feature [49] present in test data point [True]
# 410 Text feature [reverse] present in test data point [True]
# 411 Text feature [domain] present in test data point [True]
# 412 Text feature [org] present in test data point [True]
# 414 Text feature [1a] present in test data point [True]
# 415 Text feature [somatic] present in test data point [True]
# 431 Text feature [blood] present in test data point [True]
# 432 Text feature [higher] present in test data point [True]
# 433 Text feature [2002] present in test data point [True]
# 434 Text feature [primer] present in test data point [True]
# 435 Text feature [although] present in test data point [True]
# 437 Text feature [contribute] present in test data point [True]
# 438 Text feature [lines] present in test data point [True]
# 439 Text feature [whole] present in test data point [True]
# 440 Text feature [membrane] present in test data point [True]
# 442 Text feature [either] present in test data point [True]
# 443 Text feature [phosphate] present in test data point [True]
# 444 Text feature [double] present in test data point [True]
# 448 Text feature [open] present in test data point [True]
# 449 Text feature [vector] present in test data point [True]
# 450 Text feature [jak2] present in test data point [True]
# 451 Text feature [coding] present in test data point [True]
# 452 Text feature [made] present in test data point [True]
# 453 Text feature [well] present in test data point [True]
# 454 Text feature [14] present in test data point [True]
# 455 Text feature [leads] present in test data point [True]
# 456 Text feature [tumors] present in test data point [True]
# 462 Text feature [flt3] present in test data point [True]
# 463 Text feature [essential] present in test data point [True]
# 464 Text feature [strong] present in test data point [True]
# 465 Text feature [possibility] present in test data point [True]
# 466 Text feature [57] present in test data point [True]
# 467 Text feature [nm] present in test data point [True]
# 469 Text feature [forms] present in test data point [True]
# 470 Text feature [cell] present in test data point [True]
# 471 Text feature [previous] present in test data point [True]
# 472 Text feature [various] present in test data point [True]
# 473 Text feature [seen] present in test data point [True]
# 478 Text feature [experimental] present in test data point [True]
# 479 Text feature [use] present in test data point [True]
# 487 Text feature [frequency] present in test data point [True]
# 488 Text feature [region] present in test data point [True]
# 489 Text feature [1996] present in test data point [True]
# 490 Text feature [signal] present in test data point [True]
# 492 Text feature [growth] present in test data point [True]
# 494 Text feature [level] present in test data point [True]
# 495 Text feature [plates] present in test data point [True]
# 496 Text feature [structures] present in test data point [True]
# 497 Text feature [respectively] present in test data point [True]
# 498 Text feature [nucleotide] present in test data point [True]
# Out of the top  500  features  188 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With TFIDF features)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding_tfidf, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding_tfidf, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_tfidf)
rf_log_loss_train2 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_tfidf)
rf_log_loss_cv2 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_tfidf)
rf_log_loss_test2 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2415910367357876
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2486911878689548
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2399302308674107
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2398352424754449
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2308875390665652
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2346652552229862
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2289970159742045
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2338460276562577
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2308595260912982
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.2330671656739398
# For values of best estimator =  1000 The train log loss is: 0.8401557438585768
# For values of best estimator =  1000 The cross validation log loss is: 1.228997015974205
# For values of best estimator =  1000 The test log loss is: 1.1998203029714836

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding_tfidf, train_y,cv_x_onehotCoding_tfidf,cv_y, clf)
# Out:
# Log loss : 1.2289970159742047
# Number of mis-classified points : 0.44548872180451127
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_tfidf, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.3124 0.1141 0.0169 0.3183 0.0662 0.0715 0.0829 0.0078 0.0099]]
# Actual Class : 2
# --------------------------------------------------
# 3 Text feature [activation] present in test data point [True]
# 33 Text feature [expression] present in test data point [True]
# 34 Text feature [cell] present in test data point [True]
# 37 Text feature [cells] present in test data point [True]
# 39 Text feature [activate] present in test data point [True]
# 45 Text feature [growth] present in test data point [True]
# 47 Text feature [clinical] present in test data point [True]
# 54 Text feature [protein] present in test data point [True]
# 61 Text feature [activity] present in test data point [True]
# 67 Text feature [patients] present in test data point [True]
# 70 Text feature [lines] present in test data point [True]
# 75 Text feature [3t3] present in test data point [True]
# 84 Text feature [dna] present in test data point [True]
# Out of the top  100  features  13 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_tfidf[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0097 0.0941 0.0174 0.0126 0.0263 0.0217 0.8123 0.0047 0.0011]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [inhibitors] present in test data point [True]
# 2 Text feature [activating] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [activated] present in test data point [True]
# 5 Text feature [constitutive] present in test data point [True]
# 6 Text feature [tyrosine] present in test data point [True]
# 7 Text feature [inhibitor] present in test data point [True]
# 9 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [function] present in test data point [True]
# 11 Text feature [loss] present in test data point [True]
# 14 Text feature [treatment] present in test data point [True]
# 16 Text feature [receptor] present in test data point [True]
# 17 Text feature [therapy] present in test data point [True]
# 18 Text feature [oncogenic] present in test data point [True]
# 19 Text feature [signaling] present in test data point [True]
# 22 Text feature [constitutively] present in test data point [True]
# 25 Text feature [therapeutic] present in test data point [True]
# 26 Text feature [kinases] present in test data point [True]
# 28 Text feature [erk] present in test data point [True]
# 29 Text feature [inhibited] present in test data point [True]
# 32 Text feature [transforming] present in test data point [True]
# 33 Text feature [expression] present in test data point [True]
# 34 Text feature [cell] present in test data point [True]
# 35 Text feature [neutral] present in test data point [True]
# 36 Text feature [inhibition] present in test data point [True]
# 37 Text feature [cells] present in test data point [True]
# 38 Text feature [drug] present in test data point [True]
# 39 Text feature [activate] present in test data point [True]
# 40 Text feature [functional] present in test data point [True]
# 42 Text feature [months] present in test data point [True]
# 44 Text feature [57] present in test data point [True]
# 45 Text feature [growth] present in test data point [True]
# 47 Text feature [clinical] present in test data point [True]
# 48 Text feature [treated] present in test data point [True]
# 51 Text feature [trials] present in test data point [True]
# 52 Text feature [response] present in test data point [True]
# 54 Text feature [protein] present in test data point [True]
# 55 Text feature [akt] present in test data point [True]
# 56 Text feature [oncogene] present in test data point [True]
# 59 Text feature [sensitivity] present in test data point [True]
# 60 Text feature [proliferation] present in test data point [True]
# 61 Text feature [activity] present in test data point [True]
# 62 Text feature [extracellular] present in test data point [True]
# 63 Text feature [downstream] present in test data point [True]
# 64 Text feature [repair] present in test data point [True]
# 65 Text feature [dose] present in test data point [True]
# 66 Text feature [expected] present in test data point [True]
# 67 Text feature [patients] present in test data point [True]
# 69 Text feature [predicted] present in test data point [True]
# 70 Text feature [lines] present in test data point [True]
# 71 Text feature [resistance] present in test data point [True]
# 72 Text feature [ic50] present in test data point [True]
# 73 Text feature [proteins] present in test data point [True]
# 78 Text feature [mek] present in test data point [True]
# 81 Text feature [ligand] present in test data point [True]
# 82 Text feature [ba] present in test data point [True]
# 84 Text feature [dna] present in test data point [True]
# 86 Text feature [f3] present in test data point [True]
# 87 Text feature [survival] present in test data point [True]
# 88 Text feature [nuclear] present in test data point [True]
# 89 Text feature [substitutions] present in test data point [True]
# 90 Text feature [combined] present in test data point [True]
# 91 Text feature [imatinib] present in test data point [True]
# 93 Text feature [inactivation] present in test data point [True]
# 94 Text feature [assays] present in test data point [True]
# 95 Text feature [expressing] present in test data point [True]
# 97 Text feature [mutant] present in test data point [True]
# 99 Text feature [mutants] present in test data point [True]
# Out of the top  100  features  69 are present in query point

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding_tfidf, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

estimators =[('sig_clf1', sig_clf1),('sig_clf2',sig_clf2),('sig_clf3',sig_clf3)]

sig_clf1.fit(train_x_onehotCoding_tfidf, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding_tfidf))))
sig_clf2.fit(train_x_onehotCoding_tfidf, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding_tfidf))))
sig_clf3.fit(train_x_onehotCoding_tfidf, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding_tfidf))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(estimators=estimators,final_estimator=lr, stack_method='predict_proba')
    sclf.fit(train_x_onehotCoding_tfidf, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding_tfidf))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding_tfidf))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.02
# Support vector machines : Log Loss: 1.81
# Naive Bayes : Log Loss: 1.18
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 1.821
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.743
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.395
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.088
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.015
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.009

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=1)
sclf = StackingClassifier(estimators=estimators,final_estimator=lr, stack_method='predict_proba')
sclf.fit(train_x_onehotCoding_tfidf, train_y)

log_error_train2 = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding_tfidf))
print("Log loss (train) on the stacking classifier :",log_error)

log_error_cv2 = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding_tfidf))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error_test2 = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding_tfidf))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding_tfidf))
# Out:
# Log loss (train) on the stacking classifier : 1.0093099473305966
# Log loss (CV) on the stacking classifier : 1.0093099473305966
# Log loss (test) on the stacking classifier : 1.0093099473305966
# Number of missclassified point : 0.38646616541353385
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding_tfidf, train_y)

mvc_log_loss_train2  = log_loss(train_y, vclf.predict_proba(train_x_onehotCoding_tfidf))
mvc_log_loss_cv2  = log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding_tfidf))
mvc_log_loss_test2  = log_loss(test_y, vclf.predict_proba(test_x_onehotCoding_tfidf))

print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding_tfidf)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding_tfidf)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding_tfidf)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding_tfidf))
# Out:
# Log loss (train) on the VotingClassifier : 0.9359654854445902
# Log loss (CV) on the VotingClassifier : 1.1865805802890894
# Log loss (test) on the VotingClassifier : 1.2098957899914078
# Number of missclassified point : 0.3849624060150376
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Assignment part2
# <li>Apply Logistic regression with CountVectorizer Features, including both unigrams and bigrams</li>
# <li> Try any of the feature engineering techniques discussed in the course to reduce the CV and test log-loss to a value less than 1.0</li>

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
from sklearn.feature_extraction.text import CountVectorizer
def get_impfeature_names_lr(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer(max_features=1000,ngram_range=(1,2))
    var_count_vec = CountVectorizer(max_features=1000,ngram_range=(1,2))
    text_count_vec = CountVectorizer(max_features=1000,min_df=3,ngram_range=(1,2))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
# one-hot encoding of Gene feature.
gene_lr_bi = CountVectorizer(max_features=1000,ngram_range=(1,2))
train_gene_feature_onehotCoding_lr_bi = gene_lr_bi.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding_lr_bi = gene_lr_bi.transform(test_df['Gene'])
cv_gene_feature_onehotCoding_lr_bi = gene_lr_bi.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_lr_bi = CountVectorizer(max_features=1000,ngram_range=(1,2))
train_variation_feature_onehotCoding_lr_bi = variation_lr_bi.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding_lr_bi = variation_lr_bi.transform(test_df['Variation'])
cv_variation_feature_onehotCoding_lr_bi = variation_lr_bi.transform(cv_df['Variation'])

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_lr_bi = CountVectorizer(max_features=1000,ngram_range=(1,2),min_df=3)
train_text_feature_onehotCoding_lr_bi = text_lr_bi.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features_lr_bi= text_lr_bi.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts_lr_bi = train_text_feature_onehotCoding_lr_bi.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict_lr_bi = dict(zip(list(train_text_features_lr_bi),train_text_fea_counts_lr_bi))


print("Total number of unique words in train data :", len(train_text_features_lr_bi))
# Out:
# Total number of unique words in train data : 1000

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding_lr_bi = normalize(train_text_feature_onehotCoding_lr_bi, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_lr_bi = text_lr_bi.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_lr_bi = normalize(test_text_feature_onehotCoding_lr_bi, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_lr_bi = text_lr_bi.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_lr_bi = normalize(cv_text_feature_onehotCoding_lr_bi, axis=0)

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding_lr_bi = hstack((train_gene_feature_onehotCoding_lr_bi,train_variation_feature_onehotCoding_lr_bi))
test_gene_var_onehotCoding_lr_bi = hstack((test_gene_feature_onehotCoding_lr_bi,test_variation_feature_onehotCoding_lr_bi))
cv_gene_var_onehotCoding_lr_bi = hstack((cv_gene_feature_onehotCoding_lr_bi,cv_variation_feature_onehotCoding_lr_bi))

train_x_onehotCoding_lr_bi = hstack((train_gene_var_onehotCoding_lr_bi, train_text_feature_onehotCoding_lr_bi)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding_lr_bi = hstack((test_gene_var_onehotCoding_lr_bi, test_text_feature_onehotCoding_lr_bi)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding_lr_bi = hstack((cv_gene_var_onehotCoding_lr_bi, cv_text_feature_onehotCoding_lr_bi)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features with uni and bigrams:")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding_lr_bi.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding_lr_bi.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding_lr_bi.shape)
# Out:
# One hot encoding features with uni and bigrams:
# (number of data points * number of features) in train data =  (2124, 2227)
# (number of data points * number of features) in test data =  (665, 2227)
# (number of data points * number of features) in cross validation data = (532, 2227)

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha_lr_bi = [10 ** x for x in range(-6, 3)]
cv_log_error_array_lr_bi = []
for i in alpha_lr_bi:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
    cv_log_error_array_lr_bi.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha_lr_bi, cv_log_error_array_lr_bi,c='g')
for i, txt in enumerate(np.round(cv_log_error_array_lr_bi,3)):
    ax.annotate((alpha_lr_bi[i],str(txt)), (alpha_lr_bi[i],cv_log_error_array_lr_bi[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha_lr_bi = np.argmin(cv_log_error_array_lr_bi)
clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_lr_bi)
lr_log_loss_train3 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
lr_log_loss_cv3 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_lr_bi)
lr_log_loss_test3 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.177779507205834
# for alpha = 1e-05
# Log Loss : 1.041858214106223
# for alpha = 0.0001
# Log Loss : 0.9792026921960443
# for alpha = 0.001
# Log Loss : 1.040443551613591
# for alpha = 0.01
# Log Loss : 1.31261767643171
# for alpha = 0.1
# Log Loss : 1.7232136779174387
# for alpha = 1
# Log Loss : 1.7735987486108717
# for alpha = 10
# Log Loss : 1.7783469062011983
# for alpha = 100
# Log Loss : 1.7788685490269458
# For values of best alpha =  0.0001 The train log loss is: 0.5520839682234948
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9800392667501542
# For values of best alpha =  0.0001 The test log loss is: 0.9964458770454113

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_lr_bi, train_y, cv_x_onehotCoding_lr_bi, cv_y, clf)
# Out:
# Log loss : 0.9792026921960443
# Number of mis-classified points : 0.33646616541353386
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names_lr_bi(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding_lr_bi.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0683 0.0663 0.0282 0.0408 0.0437 0.0402 0.6835 0.0098 0.0192]]
# Actual Class : 2
# --------------------------------------------------
# 36 Text feature [approximately] present in test data point [True]
# 57 Text feature [malignant] present in test data point [True]
# 81 Text feature [obtained] present in test data point [True]
# 84 Text feature [2a] present in test data point [True]
# 93 Text feature [3b] present in test data point [True]
# 99 Text feature [2b] present in test data point [True]
# 117 Text feature [3a] present in test data point [True]
# 175 Text feature [biochemical] present in test data point [True]
# 218 Text feature [activation] present in test data point [True]
# 219 Text feature [adenocarcinoma] present in test data point [True]
# 227 Text feature [72] present in test data point [True]
# 232 Text feature [factors] present in test data point [True]
# 233 Text feature [bone] present in test data point [True]
# 249 Text feature [3t3] present in test data point [True]
# 250 Text feature [respectively] present in test data point [True]
# 303 Text feature [total] present in test data point [True]
# 314 Text feature [blot] present in test data point [True]
# 321 Text feature [metastatic] present in test data point [True]
# 326 Text feature [fig] present in test data point [True]
# 327 Text feature [common] present in test data point [True]
# 331 Text feature [factor] present in test data point [True]
# 349 Text feature [tumors] present in test data point [True]
# 360 Text feature [represent] present in test data point [True]
# 362 Text feature [similarly] present in test data point [True]
# 371 Text feature [22] present in test data point [True]
# 372 Text feature [tumor] present in test data point [True]
# 411 Text feature [transcription] present in test data point [True]
# 417 Text feature [similar] present in test data point [True]
# 426 Text feature [positive] present in test data point [True]
# 433 Text feature [features] present in test data point [True]
# 436 Text feature [showed] present in test data point [True]
# 438 Text feature [12] present in test data point [True]
# 441 Text feature [14] present in test data point [True]
# 451 Text feature [materials] present in test data point [True]
# 453 Text feature [locus] present in test data point [True]
# 454 Text feature [may] present in test data point [True]
# 459 Text feature [previously] present in test data point [True]
# 464 Text feature [cells] present in test data point [True]
# 469 Text feature [characteristics] present in test data point [True]
# 488 Text feature [like] present in test data point [True]
# Out of the top  500  features  40 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[6.000e-04 8.100e-03 8.000e-04 3.600e-03 8.000e-04 1.000e-04 9.828e-01
#   3.100e-03 0.000e+00]]
# Actual Class : 7
# --------------------------------------------------
# 16 Text feature [inhibited] present in test data point [True]
# 17 Text feature [downstream] present in test data point [True]
# 19 Text feature [codon] present in test data point [True]
# 22 Text feature [insertion] present in test data point [True]
# 29 Text feature [constitutive] present in test data point [True]
# 31 Text feature [constitutively] present in test data point [True]
# 32 Text feature [overexpression] present in test data point [True]
# 36 Text feature [approximately] present in test data point [True]
# 39 Text feature [hours] present in test data point [True]
# 40 Text feature [concentrations] present in test data point [True]
# 51 Text feature [oncogene] present in test data point [True]
# 55 Text feature [inhibitor] present in test data point [True]
# 57 Text feature [malignant] present in test data point [True]
# 61 Text feature [mapk] present in test data point [True]
# 65 Text feature [transforming] present in test data point [True]
# 75 Text feature [ligand] present in test data point [True]
# 81 Text feature [obtained] present in test data point [True]
# 84 Text feature [2a] present in test data point [True]
# 85 Text feature [versus] present in test data point [True]
# 91 Text feature [activated] present in test data point [True]
# 93 Text feature [3b] present in test data point [True]
# 98 Text feature [without] present in test data point [True]
# 99 Text feature [2b] present in test data point [True]
# 106 Text feature [wt] present in test data point [True]
# 117 Text feature [3a] present in test data point [True]
# 132 Text feature [double] present in test data point [True]
# 135 Text feature [provided] present in test data point [True]
# 137 Text feature [expressing] present in test data point [True]
# 139 Text feature [extracellular] present in test data point [True]
# 143 Text feature [pathways] present in test data point [True]
# 146 Text feature [derived] present in test data point [True]
# 149 Text feature [forms] present in test data point [True]
# 161 Text feature [combination] present in test data point [True]
# 166 Text feature [itd] present in test data point [True]
# 174 Text feature [initial] present in test data point [True]
# 188 Text feature [leading] present in test data point [True]
# 189 Text feature [nucleotide] present in test data point [True]
# 208 Text feature [flt3] present in test data point [True]
# 212 Text feature [coding] present in test data point [True]
# 214 Text feature [size] present in test data point [True]
# 215 Text feature [mutant] present in test data point [True]
# 218 Text feature [activation] present in test data point [True]
# 223 Text feature [high] present in test data point [True]
# 227 Text feature [72] present in test data point [True]
# 231 Text feature [000] present in test data point [True]
# 232 Text feature [factors] present in test data point [True]
# 233 Text feature [bone] present in test data point [True]
# 238 Text feature [src] present in test data point [True]
# 239 Text feature [enhanced] present in test data point [True]
# 241 Text feature [proliferation] present in test data point [True]
# 243 Text feature [bp] present in test data point [True]
# 246 Text feature [sensitive] present in test data point [True]
# 250 Text feature [respectively] present in test data point [True]
# 251 Text feature [calculated] present in test data point [True]
# 253 Text feature [somatic] present in test data point [True]
# 254 Text feature [occur] present in test data point [True]
# 257 Text feature [signaling] present in test data point [True]
# 262 Text feature [ph] present in test data point [True]
# 264 Text feature [receptors] present in test data point [True]
# 265 Text feature [nm] present in test data point [True]
# 266 Text feature [cultured] present in test data point [True]
# 269 Text feature [colony] present in test data point [True]
# 271 Text feature [caused] present in test data point [True]
# 276 Text feature [rates] present in test data point [True]
# 284 Text feature [specimens] present in test data point [True]
# 288 Text feature [early] present in test data point [True]
# 303 Text feature [total] present in test data point [True]
# 313 Text feature [experimental] present in test data point [True]
# 314 Text feature [blot] present in test data point [True]
# 315 Text feature [per] present in test data point [True]
# 316 Text feature [fold] present in test data point [True]
# 320 Text feature [induction] present in test data point [True]
# 322 Text feature [sequenced] present in test data point [True]
# 323 Text feature [leukemia] present in test data point [True]
# 324 Text feature [fact] present in test data point [True]
# 327 Text feature [common] present in test data point [True]
# 331 Text feature [factor] present in test data point [True]
# 333 Text feature [tyrosine] present in test data point [True]
# 336 Text feature [effective] present in test data point [True]
# 340 Text feature [membrane] present in test data point [True]
# 342 Text feature [blood] present in test data point [True]
# 346 Text feature [51] present in test data point [True]
# 347 Text feature [mutants] present in test data point [True]
# 348 Text feature [1a] present in test data point [True]
# 349 Text feature [tumors] present in test data point [True]
# 350 Text feature [days] present in test data point [True]
# 353 Text feature [additional] present in test data point [True]
# 356 Text feature [mechanisms] present in test data point [True]
# 357 Text feature [transformation] present in test data point [True]
# 360 Text feature [represent] present in test data point [True]
# 362 Text feature [similarly] present in test data point [True]
# 365 Text feature [less] present in test data point [True]
# 366 Text feature [treated] present in test data point [True]
# 368 Text feature [presence] present in test data point [True]
# 371 Text feature [22] present in test data point [True]
# 373 Text feature [tissues] present in test data point [True]
# 375 Text feature [2000] present in test data point [True]
# 376 Text feature [properties] present in test data point [True]
# 378 Text feature [absence] present in test data point [True]
# 380 Text feature [see] present in test data point [True]
# 382 Text feature [regulated] present in test data point [True]
# 383 Text feature [clones] present in test data point [True]
# 386 Text feature [published] present in test data point [True]
# 392 Text feature [various] present in test data point [True]
# 395 Text feature [jak2] present in test data point [True]
# 398 Text feature [syndrome] present in test data point [True]
# 399 Text feature [2002] present in test data point [True]
# 401 Text feature [70] present in test data point [True]
# 404 Text feature [greater] present in test data point [True]
# 405 Text feature [events] present in test data point [True]
# 406 Text feature [open] present in test data point [True]
# 408 Text feature [university] present in test data point [True]
# 411 Text feature [transcription] present in test data point [True]
# 415 Text feature [note] present in test data point [True]
# 417 Text feature [similar] present in test data point [True]
# 418 Text feature [association] present in test data point [True]
# 419 Text feature [require] present in test data point [True]
# 426 Text feature [positive] present in test data point [True]
# 429 Text feature [higher] present in test data point [True]
# 430 Text feature [mm] present in test data point [True]
# 433 Text feature [features] present in test data point [True]
# 434 Text feature [erk] present in test data point [True]
# 436 Text feature [showed] present in test data point [True]
# 438 Text feature [12] present in test data point [True]
# 440 Text feature [rate] present in test data point [True]
# 441 Text feature [14] present in test data point [True]
# 446 Text feature [drug] present in test data point [True]
# 449 Text feature [basal] present in test data point [True]
# 451 Text feature [materials] present in test data point [True]
# 452 Text feature [dose] present in test data point [True]
# 454 Text feature [may] present in test data point [True]
# 459 Text feature [previously] present in test data point [True]
# 460 Text feature [suggest] present in test data point [True]
# 462 Text feature [day] present in test data point [True]
# 463 Text feature [recently] present in test data point [True]
# 464 Text feature [cells] present in test data point [True]
# 465 Text feature [gfp] present in test data point [True]
# 468 Text feature [kinases] present in test data point [True]
# 469 Text feature [characteristics] present in test data point [True]
# 470 Text feature [24] present in test data point [True]
# 476 Text feature [sensitivity] present in test data point [True]
# 482 Text feature [distinct] present in test data point [True]
# 484 Text feature [position] present in test data point [True]
# 485 Text feature [phase] present in test data point [True]
# 486 Text feature [52] present in test data point [True]
# 487 Text feature [inhibition] present in test data point [True]
# 488 Text feature [like] present in test data point [True]
# 490 Text feature [mechanism] present in test data point [True]
# 493 Text feature [added] present in test data point [True]
# 494 Text feature [compared] present in test data point [True]
# 497 Text feature [contrast] present in test data point [True]
# 499 Text feature [pdgfr] present in test data point [True]
# Out of the top  500  features  152 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha_lr_bi = [10 ** x for x in range(-6, 1)]
cv_log_error_array_lr_bi = []
for i in alpha_lr_bi:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
    cv_log_error_array_lr_bi.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha_lr_bi, cv_log_error_array_lr_bi,c='g')
for i, txt in enumerate(np.round(cv_log_error_array_lr_bi,3)):
    ax.annotate((alpha_lr_bi[i],str(txt)), (alpha_lr_bi[i],cv_log_error_array_lr_bi[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha_lr_bi = np.argmin(cv_log_error_array_lr_bi)
clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_lr_bi, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_lr_bi)
lr_log_loss_train32 = log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_lr_bi)
lr_log_loss_cv32 = log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_lr_bi)
lr_log_loss_test32 = log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)

print('For values of best alpha = ', alpha_lr_bi[best_alpha_lr_bi], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2151416200264802
# for alpha = 1e-05
# Log Loss : 1.0614766160262186
# for alpha = 0.0001
# Log Loss : 0.9800392667501542
# for alpha = 0.001
# Log Loss : 1.1080747142902796
# for alpha = 0.01
# Log Loss : 1.3366706428959532
# for alpha = 0.1
# Log Loss : 1.6020826374665995
# for alpha = 1
# Log Loss : 1.7132897934632354
# For values of best alpha =  0.0001 The train log loss is: 0.5520839682234948
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9800392667501542
# For values of best alpha =  0.0001 The test log loss is: 0.9964458770454113

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_lr_bi, train_y, cv_x_onehotCoding_lr_bi, cv_y, clf)
# Out:
# Log loss : 0.9800392667501542
# Number of mis-classified points : 0.33646616541353386
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha_lr_bi[best_alpha_lr_bi], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_lr_bi,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0683 0.0663 0.0282 0.0408 0.0437 0.0402 0.6835 0.0098 0.0192]]
# Actual Class : 2
# --------------------------------------------------
# 31 Text feature [approximately] present in test data point [True]
# 51 Text feature [2a] present in test data point [True]
# 69 Text feature [malignant] present in test data point [True]
# 94 Text feature [2b] present in test data point [True]
# 95 Text feature [obtained] present in test data point [True]
# 115 Text feature [3b] present in test data point [True]
# 128 Text feature [3a] present in test data point [True]
# 215 Text feature [respectively] present in test data point [True]
# 218 Text feature [bone] present in test data point [True]
# 226 Text feature [biochemical] present in test data point [True]
# 240 Text feature [adenocarcinoma] present in test data point [True]
# 245 Text feature [72] present in test data point [True]
# 261 Text feature [blot] present in test data point [True]
# 274 Text feature [factors] present in test data point [True]
# 282 Text feature [activation] present in test data point [True]
# 284 Text feature [common] present in test data point [True]
# 305 Text feature [total] present in test data point [True]
# 341 Text feature [represent] present in test data point [True]
# 342 Text feature [fig] present in test data point [True]
# 343 Text feature [3t3] present in test data point [True]
# 360 Text feature [tumor] present in test data point [True]
# 365 Text feature [factor] present in test data point [True]
# 366 Text feature [metastatic] present in test data point [True]
# 371 Text feature [previously] present in test data point [True]
# 373 Text feature [like] present in test data point [True]
# 383 Text feature [locus] present in test data point [True]
# 385 Text feature [22] present in test data point [True]
# 401 Text feature [transcription] present in test data point [True]
# 405 Text feature [materials] present in test data point [True]
# 410 Text feature [positive] present in test data point [True]
# 416 Text feature [showed] present in test data point [True]
# 420 Text feature [similar] present in test data point [True]
# 424 Text feature [two] present in test data point [True]
# 425 Text feature [tumors] present in test data point [True]
# 448 Text feature [features] present in test data point [True]
# 450 Text feature [12] present in test data point [True]
# 455 Text feature [form] present in test data point [True]
# 463 Text feature [similarly] present in test data point [True]
# 472 Text feature [may] present in test data point [True]
# 481 Text feature [specific] present in test data point [True]
# 485 Text feature [structure] present in test data point [True]
# 499 Text feature [11] present in test data point [True]
# Out of the top  500  features  42 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_lr_bi[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_lr_bi[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_lr(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[6.000e-04 8.100e-03 8.000e-04 3.600e-03 8.000e-04 1.000e-04 9.828e-01
#   3.100e-03 0.000e+00]]
# Actual Class : 7
# --------------------------------------------------
# 12 Text feature [codon] present in test data point [True]
# 19 Text feature [downstream] present in test data point [True]
# 20 Text feature [inhibited] present in test data point [True]
# 25 Text feature [insertion] present in test data point [True]
# 31 Text feature [approximately] present in test data point [True]
# 32 Text feature [overexpression] present in test data point [True]
# 44 Text feature [hours] present in test data point [True]
# 48 Text feature [constitutively] present in test data point [True]
# 51 Text feature [2a] present in test data point [True]
# 55 Text feature [constitutive] present in test data point [True]
# 60 Text feature [concentrations] present in test data point [True]
# 69 Text feature [malignant] present in test data point [True]
# 71 Text feature [oncogene] present in test data point [True]
# 74 Text feature [mapk] present in test data point [True]
# 75 Text feature [transforming] present in test data point [True]
# 78 Text feature [inhibitor] present in test data point [True]
# 79 Text feature [ligand] present in test data point [True]
# 94 Text feature [2b] present in test data point [True]
# 95 Text feature [obtained] present in test data point [True]
# 99 Text feature [without] present in test data point [True]
# 103 Text feature [wt] present in test data point [True]
# 115 Text feature [3b] present in test data point [True]
# 127 Text feature [versus] present in test data point [True]
# 128 Text feature [3a] present in test data point [True]
# 129 Text feature [forms] present in test data point [True]
# 133 Text feature [provided] present in test data point [True]
# 136 Text feature [extracellular] present in test data point [True]
# 139 Text feature [activated] present in test data point [True]
# 145 Text feature [coding] present in test data point [True]
# 150 Text feature [bp] present in test data point [True]
# 156 Text feature [double] present in test data point [True]
# 164 Text feature [derived] present in test data point [True]
# 166 Text feature [size] present in test data point [True]
# 172 Text feature [calculated] present in test data point [True]
# 174 Text feature [expressing] present in test data point [True]
# 177 Text feature [high] present in test data point [True]
# 181 Text feature [leading] present in test data point [True]
# 183 Text feature [src] present in test data point [True]
# 187 Text feature [pathways] present in test data point [True]
# 193 Text feature [initial] present in test data point [True]
# 195 Text feature [ph] present in test data point [True]
# 215 Text feature [respectively] present in test data point [True]
# 217 Text feature [enhanced] present in test data point [True]
# 218 Text feature [bone] present in test data point [True]
# 221 Text feature [000] present in test data point [True]
# 224 Text feature [combination] present in test data point [True]
# 231 Text feature [mutant] present in test data point [True]
# 232 Text feature [nucleotide] present in test data point [True]
# 235 Text feature [itd] present in test data point [True]
# 238 Text feature [experimental] present in test data point [True]
# 245 Text feature [72] present in test data point [True]
# 246 Text feature [flt3] present in test data point [True]
# 247 Text feature [somatic] present in test data point [True]
# 254 Text feature [additional] present in test data point [True]
# 258 Text feature [cultured] present in test data point [True]
# 259 Text feature [fold] present in test data point [True]
# 261 Text feature [blot] present in test data point [True]
# 262 Text feature [occur] present in test data point [True]
# 264 Text feature [mutants] present in test data point [True]
# 271 Text feature [rates] present in test data point [True]
# 274 Text feature [factors] present in test data point [True]
# 276 Text feature [caused] present in test data point [True]
# 280 Text feature [sensitive] present in test data point [True]
# 282 Text feature [activation] present in test data point [True]
# 284 Text feature [common] present in test data point [True]
# 295 Text feature [greater] present in test data point [True]
# 296 Text feature [specimens] present in test data point [True]
# 300 Text feature [proliferation] present in test data point [True]
# 304 Text feature [note] present in test data point [True]
# 305 Text feature [total] present in test data point [True]
# 307 Text feature [signaling] present in test data point [True]
# 308 Text feature [colony] present in test data point [True]
# 309 Text feature [events] present in test data point [True]
# 310 Text feature [2002] present in test data point [True]
# 312 Text feature [fact] present in test data point [True]
# 313 Text feature [nm] present in test data point [True]
# 316 Text feature [2000] present in test data point [True]
# 317 Text feature [blood] present in test data point [True]
# 319 Text feature [sequenced] present in test data point [True]
# 322 Text feature [receptors] present in test data point [True]
# 325 Text feature [per] present in test data point [True]
# 328 Text feature [early] present in test data point [True]
# 329 Text feature [mm] present in test data point [True]
# 330 Text feature [leukemia] present in test data point [True]
# 331 Text feature [days] present in test data point [True]
# 333 Text feature [genomic] present in test data point [True]
# 337 Text feature [less] present in test data point [True]
# 341 Text feature [represent] present in test data point [True]
# 347 Text feature [clones] present in test data point [True]
# 348 Text feature [membrane] present in test data point [True]
# 351 Text feature [presence] present in test data point [True]
# 358 Text feature [see] present in test data point [True]
# 359 Text feature [mechanisms] present in test data point [True]
# 362 Text feature [tyrosine] present in test data point [True]
# 363 Text feature [various] present in test data point [True]
# 364 Text feature [1a] present in test data point [True]
# 365 Text feature [factor] present in test data point [True]
# 368 Text feature [regulated] present in test data point [True]
# 370 Text feature [tissues] present in test data point [True]
# 371 Text feature [previously] present in test data point [True]
# 373 Text feature [like] present in test data point [True]
# 377 Text feature [university] present in test data point [True]
# 385 Text feature [22] present in test data point [True]
# 386 Text feature [absence] present in test data point [True]
# 387 Text feature [induction] present in test data point [True]
# 389 Text feature [70] present in test data point [True]
# 392 Text feature [effective] present in test data point [True]
# 395 Text feature [published] present in test data point [True]
# 397 Text feature [properties] present in test data point [True]
# 401 Text feature [transcription] present in test data point [True]
# 403 Text feature [75] present in test data point [True]
# 405 Text feature [materials] present in test data point [True]
# 406 Text feature [association] present in test data point [True]
# 408 Text feature [open] present in test data point [True]
# 410 Text feature [positive] present in test data point [True]
# 413 Text feature [distinct] present in test data point [True]
# 416 Text feature [showed] present in test data point [True]
# 417 Text feature [51] present in test data point [True]
# 420 Text feature [similar] present in test data point [True]
# 424 Text feature [two] present in test data point [True]
# 425 Text feature [tumors] present in test data point [True]
# 434 Text feature [gfp] present in test data point [True]
# 435 Text feature [suggest] present in test data point [True]
# 442 Text feature [sensitivity] present in test data point [True]
# 444 Text feature [transformation] present in test data point [True]
# 447 Text feature [higher] present in test data point [True]
# 448 Text feature [features] present in test data point [True]
# 449 Text feature [dose] present in test data point [True]
# 450 Text feature [12] present in test data point [True]
# 455 Text feature [form] present in test data point [True]
# 456 Text feature [fraction] present in test data point [True]
# 463 Text feature [similarly] present in test data point [True]
# 464 Text feature [prior] present in test data point [True]
# 465 Text feature [require] present in test data point [True]
# 467 Text feature [sites] present in test data point [True]
# 469 Text feature [rate] present in test data point [True]
# 470 Text feature [region] present in test data point [True]
# 471 Text feature [recently] present in test data point [True]
# 472 Text feature [may] present in test data point [True]
# 473 Text feature [syndrome] present in test data point [True]
# 474 Text feature [increased] present in test data point [True]
# 475 Text feature [24] present in test data point [True]
# 480 Text feature [added] present in test data point [True]
# 481 Text feature [specific] present in test data point [True]
# 482 Text feature [phosphorylated] present in test data point [True]
# 485 Text feature [structure] present in test data point [True]
# 487 Text feature [52] present in test data point [True]
# 488 Text feature [abl] present in test data point [True]
# 490 Text feature [contribute] present in test data point [True]
# 491 Text feature [basal] present in test data point [True]
# 494 Text feature [jak2] present in test data point [True]
# 496 Text feature [level] present in test data point [True]
# 497 Text feature [mean] present in test data point [True]
# 498 Text feature [major] present in test data point [True]
# 499 Text feature [11] present in test data point [True]
# Out of the top  500  features  155 are present in query point

# %% [markdown]
# # Pretty Table for the code part provided by AAIC

# %%
from prettytable import PrettyTable

prettytbl1 = PrettyTable()
prettytbl1.field_names = ["Model","features","train log-loss", "CV log-loss", "Test log-loss"]
prettytbl1.add_row(['Random Model','N/A','N/A',ran_model_log_loss_cv,ran_model_log_loss_test])
prettytbl1.add_row(['LR','Gene',gene_feat_log_loss_train,gene_feat_log_loss_cv,gene_feat_log_loss_test])
prettytbl1.add_row(['LR','Variation',var_feat_log_loss_train,var_feat_log_loss_cv,var_feat_log_loss_test])
prettytbl1.add_row(['LR','text',text_feat_log_loss_train,text_feat_log_loss_cv,text_feat_log_loss_test])
prettytbl1.add_row(['NB','ALL',nb_log_loss_train,nb_log_loss_cv,nb_log_loss_test])
prettytbl1.add_row(['KNN','ALL',knn_log_loss_train,knn_log_loss_cv,knn_log_loss_test])
prettytbl1.add_row(['LR(class balancing)','ALL',lr_log_loss_train1,lr_log_loss_cv1,lr_log_loss_test1])
prettytbl1.add_row(['LR(w/o class bal)','ALL',lr_log_loss_train2,lr_log_loss_cv2,lr_log_loss_test2])
prettytbl1.add_row(['SVM','ALL',svm_log_loss_train1,svm_log_loss_cv1,svm_log_loss_test1])
prettytbl1.add_row(['RF (OHE)','ALL',rf_log_loss_train,rf_log_loss_cv,rf_log_loss_test])
prettytbl1.add_row(['RF (RC)','ALL',rf_log_loss_train2,rf_log_loss_cv2,rf_log_loss_test2])
prettytbl1.add_row(['Stacking','ALL',log_error_train,log_error_cv,log_error_test])
prettytbl1.add_row(['MVC','ALL',mvc_log_loss_train,mvc_log_loss_cv,mvc_log_loss_test])
print(prettytbl1)
# Out:
# +---------------------+-----------+--------------------+--------------------+--------------------+
# |        Model        |  features |   train log-loss   |    CV log-loss     |   Test log-loss    |
# +---------------------+-----------+--------------------+--------------------+--------------------+
# |     Random Model    |    N/A    |        N/A         | 2.5591571879785118 |  2.47419911121577  |
# |          LR         |    Gene   | 1.0047718818417672 | 1.1467029792466508 | 1.2095780305499841 |
# |          LR         | Variation | 1.0313666873912235 |  1.71311491020675  | 1.7009212326958498 |
# |          LR         |    text   | 0.6577423680613717 | 1.142193339659903  | 1.1719303011134463 |
# |          NB         |    ALL    | 1.0643144511923024 | 1.293715823127756  | 1.3199654413019961 |
# |         KNN         |    ALL    | 0.6554417934589064 | 1.0374678814810312 | 1.1160796715407628 |
# | LR(class balancing) |    ALL    | 0.528148104225811  | 1.0918673717076315 | 1.0881534059577134 |
# |  LR(w/o class bal)  |    ALL    | 0.5251968560481574 | 1.0910878220520284 | 1.0954251377678559 |
# |         SVM         |    ALL    | 0.5274278418921878 | 1.1339433403519878 | 1.1246401787525544 |
# |       RF (OHE)      |    ALL    | 0.6787596928231501 | 1.1587561210031554 | 1.1705417855342262 |
# |       RF (RC)       |    ALL    | 0.8401557438585768 | 1.228997015974205  | 1.1998203029714836 |
# |       Stacking      |    ALL    | 0.4938755078609015 | 1.0288006387811752 | 1.025590163391543  |
# |         MVC         |    ALL    | 0.8663460049882042 | 1.2174924374631744 | 1.2047504835260767 |
# +---------------------+-----------+--------------------+--------------------+--------------------+

# %% [markdown]
# # Prettytable for the models built with using TFIDF features as a part of assignment

# %%
from prettytable import PrettyTable

prettytbl2 = PrettyTable()
prettytbl2.field_names = ["Model","features","train log-loss", "CV log-loss", "Test log-loss"]
prettytbl2.add_row(['NB','ALL',nb_log_loss_train2,nb_log_loss_cv2,nb_log_loss_test2])
prettytbl2.add_row(['LR(class balancing)','ALL',lr_log_loss_train12,lr_log_loss_cv12,lr_log_loss_test12])
prettytbl2.add_row(['LR(w/o class bal)','ALL',lr_log_loss_train22,lr_log_loss_cv22,lr_log_loss_test22])
prettytbl2.add_row(['SVM','ALL',svm_log_loss_train12,svm_log_loss_cv12,svm_log_loss_test12])
prettytbl2.add_row(['RF','ALL',rf_log_loss_train2,rf_log_loss_cv2,rf_log_loss_test2])
prettytbl2.add_row(['Stacking','ALL',log_error_train2,log_error_cv2,log_error_test2])
prettytbl2.add_row(['MVC','ALL',mvc_log_loss_train2,mvc_log_loss_cv2,mvc_log_loss_test2])
print(prettytbl2)
# Out:
# +---------------------+----------+--------------------+--------------------+--------------------+
# |        Model        | features |   train log-loss   |    CV log-loss     |   Test log-loss    |
# +---------------------+----------+--------------------+--------------------+--------------------+
# |          NB         |   ALL    | 0.7196945218499241 | 1.1760349673130641 | 1.2036831340376948 |
# | LR(class balancing) |   ALL    | 0.5418962868552746 | 0.9919241165571845 | 1.018164298141385  |
# |  LR(w/o class bal)  |   ALL    | 0.5312557252184251 | 1.0101168874317024 | 1.030731463007708  |
# |         SVM         |   ALL    | 0.8047885514121019 | 1.1101374278039535 | 1.1410979655228277 |
# |          RF         |   ALL    | 0.8401557438585768 | 1.228997015974205  | 1.1998203029714836 |
# |       Stacking      |   ALL    | 0.7419747186090276 | 1.0150306419478827 | 1.067770054692821  |
# |         MVC         |   ALL    | 0.9359654854445902 | 1.1865805802890894 | 1.2098957899914078 |
# +---------------------+----------+--------------------+--------------------+--------------------+

# %% [markdown]
# Here LR with class balancing could produce log loss of less than 1 for train and Cv but not test

# %% [markdown]
# # Prettytable for the models built with CountVectorizer Uni/Bi Grams as part of assignment

# %%
from prettytable import PrettyTable

prettytbl3 = PrettyTable()
prettytbl3.field_names = ["Model","features","train log-loss", "CV log-loss", "Test log-loss"]
prettytbl3.add_row(['LR(class balancing)','ALL',lr_log_loss_train3,lr_log_loss_cv3,lr_log_loss_test3])
prettytbl3.add_row(['LR(w/o class bal)','ALL',lr_log_loss_train32,lr_log_loss_cv32,lr_log_loss_test32])
print(prettytbl3)
# Out:
# +---------------------+----------+--------------------+--------------------+--------------------+
# |        Model        | features |   train log-loss   |    CV log-loss     |   Test log-loss    |
# +---------------------+----------+--------------------+--------------------+--------------------+
# | LR(class balancing) |   ALL    | 0.5520839682234948 | 0.9800392667501542 | 0.9964458770454113 |
# |  LR(w/o class bal)  |   ALL    | 0.5520839682234948 | 0.9800392667501542 | 0.9964458770454113 |
# +---------------------+----------+--------------------+--------------------+--------------------+

# %% [markdown]
# Using Uni/Bi Grams ,the LR gives log loss of less than 1

# %% [markdown]
# The last part of assignment dealing with feature engineering has been procured in another notebook
